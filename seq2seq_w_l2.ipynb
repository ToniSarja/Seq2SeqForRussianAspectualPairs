# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import random
import pandas as pd

# %%
data = pd.read_csv("teacher_learner.csv")
df = pd.DataFrame(data)

# %%
teacher = df["teacher"]
learner = df["learner"]

pairs = list(zip(teacher, learner))

# %%
pairs
# Out:
# [('помочь', 'помогать'),
#  ('злоупотреблять', 'злоупотребить'),
#  ('пойти', 'идти'),
#  ('проконтролировать', 'контролировать'),
#  ('покупать', 'купить'),
#  ('начинать', 'начать'),
#  ('передавать', 'передать'),
#  ('возвращаться', 'вернуться'),
#  ('приходить', 'прийти'),
#  ('выражать', 'выразить'),
#  ('разрушать', 'разрушить'),
#  ('уделять', 'удалить'),
#  ('достигнуть', 'достигать'),
#  ('заменить', 'заменять'),
#  ('заметить', 'замечать'),
#  ('пообщаться', 'общаться'),
#  ('оживить', 'оживлять'),
#  ('помочь', 'помогать'),
#  ('помочь', 'помогать'),
#  ('помочь', 'помогать'),
#  ('поступить', 'поступать'),
#  ('представить', 'представлять'),
#  ('принимать', 'принять'),
#  ('проверить', 'проверять'),
#  ('разуверить', 'разуверять'),
#  ('сократить', 'сокращать'),
#  ('улучшить', 'улучшать'),
#  ('уступить', 'уступать'),
#  ('увидеть', 'видеть'),
#  ('увидеть', 'видеть'),
#  ('увидеть', 'видеть'),
#  ('увидеть', 'видеть'),
#  ('поговорить', 'говорить'),
#  ('приготовить', 'готовить'),
#  ('сделать', 'делать'),
#  ('сделать', 'делать'),
#  ('сделать', 'делать'),
#  ('сделать', 'делать'),
#  ('сделать это', 'делать'),
#  ('подождать', 'ждать'),
#  ('пойти', 'идти'),
#  ('сконцентрироваться', 'концентрироваться'),
#  ('закончить', 'кончать'),
#  ('покупать', 'купить'),
#  ('покупать', 'купить'),
#  ('понять,', 'могут понимать'),
#  ('сможет работать', 'может работает'),
#  ('пообедать.', 'обедать'),
#  ('оставаться', 'остаться'),
#  ('написать', 'писать'),
#  ('написать', 'писать'),
#  ('выпить', 'пить'),
#  ('оплатить', 'платить'),
#  ('поддерживать', 'поддержaть'),
#  ('продавать', 'продать'),
#  ('попросить', 'просить'),
#  ('вырасти', 'раститься'),
#  ('связывать', 'связать'),
#  ('услышать', 'слышать'),
#  ('потрогать', 'трогать'),
#  ('убивать и наносить', 'убить и нанести'),
#  ('узнавать', 'узнать'),
#  ('охарактеризовать как', 'характеризовать'),
#  ('захотеть', 'хотеть'),
#  ('почувствовать', 'чувствовать'),
#  ('почувствовать', 'чуствовать'),
#  ('вернуться', 'возвращать'),
#  ('нанести', 'наносить'),
#  ('переезжать', 'переехать'),
#  ('прийти', 'приходить'),
#  ('прийти', 'приходить'),
#  ('прийти', 'приходить'),
#  ('проводить', 'провести'),
#  ('проводить', 'провести'),
#  ('произойти', 'происходить'),
#  ('стать', 'становить'),
#  ('убивать и наносить', 'убить и нанести'),
#  ('выбрать', 'выбирать'),
#  ('изменять', 'изменить'),
#  ('изменяться', 'измениться'),
#  ('изменить', 'изменрять'),
#  ('измениться', 'изменяться'),
#  ('получать', 'получить'),
#  ('проявляться', 'проявиться'),
#  ('решать', 'решить'),
#  ('решать', 'решить'),
#  ('оказаться', 'оказываться'),
#  ('отказаться', 'отказываться'),
#  ('открыть', 'открывать'),
#  ('показать', 'показывать'),
#  ('рассмотреть', 'рассматривать'),
#  ('понять', 'понимать'),
#  ('понять', 'понимать'),
#  ('понять', 'понимать'),
#  ('понять', 'понимать'),
#  ('понять', 'понимать'),
#  ('понять', 'понимать'),
#  ('понять', 'понимать'),
#  ('писать', 'написать'),
#  ('забыть', 'забывать'),
#  ('возникнуть', 'возникать'),
#  ('выдерживать', 'выдержать'),
#  ('ответить', 'отвечать'),
#  ('выбирать', 'выбрать'),
#  ('сделать', 'делать'),
#  ('забывать', 'забыть'),
#  ('записывать', 'записать'),
#  ('пойти', 'идти'),
#  ('покупать', 'купить'),
#  ('покупать', 'купить'),
#  ('помыть', 'мыть'),
#  ('называть', 'назвать'),
#  ('одеваться', 'одеться'),
#  ('написать', 'писать'),
#  ('придумывать', 'придумать'),
#  ('признать', 'признавать'),
#  ('узнавать', 'узнать'),
#  ('помогать', 'помочь'),
#  ('выезжать', 'выехать'),
#  ('перевести', 'переводить'),
#  ('говорить', 'сказать'),
#  ('сравнить', 'сравнивать'),
#  ('понять', 'понимать'),
#  ('писать', 'написать'),
#  ('нанимать', 'нанять'),
#  ('нанимать', 'нанять'),
#  ('обсудить', 'обсуждать'),
#  ('обсудить', 'обсуждать'),
#  ('отметить', 'отмечать'),
#  ('отступить', 'отступать'),
#  ('помочь', 'помогать'),
#  ('помочь.', 'помогать'),
#  ('поразить', 'поражать'),
#  ('прекратить', 'прекращать'),
#  ('принимать', 'принять'),
#  ('продолжить', 'продалжать'),
#  ('соединиться', 'соединяться'),
#  ('увидеть', 'видеть'),
#  ('увидеть', 'видеть'),
#  ('поговорить', 'говорить'),
#  ('сделать', 'делать'),
#  ('сделать', 'делать'),
#  ('поделиться', 'делиться'),
#  ('поиграть в', 'играть'),
#  ('покупать', 'купить'),
#  ('оставаться ', 'остаться'),
#  ('написать', 'писать'),
#  ('описать', 'писать'),
#  ('написать', 'писать'),
#  ('выпить', 'пить'),
#  ('показывать', 'показать'),
#  ('услышать', 'слышать'),
#  ('потанцевать,', 'танцевать'),
#  ('знать', 'узнать'),
#  ('поучаствовать', 'участвовать'),
#  ('вернуться', 'возвращаться'),
#  ('выходить', 'выйти'),
#  ('поймать', 'ловить'),
#  ('отдохнуть', 'отдыхать'),
#  ('отдохнуть', 'отдыхать'),
#  ('отдохнуть', 'отдыхать'),
#  ('отдохнуть', 'отдыхать'),
#  ('переезжать', 'переехать'),
#  ('переезжать', 'переехать'),
#  ('предложить', 'предлагать'),
#  ('проводить', 'провести'),
#  ('проводить', 'провести'),
#  ('проводить', 'провести'),
#  ('развестись', 'разводиться'),
#  ('говорить', 'сказать'),
#  ('стать', 'становиться'),
#  ('уезжать', 'уехать'),
#  ('решать', 'решить'),
#  ('окончить', 'оканчивать'),
#  ('описать', 'описывать'),
#  ('подчеркнуть', 'подчеркивать'),
#  ('подчеркнуть', 'подчёркивать'),
#  ('рассказать', 'рассказывать'),
#  ('спросить', 'спрашивать'),
#  ('увеличить', 'увеличивать'),
#  ('обнять', 'обнимать'),
#  ('понять,', 'понимать'),
#  ('понять,', 'понимать'),
#  ('съесть', 'есть'),
#  ('советовал', 'посоветовал'),
#  ('вспомнить', 'вспоминать'),
#  ('выразить', 'выражать'),
#  ('достичь', 'достигать'),
#  ('обсудить', 'обсуждать'),
#  ('оживить', 'оживлять'),
#  ('поднимать', 'поднять'),
#  ('помочь', 'помогать'),
#  ('помочь', 'помогать'),
#  ('помочь', 'помогать'),
#  ('поступить', 'поступать'),
#  ('привлечь', 'привлекать'),
#  ('решить', 'решать'),
#  ('спасти', 'спасать'),
#  ('укрепить', 'укреплять'),
#  ('уменьшить', 'уменьшать'),
#  ('увидеть ', 'ведеть'),
#  ('увидеть', 'видеть'),
#  ('увидеть', 'видеть'),
#  ('поговорить', 'говорить'),
#  ('подготовиться', 'готовиться'),
#  ('сделать', 'делать'),
#  ('сделать', 'делать'),
#  ('сделать', 'делать'),
#  ('сделать', 'делать'),
#  ('пожить', 'жить'),
#  ('покупать', 'купить'),
#  ('пообедать', 'обедать'),
#  ('заплатить', 'платить'),
#  ('попить', 'пыть'),
#  ('порадовать', 'радовать'),
#  ('развивать', 'развить'),
#  ('развивать', 'развить'),
#  ('отремонтировать.', 'ремонтировать'),
#  ('сдавать', 'сдать'),
#  ('услышать', 'слышать'),
#  ('знать', 'узнать'),
#  ('научить', 'учить'),
#  ('вернуться', 'возвращаться'),
#  ('выйти', 'выходить'),
#  ('избежать', 'избегать'),
#  ('изменять', 'изменить'),
#  ('оставлять', 'оставить'),
#  ('решать', 'решить'),
#  ('решать', 'решить'),
#  ('улучшать', 'улучшить'),
#  ('доказать', 'доказывать'),
#  ('заработать', 'зарабатывать'),
#  ('заняться', 'заниматься'),
#  ('понять', 'понимать'),
#  ('принять', 'принимать'),
#  ('смотреть', 'посмотреть'),
#  ('узнал', 'узнавал'),
#  ('включить', 'включать'),
#  ('возникла', 'возникала'),
#  ('воспринимать', 'воспринять'),
#  ('было бы вспомнить', 'вспоминать'),
#  ('выразить', 'выражать'),
#  ('выразить', 'выражать'),
#  ('выразить', 'выразать'),
#  ('достичь', 'достигать'),
#  ('достичь', 'достигать'),
#  ('достичь', 'достигать'),
#  ('Назначить', 'Назначать'),
#  ('обручились', 'обручались'),
#  ('обсудить', 'обсуждать'),
#  ('обсудить', 'обсуждать'),
#  ('обсудить', 'обсуждать'),
#  ('обсудить', 'обсуждать'),
#  ('обсудить', 'обсуждать'),
#  ('обсудить', 'обсуждать'),
#  ('объяснить', 'объяснять'),
#  ('определить', 'определять'),
#  ('определить', 'определять'),
#  ('отличиться от', 'отличатся'),
#  ('помочь', 'памагать'),
#  ('помочь', 'помогат'),
#  ('помочь', 'помогать'),
#  ('помочь', 'помогать'),
#  ('понимать', 'понять'),
#  ('посетить', 'посещать'),
#  ('посетить', 'посещать'),
#  ('пригласил', 'приглашал'),
#  ('принимать', 'принять'),
#  ('продолжить', 'продолжать'),
#  ('продолжил', 'продолжать'),
#  ('развлечься', 'развлекаться'),
#  ('согласиться', 'соглашаться'),
#  ('убедить', 'убеждать'),
#  ('убедят', 'убеждать'),
#  ('удерживается ', 'удержаться'),
#  ('ускорить', 'ускорять'),
#  ('забронировать', 'бронировать'),
#  ('увидеть', 'видеть'),
#  ('увидеть', 'видеть'),
#  ('вывешивать', 'вывесить'),
#  ('вызывать', 'вызвать'),
#  ('выкапывать', 'выкопать'),
#  ('высказывать', 'высказать'),
#  ('высказывать', 'высказать'),
#  ('поговорить', 'говорить'),
#  ('сказать', 'говорить'),
#  ('приготовить', 'готовить'),
#  ('погулять', 'гулять'),
#  ('сделать', 'делать'),
#  ('сделать', 'делать'),
#  ('сделать', 'делать'),
#  ('сделать', 'делать'),
#  ('сделать', 'делать'),
#  ('подружиться', 'дружиться'),
#  ('подумать', 'думать'),
#  ('подумать', 'думать'),
#  ('подумать', 'думать'),
#  ('пожениться', 'жениться'),
#  ('позавтракал', 'завтракал'),
#  ('позавтракала', 'завтракала'),
#  ('узнать', 'знать'),
#  ('узнать', 'знать'),
#  ('проконтролировать', 'контролировать'),
#  ('покупать', 'купить'),
#  ('покупать', 'купить'),
#  ('покупать', 'купить'),
#  ('покупать', 'купить'),
#  ('покупать', 'купить'),
#  ('покупать', 'купить'),
#  ('помыть', 'мыть'),
#  ('помыть', 'мыть'),
#  ('начинать', 'начать'),
#  ('пообедать', 'обедать'),
#  ('описывать', 'описать'),
#  ('описывать', 'описать'),
#  ('опаздывать', 'опоздать'),
#  ('осваивать', 'освоить'),
#  ('оставаться', 'остаться'),
#  ('оставаться ', 'остаться'),
#  ('оставаться ', 'остаться'),
#  ('открывать', 'открыть'),
#  ('открывать', 'открыть'),
#  ('переписывать', 'переписать'),
#  ('напечатать', 'печатать'),
#  ('напечатать', 'печатать'),
#  ('написать', 'писать'),
#  ('прерывать', 'прервать'),
#  ('придумывать', 'придумать'),
#  ('попросить', 'просить'),
#  ('попутешествовать', 'путешествовать'),
#  ('попыталась', 'пыталась'),
#  ('попытаться', 'пытаться'),
#  ('развивать', 'развить'),
#  ('развивать', 'развить'),
#  ('сдавать', 'сдать'),
#  ('послушать', 'слушать'),
#  ('услышать то,', 'слышать'),
#  ('посмотреть', 'смотреть'),
#  ('Посмотрите', 'Смотрите'),
#  ('создавать', 'создать'),
#  ('создавать', 'создать'),
#  ('спрашивать.', 'спросить'),
#  ('спрашивать', 'спросить'),
#  ('спрашивать', 'спросить'),
#  ('постараться', 'стараться'),
#  ('потанцуем..."', 'танцевать'),
#  ('убивать', 'убить'),
#  ('узнавать', 'узнать'),
#  ('упаковывать', 'упаковать'),
#  ('устанавливать', 'установить'),
#  ('научить', 'учить'),
#  ('научитесь', 'учиться'),
#  ('сформировать', 'формировать'),
#  ('очистить', 'чистить'),
#  ('выбирать', 'выбрать'),
#  (' помочь ', 'помоготь'),
#  ('помогать', 'помочь'),
#  ('вложить', 'вкладывать'),
#  ('избежать', 'избегать'),
#  ('найти', 'находить'),
#  ('перевести', 'переводить'),
#  ('перевести.', 'переводить'),
#  ('попадать', 'попасть'),
#  ('послать', 'посылать'),
#  ('предложить', 'предлагать'),
#  ('приходит', 'прийти'),
#  ('приходит', 'прийти'),
#  ('провести', 'проводить'),
#  ('говорить', 'сказать'),
#  ('говорить', 'сказать'),
#  ('становиться', 'стать'),
#  ('становиться', 'стать'),
#  ('увозят', 'увести'),
#  ('уехать', 'уезжать'),
#  ('начать', 'начинать'),
#  ('начать', 'начинать'),
#  ('выбрать', 'выбирать'),
#  ('выбрать', 'выбирать'),
#  ('выбрать', 'выбирать'),
#  ('собрать', 'собирать'),
#  ('включать', 'включить'),
#  ('вспоминать', 'вспомнить'),
#  ('встречаться', 'встретиться'),
#  ('добавлять', 'добавить'),
#  ('добавлять', 'добавить'),
#  ('замечать', 'заметить'),
#  ('заставляют', 'заставят'),
#  ('изготовлять', 'изготовить'),
#  ('изменить', 'изменять'),
#  ('изучать', 'изучить'),
#  ('изучать', 'изучить'),
#  ('обращали', 'обратить'),
#  ('обсуждают', 'обсудить'),
#  ('объяснять', 'объяснить'),
#  ('объяснять', 'объяснить'),
#  ('определять', 'определить'),
#  ('оставляет', 'оставить'),
#  ('перемещаться', 'переместить'),
#  ('повторять', 'повторить'),
#  ('повторять', 'повторить'),
#  ('повторять', 'помнить'),
#  ('посвящать', 'посвятить'),
#  ('появляется', 'появится'),
#  ('приглашать', 'пригласить'),
#  ('примерять', 'примерить'),
#  ('разделять', 'разделить'),
#  ('расслабляется', 'расслабится'),
#  ('решать', 'решить'),
#  ('решает', 'решить'),
#  ('соединять', 'соединить'),
#  ('сохранять', 'сохранить'),
#  ('сохранять', 'сохранить'),
#  ('уверять', 'уверить'),
#  ('улучшать', 'улучшить'),
#  ('вызвали', 'вызывал'),
#  ('договориться', 'договариваться'),
#  ('закрыть', 'закрывать'),
#  ('назвать', 'называть'),
#  ('описать', 'описывать'),
#  ('описать', 'описывать'),
#  ('остановиться', 'останавливаться'),
#  ('поддержать', 'поддерживать'),
#  ('подпишет', 'подписывает'),
#  ('показать', 'показывать'),
#  ('показать, ', 'показывать'),
#  ('предсказать,', 'предсказывать'),
#  ('прервать', 'прерывать'),
#  ('расскажу', 'рассказиваю'),
#  ('рассмотреть', 'рассматрывать'),
#  ('спросить', 'спрашивать'),
#  ('увеличиться', 'увеличиваться'),
#  ('понять', 'понимать'),
#  ('понять', 'понимать'),
#  ('понять', 'понимать'),
#  ('понять', 'понимать'),
#  ('понять', 'понимать'),
#  ('понять', 'понимать'),
#  ('понять', 'понимать'),
#  ('понять', 'понимать'),
#  ('понять', 'понимать'),
#  ('принять', 'принимать'),
#  ('делать', 'cделать'),
#  ('съесть', 'есть'),
#  ('платить', 'заплатить'),
#  ('писать', 'написать'),
#  ('готовятся', 'подготовятся'),
#  ('думаю', 'подумаю'),
#  ('знакомятся', 'познакомятся'),
#  ('идут', 'поидёт'),
#  ('красят', 'покрасиют'),
#  ('мыть', 'помыть'),
#  ('нравились', 'понравилась'),
#  ('нравилось', 'понравилось'),
#  ('нравился', 'понравился'),
#  ('пытался', 'попытался'),
#  ('пытаются', 'попытаются'),
#  ('смотрела', 'посмотрела'),
#  ('смотрю', 'посмотрю'),
#  ('теряет', 'потеряет'),
#  ('чистим', 'почистаем'),
#  ('шли', 'пошли'),
#  ('попросила', 'просил'),
#  ('читать', 'прочитать'),
#  ('бужу', 'разбужу'),
#  ('сердились', 'рассердились'),
#  ('делает', 'сделает'),
#  ('делать', 'сделать'),
#  ('дeлать', 'Сделать'),
#  ('делать', 'сделать'),
#  ('делать', 'сделать'),
#  ('делаю', 'сделаю'),
#  ('делаю', 'сделаю'),
#  ('делают', 'сделают'),
#  ('могла', 'смог'),
#  ('формулирует', 'сформулирует'),
#  ('видел', 'увидел'),
#  ('пошёл', 'шёл'),
#  ('кричит', 'крикнует'),
#  ('подчеркивает', 'подчеркнет'),
#  ('подчеркивает', 'подчеркнует'),
#  ('забудет', 'забывает'),
#  ('забыли', 'забывали'),
#  ('задать', 'задавать'),
#  ('сдают', 'задают'),
#  ('издала', 'издавала'),
#  ('оделся', 'одевался'),
#  ('мыть', 'помыть'),
#  ('подумай', 'думай'),
#  ('Позвони', 'Звони'),
#  ('Постарайтесь', 'Старайтесь'),
#  ('посчитайте ', 'считайте'),
#  ('пошлите', 'посылайте'),
#  ('станете', 'становите'),
#  ('зассказала', 'рассказывала'),
#  ('вдадимся', 'вдаваемся'),
#  ('смогут', 'могут понимать'),
#  ('сможем', 'можем'),
#  ('сможем', 'можем'),
#  ('сможем', 'можем'),
#  ('сможет', 'может'),
#  ('понять', 'понимает'),
#  ('показаться', 'показываться'),
#  ('сажать', 'посадить'),
#  ('может', 'сможет'),
#  ('прийти', 'приходит'),
#  ('выключать', 'выключить'),
#  ('идти', 'пойти'),
#  ('читать', 'прочитать'),
#  ('поговорить', 'говорит'),
#  ('поговорить', 'говорит'),
#  ('понравиться', 'нравятся'),
#  ('нарисовал', 'рисовал'),
#  ('делает', 'сделает'),
#  ('слышать', 'услышать'),
#  ('вскакивает', 'выскочит'),
#  ('допустите', 'допускайте'),
#  ('исчезнет', 'исчезает'),
#  ('кончится', 'кончает'),
#  ('наступит', 'наступает'),
#  ('обмениваемся', 'обменяемся'),
#  ('поднимаюсь', 'поднимусь'),
#  ('получишь', 'получаешь'),
#  ('получить', 'получат'),
#  ('получить', 'получат'),
#  ('получили', 'получают'),
#  ('помогут', 'помогают'),
#  ('принимайте', 'примите'),
#  ('продолжите', 'продолжаете'),
#  ('продолжу', 'продолжаю'),
#  ('рассказывает', 'расскажет'),
#  ('решу', 'решаю'),
#  ('состоит', 'составляется'),
#  ('они справятся', 'справляются'),
#  ('сбережём', 'бережём'),
#  ('увидеть', 'видит'),
#  ('вспоминает', 'вспомнит'),
#  ('встаю', 'встану'),
#  ('встаю', 'встану'),
#  ('встану', 'встаю'),
#  ('выигрывает', 'выиграет'),
#  ('высказываю', 'выскажу'),
#  ('поговорим', 'говорим'),
#  ('гулять', 'гуляют'),
#  ('сделает', 'делает'),
#  ('сделают', 'делает'),
#  ('подумайте', 'думаете'),
#  ('думайте', 'думаете'),
#  ('заканчивается', 'закончится'),
#  ('зарабатываю', 'заработаю'),
#  ('пойдем', 'идём'),
#  ('окончат', 'кончат'),
#  ('покупаю', 'куплю'),
#  ('покупаю', 'куплю'),
#  ('покупают', 'купят'),
#  ('покупают', 'купят'),
#  ('покупают', 'купят'),
#  ('смогу', 'могу'),
#  ('смогу', 'могу'),
#  ('смогу', 'могу'),
#  ('смогут', 'могут'),
#  ('сможем', 'можем'),
#  ('сможем', 'можем'),
#  ('сможет', 'может'),
#  ('сможет', 'может'),
#  ('сможете', 'можете'),
#  ('оказывают наибольшее влияние', 'наиболее   влияние   окажут'),
#  ('напоминает', 'напомнит'),
#  ('оказываются', 'окажутся'),
#  ('напишу', 'опишу'),
#  ('опаздываю', 'опоздаю'),
#  ('опаздываю.', 'опоздаю.'),
#  ('оспаривает', 'оспорит'),
#  ('открывается', 'откроется'),
#  ('открываю', 'открою'),
#  ('перестают', 'перестанут'),
#  ('дарят', 'подарят,'),
#  ('показывают', 'покажут'),
#  ('приодевается', 'приоденется'),
#  ('проигрывает', 'проиграет'),
#  ('поработаю', 'работаю'),
#  ('разрабатывают', 'разработают'),
#  ('рассказываю', 'расскажу'),
#  ('делает', 'сделает'),
#  ('смешиваются,', 'смешаются'),
#  ('спрашивает', 'спросит'),
#  ('спрашивайте', 'спросите.'),
#  ('спрашиваю', 'спрошу'),
#  ('постараюсь', 'стараюсь'),
#  ('Потанцуем,', 'Танцуем'),
#  ('Потанцуем?', 'Танцуем'),
#  ('Потанцуем, ', 'Танцуем,'),
#  ('сумеешь', 'умеешь'),
#  ('успевает', 'успеет'),
#  ('успеваю', 'успею'),
#  ('успеваю', 'успею'),
#  ('успеваю', 'успею'),
#  ('захотят', 'хотят'),
#  ('захочет', 'хочет'),
#  ('захочу', 'хочу'),
#  ('почувствуете', 'чувствуете'),
#  ('помогает', 'поможет'),
#  ('помогает', 'поможет'),
#  ('помогают коже.', 'поможет   кожи.'),
#  ('возьму', 'беру'),
#  ('возвращается', 'вернется'),
#  ('возвращается', 'вернётся'),
#  ('возвращается', 'вернётся'),
#  ('возвращается', 'вернуется'),
#  ('возвращаюсь', 'вернусь'),
#  ('возвращаются', 'вернутся'),
#  ('возвращаюсь', 'вернуюсь'),
#  ('возвращаюсь', 'вернуюсь'),
#  ('входят', 'воидут'),
#  ('выбегаем', 'выбежим'),
#  ('выезжает', 'выедет'),
#  ('выезжаю', 'выеду'),
#  ('выходит', 'выидет'),
#  ('выходят', 'выйдут'),
#  ('подходит', 'доидет'),
#  ('ложусь', 'лягу'),
#  ('находит', 'найдет'),
#  ('находит', 'найдёт'),
#  ('находите', 'найдёте'),
#  ('нахожу', 'найду'),
#  ('нахожу', 'найду'),
#  ('нахожу', 'найду'),
#  ('обходит', 'обоидет'),
#  ('отбегает', 'отбежит'),
#  ('подходят', 'подойдут'),
#  ('кладет', 'положит'),
#  ('предлагает', 'предложит'),
#  ('приходят', 'придёт'),
#  ('приезжает', 'приедет'),
#  ('приезжает', 'приедет'),
#  ('приезжает', 'приедет'),
#  ('приезжают', 'приедут'),
#  ('приходит', 'приидёт'),
#  ('приходит.', 'приидёт'),
#  ('прихожу', 'прииду'),
#  ('приходят', 'приидут'),
#  ('приходят', 'прийдут'),
#  ('приносят', 'принесут'),
#  ('принесет', 'приносит'),
#  ('придёт', 'приходит'),
#  ('проезжают', 'проедут'),
#  ('сбегают', 'сбегут'),
#  ('говорят', 'скажут'),
#  ('становятся', 'станут'),
#  ('становятся', 'станут'),
#  ('становятся', 'станут'),
#  (' убегает', 'убежит'),
#  ('уезжают', 'уедут'),
#  ('уходит.', 'уидёт'),
#  ('уходит', 'уидёт'),
#  ('уходит', 'уидёт.'),
#  ('падает', 'упадёт'),
#  ('падает', 'упает'),
#  ('уйдет', 'уходит'),
#  ('начнём', 'начинаем'),
#  ('начали', 'начинает'),
#  ('бросает', 'бросит'),
#  ('включает', 'включит'),
#  ('вспоминает', 'вспомнит'),
#  ('встречаемся', 'встретимся'),
#  ('встречаемся', 'встретимся'),
#  ('встречаемся', 'встретимся'),
#  ('встречаемся', 'встретимся'),
#  ('встречают', 'встретят'),
#  ('договариваются', 'договорятся'),
#  ('изучает', 'изучит'),
#  ('кончает', 'кончит'),
#  ('кончается', 'кончится'),
#  ('облегчает', 'облегчит'),
#  ('обращают', 'обратят'),
#  ('обращают', 'обратят'),
#  ('объясняет', 'обьяснит'),
#  ('отражает', 'отразят'),
#  (', отражает', 'отразят'),
#  ('говорит', 'поговорит'),
#  ('готовят', 'подготовят'),
#  ('позволяли', 'позволят'),
#  ('предъявляют', 'предъявят'),
#  ('приближается', 'приблизится'),
#  ('приглашают', 'пригласят'),
#  ('приготовля́ют', 'приготовлят'),
#  ('решает', 'решит'),
#  ('решает ', 'решит'),
#  ('решают', 'решят'),
#  ('совершают', 'совершят'),
#  ('сообщает', 'сообщит'),
#  ('видят', 'удивят'),
#  ('видят', 'удивят'),
#  ('расскажите', 'Рассказывайте'),
#  ('расскажу', 'рассказываю'),
#  ('спросим', 'спрашиваем'),
#  ('спросят', 'спрашивают'),
#  ('спросите', 'срашаваете'),
#  ('обнимемся', 'обнимаем'),
#  ('моется', 'вымоется'),
#  ('заболевают', 'заболят'),
#  ('позаботимся', 'заботимся'),
#  ('смеются', 'засмеются'),
#  ('пишет', 'напишит'),
#  ('учат', 'научат'),
#  ('характеризует', 'охарактеризует'),
#  ('обедаю', 'победаю'),
#  ('кому верите ', 'поверите'),
#  ('говорить', 'поговорить'),
#  ('гулять', 'погулять'),
#  ('думал', 'подумал'),
#  ('посещать', 'поетить'),
#  ('жили.', 'пожили'),
#  ('идет', 'пойдет'),
#  ('идет', 'пойдёт'),
#  ('иду', 'пойду'),
#  ('иду', 'пойду'),
#  ('иду', 'пойду'),
#  ('идут', 'пойдут'),
#  ('идут', 'поидят'),
#  ('идти', 'пойти'),
#  ('купила', 'покупала'),
#  ('купить', 'покупать'),
#  ('пытался', 'попытался'),
#  ('служат', 'послужат'),
#  ('старались', 'постарались'),
#  ('стараюсь', 'постараюсь'),
#  ('строил', 'построил'),
#  ('строилось', 'построилось'),
#  ('теряют', 'потеряют'),
#  ('толстеют', 'потолстают'),
#  ('учиться', 'поучиться'),
#  ('хвалить', 'похвалить'),
#  ('себя чувствую', 'почувствую'),
#  ('шла', 'пошла'),
#  ('являлась', 'появилась'),
#  ('делал', 'сделал'),
#  ('делают', 'сделают'),
#  ('делают', 'сделают'),
#  ('садиться', 'сесть'),
#  ('кручу', 'скручу'),
#  ('могут', 'смогут'),
#  ('лгут', 'солгут'),
#  ('видел', 'увидел'),
#  ('поужинали', 'ужинали'),
#  ('отдыхаю', 'отдохну'),
#  ('отдыхаю', 'отдохну'),
#  ('отдыхать', 'отдохнуть'),
#  ('упоминали', 'упомянули'),
#  ('встала', 'бстабала'),
#  ('забывать', 'забыть'),
#  ('оденутся', 'одеваются'),
#  ('останется', 'остаётся'),
#  ('перегреться', 'перегреваться'),
#  ('узнаете', 'узнаёте'),
#  ('дала', 'давала'),
#  ('смогла', 'могла'),
#  ('мог бы пойти', 'он мог бы идти'),
#  ('посмотреть', 'смотреть'),
#  ('прочитать', 'читать'),
#  ('ограничить', 'ограничивать'),
#  ('делать', 'сделать'),
#  ('спасать', 'спасти'),
#  ('задать', 'задавать'),
#  ('страдать', 'пострадать'),
#  ('делать', 'сделать'),
#  ('встретить', 'встречать'),
#  ('захотела', 'хотела'),
#  ('захотели', 'хотели'),
#  ('прочитать', 'читать'),
#  ('прочитать', 'читать'),
#  ('сосредоточиться', 'сосредоточиваться'),
#  ('мешать', 'помешать'),
#  ('попробовать', 'пробовать'),
#  ('проверил', 'проверял'),
#  ('сварила', 'варила'),
#  ('помыла', 'мыла'),
#  ('помогали', 'помогли'),
#  ('собралась', 'собиралась'),
#  ('прочитать', 'читать'),
#  ('дать', 'давать'),
#  ('бросил', 'бросал'),
#  ('встретил', 'встречал'),
#  ('встретил', 'встречал'),
#  ('встретила', 'встречала'),
#  ('встретила', 'встречала'),
#  ('встретила', 'встречала'),
#  ('встретила', 'встречали'),
#  ('выросло', 'вырастало'),
#  ('достиг', 'достигал'),
#  ('достигли', 'достигали'),
#  ('достигли', 'достигали'),
#  ('заключил', 'заключал'),
#  ('заметил', 'замечал'),
#  ('заметил', 'замечал'),
#  ('заметила', 'замечала'),
#  ('я заметила', 'замечала'),
#  ('защищали', 'защитили'),
#  ('изобрели', 'изобретали'),
#  ('исчезли', 'исчезали'),
#  ('называли', 'назвали'),
#  ('объяснила,', 'объясняла'),
#  ('объяснила', 'обясняла'),
#  ('отказывался', 'оказался'),
#  ('казалось', 'показалось'),
#  ('получил', 'получал'),
#  ('помогла', 'помогал'),
#  ('помогла', 'помогала'),
#  ('помогли', 'помогали'),
#  ('помогло', 'помогало'),
#  ('понимала', 'понила'),
#  ('понимал', 'понял'),
#  ('понимала', 'поняла'),
#  ('понимали', 'поняли'),
#  ('поразил', 'поражал'),
#  ('поступила', 'поступала'),
#  ('поступила', 'поступала'),
#  ('появлялись', 'появились'),
#  ('предложил', 'предлагал'),
#  ('предложила', 'предлагала.'),
#  ('предложили', 'предлагали'),
#  ('предпочли', 'предпочитали'),
#  ('предложил', 'предупреждал'),
#  ('переступила', 'преступала'),
#  ('привлекло', 'привлекало'),
#  ('прилетел', 'прилетал'),
#  ('принимал', 'принял'),
#  ('продолжил', 'продолжал'),
#  ('продолжил', 'продолжал'),
#  ('продолжил', 'продолжал'),
#  ('продолжил', 'продолжал'),
#  ('продолжил', 'продолжал'),
#  ('продолжила обучение', 'продолжала'),
#  ('продолжили', 'продолжали'),
#  ('разрешил', 'разрешал'),
#  ('рассказывала', 'рассказала'),
#  ('решили', 'решали'),
#  ('сообщила', 'сообщала'),
#  ('справили', 'справляли'),
#  ('уверил', 'уверял'),
#  ('поужинала', 'ужинала'),
#  ('уменьшилось', 'уменьшалось'),
#  ('ухудшил', 'ухудшал'),
#  ('арестовывали', 'арестовали'),
#  ('поблагодврила', 'благодарила'),
#  ('побывал', 'бывал'),
#  ('побывали', 'бывали'),
#  ('увидел', 'видел'),
#  ('увидела', 'видела'),
#  ('увидела', 'видела'),
#  ('увидели', 'видели'),
#  ('увидели', 'видели'),
#  ('увидели', 'видели'),
#  ('увидели', 'видели'),
#  ('повлиял', 'влиял'),
#  ('повлиял', 'влиял'),
#  ('повлиял', 'влиял'),
#  ('повлияла', 'влияла'),
#  ('повлияла', 'влияла'),
#  ('повлияла', 'влияла'),
#  ('повлияли', 'влияли'),
#  ('своровал', 'воровал'),
#  ('воспитывала', 'воспитала'),
#  ('воспитывали', 'воспитали'),
#  ('выбирали', 'выбрали'),
#  ('выбирали', 'выбрали'),
#  ('поговорили', 'говорили'),
#  ('проголосовал', 'голосовал'),
#  ('проголосовал', 'голосовал'),
#  ('давал', 'дал'),
#  ('сделал', 'делал'),
#  ('сделал', 'делал'),
#  ('сделал', 'делал'),
#  ('сделала', 'делала'),
#  ('продиктовала', 'диктировала'),
#  ('договаривались', 'договорились'),
#  ('подумал', 'думал'),
#  ('подумала', 'думала'),
#  ('обдумала', 'думала'),
#  ('подумала', 'думала'),
#  ('подумала', 'думала'),
#  ('подумали', 'думали'),
#  ('пожалел', 'жалел'),
#  ('пожалела', 'жалела'),
#  ('пожелал', 'желал'),
#  ('прожил', 'жил'),
#  ('прожил', 'жил'),
#  ('прожила', 'жила'),
#  ('прожила', 'жила'),
#  ('прожила.', 'жила'),
#  ('позавтракал', 'завтракал'),
#  ('задавать', 'задать'),
#  ('заканчивали', 'закончили'),
#  ('заканчивалось', 'закончилось'),
#  ('позвонил', 'звонил'),
#  ('позвонил', 'звонил'),
#  ('позвонили', 'звонили'),
#  ('отзвонились', 'звонили'),
#  ('познакомилась', 'знакомилась'),
#  ('познакомился', 'знакомился'),
#  ('узнали', 'знали'),
#  ('заинтересовалась', 'интересовалась'),
#  ('заинтересовались', 'интересовались'),
#  ('показалось', 'казалась'),
#  ('показалось', 'казалась'),
#  ('оказалось,', 'казалось,'),
#  ('покупал', 'купил'),
#  ('покупала', 'купила'),
#  ('покушали', 'кушали'),
#  ('поменял', 'менял'),
#  ('смогла', 'могла'),
#  ('смогла', 'могла'),
#  ('вымыл', 'мыл'),
#  ('помыл', 'мыл'),
#  ('называли', 'назвали'),
#  ('унаследовал', 'наследовал'),
#  ('начинал', 'начал'),
#  ('начинала', 'начала'),
#  ('начинали', 'начали'),
#  ('понравился', 'нравился'),
#  ('понравился', 'нравился'),
#  ('понравился', 'нравился'),
#  ('понравились', 'нравился'),
#  ('одевалась', 'оделась'),
#  ('оказывалось,', 'оказалась'),
#  ('опаздывал', 'опаздал'),
#  ('описывали', 'описали'),
#  ('осознавал', 'осознал'),
#  ('открылся', 'открывался'),
#  ('попарился', 'парился'),
#  ('переставала', 'перестала'),
#  ('написал', 'писал'),
#  ('написал', 'писал'),
#  ('написал', 'писал'),
#  ('написал', 'писал'),
#  ('написал', 'писал'),
#  ('написал', 'писал'),
#  ('написала', 'писала'),
#  ('показывал', 'показал'),
#  ('показывали', 'показали'),
#  ('посылал', 'послал'),
#  ('придумывали', 'придумали'),
#  ('признавали', 'признали'),
#  ('признавали,', 'признали'),
#  ('продавала', 'продала'),
#  ('продавали', 'продали'),
#  ('попросил', 'просил'),
#  ('попросила', 'просила'),
#  ('попросила', 'просили'),
#  ('испугалась', 'пугалась'),
#  ('раздавали', 'раздали'),
#  ('сдавали', 'сдали'),
#  ('сдавали', 'сдали'),
#  ('сдавали', 'сдали'),
#  ('рассердилась', 'сердилась'),
#  ('послужила', 'служила'),
#  ('услышала', 'слышала'),
#  ('услышала,', 'слышала'),
#  ('услышали', 'слышали'),
#  ('посмотрел', 'смотрел'),
#  ('посмотрел', 'смотрел'),
#  ('посмотрел', 'смотрел'),
#  ('поспал', 'спал'),
#  ('спрашивают', 'спросил'),
#  ('пострадали', 'страдали'),
#  ('утекла', 'текла'),
#  ('потратили', 'тратили'),
#  ('потребовалось', 'требовалось'),
#  ('убивали', 'убили'),
#  ('убивали ', 'убили'),
#  ('поужинал', 'ужинал'),
#  ('поужинал', 'ужинал'),
#  ('знала', 'узнала'),
#  ('умирал', 'умерли'),
#  ('успевала', 'успела'),
#  ('выучила', 'учила'),
#  ('научилась', 'училась'),
#  ('научили', 'учили'),
#  ('сформировались', 'формировались'),
#  ('похвалил', 'хвалил'),
#  ('похвастался', 'хвалился'),
#  ('захотелось', 'хотелось'),
#  ('почитал', 'читал'),
#  ('прочитал', 'читал'),
#  ('прочитала', 'читала'),
#  ('прочитать', 'читать'),
#  ('прочитать', 'читать'),
#  ('почувствовала', 'чувствовала'),
#  ('пошли', 'шли'),
#  ('сэкономило', 'экономило'),
#  ('помогал', 'помог'),
#  ('брали', 'взяли'),
#  ('вела', 'водила'),
#  ('вошел', 'входил'),
#  ('вошло', 'входил'),
#  ('вышел', 'выходил'),
#  ('вышел', 'выходил'),
#  ('выходил', 'вышел'),
#  ('догнала', 'догоняла'),
#  ('изгнали', 'изгоняли'),
#  ('изгнали', 'изгоняли'),
#  ...]

# %%
all_text = [char for src, tgt in pairs for char in src + tgt]
chars = sorted(set(all_text))
char2idx = {c: i+4 for i, c in enumerate(chars)}
char2idx["<PAD>"] = 0
char2idx["<SOS>"] = 1
char2idx["<EOS>"] = 2
char2idx["<UNK>"] = 3
idx2char = {i: c for c, i in char2idx.items()}
vocab_size = len(char2idx)

# %%
class VerbPairDataset(Dataset):
    def __init__(self, pairs, char2idx, max_len=20):
        self.pairs = pairs
        self.char2idx = char2idx
        self.max_len = max_len

    def encode(self, word, add_sos=False):
        seq = [char2idx.get(c, char2idx["<UNK>"]) for c in word]
        if add_sos:
            seq = [char2idx["<SOS>"]] + seq
        seq = seq + [char2idx["<EOS>"]]
        seq += [char2idx["<PAD>"]] * (self.max_len - len(seq))
        return seq[:self.max_len]

    def __len__(self):
        return len(self.pairs)

    def __getitem__(self, idx):
        src, tgt = self.pairs[idx]
        src_encoded = self.encode(src)
        tgt_encoded = self.encode(tgt, add_sos=True)
        return torch.tensor(src_encoded), torch.tensor(tgt_encoded)

# %%
class Encoder(nn.Module):
    def __init__(self, vocab_size, emb_dim, hidden_dim):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, emb_dim)
        self.lstm = nn.LSTM(emb_dim, hidden_dim, batch_first=True)

    def forward(self, x):
        embedded = self.embedding(x)
        outputs, (hidden, cell) = self.lstm(embedded)
        return hidden, cell


class Decoder(nn.Module):
    def __init__(self, vocab_size, emb_dim, hidden_dim):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, emb_dim)
        self.lstm = nn.LSTM(emb_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, vocab_size)

    def forward(self, x, hidden, cell):
        x = x.unsqueeze(1)
        embedded = self.embedding(x)
        output, (hidden, cell) = self.lstm(embedded, (hidden, cell))
        prediction = self.fc(output.squeeze(1))
        return prediction, hidden, cell

# %%
def train_seq2seq(encoder, decoder, dataloader, epochs=20, teacher_forcing_ratio=0.5):
    criterion = nn.CrossEntropyLoss(ignore_index=char2idx["<PAD>"])
    enc_opt = optim.Adam(encoder.parameters(), lr=0.001)
    dec_opt = optim.Adam(decoder.parameters(), lr=0.001)

    for epoch in range(epochs):
        total_loss = 0
        for src, tgt in dataloader:
            enc_opt.zero_grad()
            dec_opt.zero_grad()
            hidden, cell = encoder(src)
            input_token = tgt[:, 0]
            loss = 0
            for t in range(1, tgt.shape[1]):
                output, hidden, cell = decoder(input_token, hidden, cell)
                loss += criterion(output, tgt[:, t])
                teacher_force = random.random() < teacher_forcing_ratio
                top1 = output.argmax(1)
                input_token = tgt[:, t] if teacher_force else top1
            loss.backward()
            enc_opt.step()
            dec_opt.step()
            total_loss += loss.item() / tgt.shape[1]
        print(f"Epoch {epoch+1}, Loss: {total_loss / len(dataloader):.4f}")

# %%
def predict(encoder, decoder, word, max_len=20):
    with torch.no_grad():
        encoder.eval()
        decoder.eval()
        input_seq = torch.tensor([dataset.encode(word)], dtype=torch.long)
        hidden, cell = encoder(input_seq)
        input_token = torch.tensor([char2idx["<SOS>"]])
        output_seq = []

        for _ in range(max_len):
            output, hidden, cell = decoder(input_token, hidden, cell)
            top1 = output.argmax(1)
            if top1.item() == char2idx["<EOS>"]:
                break
            output_seq.append(idx2char[top1.item()])
            input_token = top1

        return "".join(output_seq)

# %%
dataset = VerbPairDataset(pairs, char2idx)
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

encoder = Encoder(vocab_size, emb_dim=64, hidden_dim=128)
decoder = Decoder(vocab_size, emb_dim=64, hidden_dim=128)

train_seq2seq(encoder, decoder, dataloader, epochs=30)

# Test
# Out:
# Epoch 1, Loss: nan
# Epoch 2, Loss: nan
# Epoch 3, Loss: nan
# Epoch 4, Loss: nan
# Epoch 5, Loss: nan
# Epoch 6, Loss: nan
# Epoch 7, Loss: nan
# Epoch 8, Loss: nan
# Epoch 9, Loss: nan
# Epoch 10, Loss: nan
# Epoch 11, Loss: nan
# Epoch 12, Loss: nan
# Epoch 13, Loss: nan
# Epoch 14, Loss: nan
# Epoch 15, Loss: nan
# Epoch 16, Loss: nan
# Epoch 17, Loss: nan
# Epoch 18, Loss: nan
# Epoch 19, Loss: nan
# Epoch 20, Loss: nan
# Epoch 21, Loss: nan
# Epoch 22, Loss: nan
# Epoch 23, Loss: nan
# Epoch 24, Loss: nan
# Epoch 25, Loss: nan
# Epoch 26, Loss: nan
# Epoch 27, Loss: nan
# Epoch 28, Loss: nan
# Epoch 29, Loss: nan
# Epoch 30, Loss: nan

# %%
df["learner_pred"] = df["teacher"].apply(lambda word: predict(encoder, decoder, word))

# %%
df
# Out:
#                 teacher         learner    learner_pred
# 0                помочь        помогать        помогать
# 1        злоупотреблять   злоупотребить    злогробовать
# 2                 пойти            идти            идти
# 3     проконтролировать  контролировать  контролировать
# 4              покупать          купить          купить
# ...                 ...             ...             ...
# 1220               дать          давать          давать
# 1221         переоделся    переодевался     перегововал
# 1222              сдать         сдавать         сдавать
# 1223              сдают         сдавают        садавают
# 1224               дала          давала         одавала
#
# [1225 rows x 3 columns]

# %%
df["is_correct"] = df["learner_pred"] == df["learner"]
accuracy = df["is_correct"].mean()
print(f"Exact match accuracy: {accuracy:.2f}")
# Out:
# Exact match accuracy: 0.85

# %%
import nltk
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
import editdistance

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/toni/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
smoothie = SmoothingFunction().method4

def compute_metrics(row):
    pred = row["learner_pred"]
    truth = row["learner"]

    # Exact match
    is_exact = pred == truth

    # Edit distance
    edit_dist = editdistance.eval(pred, truth)

    # Character accuracy
    max_len = max(len(pred), len(truth))
    char_acc = 1 - (edit_dist / max_len) if max_len > 0 else 1.0

    # BLEU score (character-level)
    bleu = sentence_bleu(
        [list(truth)], list(pred), weights=(1, 0, 0, 0), smoothing_function=smoothie
    )

    return pd.Series([is_exact, edit_dist, char_acc, bleu],
                     index=["is_exact", "edit_distance", "char_accuracy", "bleu"])

# %%
df[["is_exact", "edit_distance", "char_accuracy", "bleu"]] = df.apply(compute_metrics, axis=1)

# %%
print("Exact Match Accuracy:", df["is_exact"].mean())
print("Average Edit Distance:", df["edit_distance"].mean())
print("Average Character Accuracy:", df["char_accuracy"].mean())
print("Average BLEU Score:", df["bleu"].mean())
# Out:
# Exact Match Accuracy: 0.8473469387755102
# Average Edit Distance: 0.33714285714285713
# Average Character Accuracy: 0.9619764324866367
# Average BLEU Score: 0.9656201616996661

# %%
import pandas as pd

# Show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# To avoid cutting off wide content
pd.set_option('display.max_colwidth', None)


df
# Out:
#                   imp            perf                            eng  \
# 0      бегать, бежать        побежать                  to run, hurry
# 1      бегать, бежать        побежать                  to run, hurry
# 2                бить          побить                   to beat, hit
# 3              болеть        заболеть         to be ill; be a fan of
# 4            бороться      побороться             to struggle, fight
# 5             бояться       забояться             to be afraid, fear
# 6               брать           взять                  to take; rent
# 7             браться         взяться        to set about, undertake
# 8             бросать         бросить                       to throw
# 9           бросаться       броситься         to throw oneself, rush
# 10             валить         свалить                  to fell, dump
# 11             валять         свалять                 to roll, shape
# 12             варить         сварить                  to boil, cook
# 13      возить, везти         повезти     to drive, carry by vehicle
# 14             велеть        повелеть             to order (someone)
# 15             верить        поверить                     to believe
# 16         возвращать         вернуть           to return, give back
# 17       возвращаться       вернуться           to return (yourself)
# 18      водить, вести         повести              to lead (walking)
# 19        волноваться   взволноваться            to worry, get upset
# 20          взглянуть     взглядывать                to look, glance
# 21          взглянуть     взглядывать                to look, glance
# 22           вздыхать       вздохнуть        to take breath, to sigh
# 23              брать           взять                  to take; rent
# 24            браться         взяться        to set about, undertake
# 25           вздыхать       вздохнуть        to take breath, to sigh
# 26             видеть         увидеть                         to see
# 27             висеть        повисеть                        to hang
# 28           включать        включить       to include; to switch on
# 29           включать        включить       to include; to switch on
# 30      водить, вести         повести              to lead (walking)
# 31            воевать       повоевать              to fight (in war)
# 32       возвращаться    возвратиться                      to return
# 33         возвращать         вернуть           to return, give back
# 34       возвращаться    возвратиться            to return (oneself)
# 35      возить, везти         повезти     to drive, carry by vehicle
# 36      возить, везти         повезти     to drive, carry by vehicle
# 37          возникать      возникнуть              to emerge, appear
# 38          возникать      возникнуть              to emerge, appear
# 39          возражать       возразить            to object, disagree
# 40          возражать       возразить            to object, disagree
# 41            входить           войти              to enter, come in
# 42        волноваться   взволноваться            to worry, get upset
# 43         восклицать     воскликнуть                to exclaim, cry
# 44         восклицать     воскликнуть                to exclaim, cry
# 45              врать         соврать              to lie, tell lies
# 46         вскакивать        вскочить               to jump, jump up
# 47         вскакивать        вскочить               to jump, jump up
# 48         вспоминать       вспомнить            to remember, recall
# 49         вспоминать       вспомнить            to remember, recall
# 50           вставать          встать      to get up, rise, stand up
# 51           вставать          встать      to get up, rise, stand up
# 52          встречать       встретить                        to meet
# 53        встречаться     встретиться       to meet, be found, occur
# 54          встречать       встретить                        to meet
# 55        встречаться     встретиться       to meet, be found, occur
# 56            входить           войти              to enter, come in
# 57           выбирать         выбрать              to choose, select
# 58           выбирать         выбрать              to choose, select
# 59           выводить         вывести          to take out, lead out
# 60           выводить         вывести          to take out, lead out
# 61           выдавать          выдать            to hand, distribute
# 62           выдавать          выдать            to hand, distribute
# 63        выдерживать       выдержать         to bear, stand, endure
# 64        выдерживать       выдержать         to bear, stand, endure
# 65           вызывать         вызвать                  to call, send
# 66           вызывать         вызвать                  to call, send
# 67           выходить           выйти               to go out; nurse
# 68           вынимать          вынуть           to take out, extract
# 69           вынимать          вынуть           to take out, extract
# 70           выпивать          выпить                   to get drunk
# 71           выпивать          выпить                       to drink
# 72               пить          выпить                       to drink
# 73          выполнять       выполнить          to carry out, execute
# 74          выполнять       выполнить          to carry out, execute
# 75          выпускать       выпустить          to let out, discharge
# 76          выпускать       выпустить          to let out, discharge
# 77          вырастать         вырасти                     to grow up
# 78          вырастать         вырасти                     to grow up
# 79        выскакивать       выскочить           to jump out, pop out
# 80        выскакивать       выскочить           to jump out, pop out
# 81          выступать       выступить        to come forward, appear
# 82          выступать       выступить        to come forward, appear
# 83        вытаскивать        вытащить           to take out, extract
# 84        вытаскивать        вытащить           to take out, extract
# 85             тянуть        вытянуть             to stretch, extend
# 86           выходить           выйти                      to go out
# 87            глядеть         глянуть             to look at, glance
# 88            глядеть         глянуть             to look at, glance
# 89           говорить         сказать            to say, speak, tell
# 90             гореть         сгореть                        to burn
# 91           готовить     приготовить               to prepare, cook
# 92             гулять        погулять                 to take a walk
# 93             давать            дать            to give; let, allow
# 94             дарить        подарить            to give (a present)
# 95             давать            дать            to give; let, allow
# 96            двигать         двинуть                        to move
# 97            двигать         двинуть                        to move
# 98        действовать   подействовать                         to act
# 99             делать         сделать                    to do, make
# 100          делаться       сделаться              to become, happen
# 101         добавлять        добавить                         to add
# 102         добавлять        добавить                         to add
# 103        добираться       добраться               to get to, reach
# 104        добираться       добраться               to get to, reach
# 105      догадываться      догадаться                       to guess
# 106      догадываться      догадаться                       to guess
# 107        дожидаться       дождаться                  to wait until
# 108        дожидаться       дождаться                  to wait until
# 109          доходить           дойти        to reach, get as far as
# 110         доставать         достать                       to prove
# 111        доказывать        доказать                       to prove
# 112         доставать         достать                 to get, obtain
# 113          доходить           дойти               to reach, arrive
# 114          доходить           дойти               to reach, arrive
# 115     ездить, ехать         поехать                 to ride, drive
# 116              есть          съесть                         to eat
# 117     ездить, ехать         поехать                 to ride, drive
# 118            жалеть        пожалеть            to feel sorry, ptty
# 119            жалить         ужалить                       to sting
# 120          жаловать      пожаловать               to grant, bestow
# 121             ждать       подождать                        to wait
# 122            желать        пожелать                        to wish
# 123          жениться      пожениться                       to marry
# 124          забирать         забрать                        pick up
# 125            болеть        заболеть       to get ill; become a fan
# 126          забирать         забрать                        pick up
# 127          забывать          забыть                      to forget
# 128          забывать          забыть                      to forget
# 129          заводить         завести              to bring, wind up
# 130          заводить         завести           to bring by, wind up
# 131       заглядывать       заглянуть             to peep in, glance
# 132       заглядывать       заглянуть             to peep in, glance
# 133      заговаривать      заговорить             to begin to speak,
# 134      заговаривать      заговорить             to begin to speak,
# 135      задумываться      задуматься                      to ponder
# 136      задумываться      задуматься                      to ponder
# 137  заинтересовывать  заинтересовать            to capture interest
# 138  заинтересовывать  заинтересовать            to capture interest
# 139          заходить           зайти        to drop in or by, visit
# 140       заканчивать       закончить       to end, finish, complete
# 141       заканчивать       закончить       to end, finish, complete
# 142           кричать       закричать              to shout, cry out
# 143         закрывать         закрыть             to close, cover up
# 144         закрывать         закрыть             to close, cover up
# 145        закуривать        закурить        to light up (a cigaret)
# 146        закуривать        закурить        to light up (a cigaret)
# 147          замирать        замереть           to stand still, stop
# 148          замечать        заметить         to notice, take a note
# 149          замечать        заметить          to notice, take notes
# 150          замирать        замереть           to stand still, stop
# 151         замолчать     замалчивать          to shut up, be silent
# 152         замолчать     замалчивать          to shut up, be silent
# 153          занимать          занять      to borrow; occupy; secure
# 154        заниматься        заняться         to be occupied, engage
# 155          занимать          занять              to borrow; occupy
# 156        заниматься        заняться        to be occupied, engaged
# 157             орать         заорать         to shout, scream, yell
# 158        записывать        записать           to note down, record
# 159        записывать        записать           to note down, record
# 160           платить       заплатить                         to pay
# 161        запоминать       запомнить          to memorize, remember
# 162        запоминать       запомнить          to memorize, remember
# 163        засмеивать        засмеять              to start laughing
# 164        засмеивать        засмеять              to start laughing
# 165       сомневаться   засомневаться             to doubt, hesitate
# 166        заставлять       заставить         to force, compel, make
# 167        заставлять       заставить         to force, compel, make
# 168       захватывать       захватить        to grab, seize, capture
# 169       захватывать       захватить        to grab, seize, capture
# 170          заходить           зайти        to drop in or by, visit
# 171            хотеть        захотеть                  to want, like
# 172          заявлять         заявить           to declare, announce
# 173          заявлять         заявить           to declare, announce
# 174             звать         позвать                        to call
# 175           звонить       позвонить           to call by telephone
# 176           звучать      прозвучать                 to sound, ring
# 177       знакомиться   познакомиться     to meet, get acquaintanted
# 178            играть         cыграть                        to play
# 179      ходить, идти           пойти                    to go, come
# 180          извинять        извинить              to excuse, pardon
# 181          извинять        извинить              to excuse, pardon
# 182          изменять        изменить                  to change, to
# 183        изменяться      измениться              to become changed
# 184          изменять        изменить                  to change, to
# 185        изменяться      измениться              to become changed
# 186            искать         сыскать            to search, look for
# 187        пользовать    использовать         to use, take advantage
# 188      пользоваться  использоваться                to use, be used
# 189          пугаться      испугаться     to be frightened, startled
# 190        испытывать        испытать                   to try, test
# 191        испытывать        испытать                   to try, test
# 192          исчезать       исчезнуть                   to disappear
# 193          исчезать       исчезнуть                   to disappear
# 194          казаться      показаться                to seem, appear
# 195          касаться       коснуться         to touch (on), concern
# 196            катить        покатить                        to roll
# 197            кивать         кивнуть                         to nod
# 198            кивать         кивнуть                         to nod
# 199            класть        положить             to lay down, place
# 200            колоть         уколоть                       to prick
# 201           кончать         кончить                         to end
# 202           кончать         кончить                         to end
# 203          касаться       коснуться         to touch (on), concern
# 204            косить         скосить                         to mow
# 205           костить        скостить    to abuse, reprimand angrily
# 206           кричать        крикнуть                  to cry, shout
# 207           кричать        крикнуть                  to cry, shout
# 208            купать          купить               to buy, purchase
# 209            купать          купить               to buy, purchase
# 210     лазить, лезть         полезть                to climb, go up
# 211     лазить, лезть         полезть                to climb, go up
# 212    летать, лететь        полететь                         to fly
# 213    летять, лететь        полететь                         to fly
# 214          ложиться            лечь                    to lie down
# 215            ловить         поймать                       to catch
# 216          ложиться            лечь                    to lie down
# 217            махать         махнуть         to wave, flap, flutter
# 218            махать         махнуть         to wave, flap, flutter
# 219            менять        поменять            to change, exchange
# 220            мешать        помешать     to interfere, prevent; mix
# 221              мочь           смочь                     to be able
# 222         надоедать        надоесть        to bore, bother, pester
# 223         надоедать        надоесть        to bore, bother, pester
# 224          называть         назвать                  to call, name
# 225        называться       назваться                to call oneself
# 226         назначать       назначить          to assign, allot, fix
# 227         назначать       назначить          to assign, allot, fix
# 228          называть         назвать                  to call, name
# 229        называться       назваться                to call oneself
# 230          находить           найти              to find, discover
# 231        находиться         найтись           to be found, located
# 232            писать        написать                       to write
# 233        напоминать       напомнить            to remind, resemble
# 234        напоминать       напомнить            to remind, resemble
# 235        направлять       направить           to direct, aim, send
# 236      направляться     направиться                to head towards
# 237        направлять       направить           to direct, aim, send
# 238      направляться     направиться                to head towards
# 239           следить       наследить          to watch, spy, follow
# 240         наступать       наступить                step on, attack
# 241         наступать       наступить                step on, attack
# 242             учить         научить                       to teach
# 243           учиться       научиться                to study, learn
# 244          находить           найти              to find, discover
# 245        находиться         найтись           to be found, located
# 246          начинать          начать           to begin (something)
# 247        начинаться        начаться                       to begin
# 248          начинать          начать           to begin (something)
# 249        начинаться        начаться                       to begin
# 250     носить, нести         понести                       to carry
# 251     носить, нести         понести                 to carry, wear
# 252         нравиться     понравиться                      to please
# 253     оборачиваться      обернуться         to turn out, result in
# 254           обещать       пообещать                     to promise
# 255      обнаруживать      обнаружить            to reveal, discover
# 256      обнаруживать      обнаружить            to reveal, discover
# 257        обходиться        обойтись                to cost, manage
# 258     оборачиваться      обернуться         to turn out, result in
# 259        радоваться    обрадоваться              to be glad, happy
# 260          обращать        обратить                     to turn to
# 261        обращаться      обратиться             to appeal, address
# 262          обращать        обратить                     to turn to
# 263        обращаться      обратиться             to appeal, address
# 264        обходиться        обойтись                to cost, manage
# 265         объявлять        объявить           to declare, announce
# 266         объявлять        объявить           to declare, announce
# 267         объяснять       объяснить                     to explain
# 268         объяснять       объяснить                     to explain
# 269      оглядываться      оглянуться                 to look around
# 270      оглядываться      оглянуться                 to look around
# 271       оказываться       оказаться          find oneself, turn up
# 272       оказываться       оказаться          find oneself, turn up
# 273        определять      определить           to define, determine
# 274        определять      определить           to define, determine
# 275          опускать        опустить                 put down, omit
# 276          опускать        опустить                 put down, omit
# 277             орать         заорать               to shout, scream
# 278        оставаться        остаться                to remain, stay
# 279         оставлять        оставить              to leave, abandon
# 280         оставлять        оставить              to leave, abandon
# 281     останавливать      остановить                        to stop
# 282   останавливаться    остановиться              to stop (oneself)
# 283     останавливать      остановить                        to stop
# 284   останавливаться    остановиться              to stop (oneself)
# 285        оставаться        остаться                to remain, stay
# 286          отвечать        ответить               to answer, reply
# 287          отвечать        ответить               to answer, reply
# 288          отдавать          отдать                   to give back
# 289          отдавать          отдать                   to give back
# 290      отказываться      отказаться             to decline, reject
# 291      отказываться      отказаться             to decline, reject
# 292         открывать         открыть                        to open
# 293       открываться       открыться         to open, come to light
# 294         открывать         открыть                        to open
# 295       открываться       открыться         to open, come to light
# 296          отличать        отличить                 to distinguish
# 297          отличать        отличить                 to distinguish
# 298          отмечать        отметить                  to mark, note
# 299          отмечать        отметить                  to mark, note
# 300        относиться       отнестись          to treat, relate (to)
# 301        относиться       отнестись          to treat, regard (to)
# 302          отходить          отойти          go away (from), leave
# 303        отправлять       отправить                    to send off
# 304      отправляться     отправиться             to set off, depart
# 305        отправлять       отправить                    to send off
# 306      отправляться     отправиться             to set off, depart
# 307         отпускать       отпустить             to let go, release
# 308         отпускать       отпустить             to let go, release
# 309          отходить          отойти          go away (from), leave
# 310           ощущать         ощутить                 to feel, sense
# 311           ощущать         ощутить                 to feel, sense
# 312            падать          упасть                        to fall
# 313            пахать         пахнуть                  to smell (of)
# 314            пахать         пахнуть                  to smell (of)
# 315        переводить       перевести         to transfer, translate
# 316        переводить       перевести         to transfer, translate
# 317        передавать        передать           to pass on, transmit
# 318        передавать        передать           to pass on, transmit
# 319        переходить         перейти                  to cross over
# 320       переставать       перестать                 to stop, cease
# 321       переставать       перестать                 to stop, cease
# 322        переходить         перейти                  to cross over
# 323              петь           спеть                        to sing
# 324            писать        написать                       to write
# 325              пить          выпить                       to drink
# 326    плавать, плыть         поплыть           to swim, float, sail
# 327           плакать       поплакать                         to cry
# 328           платить       заплатить                         to pay
# 329    плавать, плыть         поплыть           to swim, float, sail
# 330    бегать, бежать        побежать                  to run, hurry
# 331            валить        повалить                  to fell, dump
# 332     возить, везти         повезти     to drive, carry by vehicle
# 333            велеть        повелеть             to order (someone)
# 334            верить        поверить                     to believe
# 335      поворачивать       повернуть            to turn (something)
# 336    поворачиваться     повернуться              to turn (oneself)
# 337     водить, вести         повести              to lead (walking)
# 338            висеть        повисеть                        to hang
# 339           воевать       повоевать              to fight (in war)
# 340      поворачивать       повернуть            to turn (something)
# 341    поворачиваться     повернуться              to turn (oneself)
# 342         повторять       повторить                      to repeat
# 343         повторять       повторить                      to repeat
# 344          погибать       погибнуть           to perish, be killed
# 345          погибать       погибнуть           to perish, be killed
# 346           глядеть       поглядеть                  to look, gaze
# 347            гулять        погулять                 to take a walk
# 348          подавать          подать                 to give, serve
# 349            дарить        подарить            to give (a present)
# 350          подавать          подать                 to give, serve
# 351       действовать   подействовать                         to act
# 352         поднимать         поднять                 to lift, raise
# 353       подниматься       подняться                 to rise, climb
# 354         поднимать         поднять                 to lift, raise
# 355       подниматься       подняться                 to rise, climb
# 356             ждать       подождать                        to wait
# 357         подходить         подойти        to approach, come up to
# 358      подтверждать     подтвердить                     to confirm
# 359      подтверждать     подтвердить                     to confirm
# 360         подходить         подойти        to approach, come up to
# 361     ездить, ехать         поехать                 to ride, drive
# 362            жалеть        пожалеть            to feel sorry, pity
# 363          жаловать      пожаловать               to grant, bestow
# 364          пожимать          пожать              to press, to reap
# 365            желать        пожелать                        to wish
# 366          жениться      пожениться                       to marry
# 367          пожимать          пожать              to press, to reap
# 368             звать         позвать                        to call
# 369         позволять       позволить               to allow, permit
# 370         позволять       позволить               to allow, permit
# 371           звонить       позвонить           to call by telephone
# 372       знакомиться   познакомиться        to meet, get acquainted
# 373          поиграть      поигрывать               to play a little
# 374      ходить, идти           пойти                    to go, come
# 375        показывать        показать               to show, display
# 376          казаться      показаться                to seem, appear
# 377      показываться      показаться                      to appear
# 378        показывать        показать               to show, display
# 379      показываться      показаться                      to appear
# 380            катить        покатить                 to drive, roll
# 381         покрывать         покрыть                       to cover
# 382         покрывать         покрыть                       to cover
# 383          покупать          купить               to buy, purchase
# 384          полагать        положить              to suppose, think
# 385     лазить, лезть         полезть                to climb, go up
# 386    летять, лететь        полететь                         to fly
# 387            класть        положить             to lay down, place
# 388          полагать        положить              to suppose, think
# 389          получать        получить                 to receve, get
# 390        получаться      получиться                    to turn out
# 391          получать        получить                 to receve, get
# 392        получаться      получиться                    to turn out
# 393        пользовать    использовать         to use, take advantage
# 394      пользоваться  использоваться                to use, be used
# 395            менять        поменять            to change, exchange
# 396           мечтать       помечтать                       to dream
# 397            мешать        помешать              to interfere; mix
# 398          помогать          помочь                        to help
# 399           молчать       помолчать                   to be silent
# 400          помогать          помочь                        to help
# 401     носить, нести         понести                       to carry
# 402          понимать          понять                  to understand
# 403         нравиться     понравиться                      to please
# 404          понимать          понять                     to realize
# 405           обещать       пообещать                     to promise
# 406          попадать         попасть                 to hit, end up
# 407          попадать         попасть                 to hit, end up
# 408    плавать, плыть         поплыть           to swim, float, sail
# 409         пробовать     попробовать                   to try, text
# 410           просить       попросить                      to ask to
# 411          пытаться      попытаться                         to try
# 412          поражать        поразить             to startle, strike
# 413          поражать        поразить             to startle, strike
# 414            садить        посадить                       to plant
# 415          посылать         послать              to send, dispatch
# 416             слать         послать                        to send
# 417         следовать     последовать                      to follow
# 418           служить       послужить                       to serve
# 419           слушать       послушать                      to listen
# 420          смеяться      посмеяться                       to laugh
# 421          смотреть      посмотреть                 to look, watch
# 422           спешить       поспешить                       to hurry
# 423           спорить       поспорить              to argue, dispute
# 424           ставить       поставить      to put, place (something)
# 425         стараться     постараться                         to try
# 426         поступать       поступить                 to enter, join
# 427         поступать       поступить                 to enter, join
# 428           считать       посчитать             to count, consider
# 429         считаться     посчитаться         to consider, settle up
# 430          посылать         послать              to send, dispatch
# 431           терпеть       потерпеть                    to tolerate
# 432            терять        потерять                        to lose
# 433        торопиться    поторопиться                       to hurry
# 434         требовать     потребовать                      to demand
# 435       требоваться   потребоваться                   to be needed
# 436            тянуть        потянуть                  to pull, draw
# 437       чувствовать   почувствовать                        to feel
# 438        появляться       появиться             to appear, show up
# 439        появляться       появиться             to appear, show up
# 440      превращаться    превратиться                   to turn into
# 441      превращаться    превратиться                   to turn into
# 442        предлагать      предложить              to offer, suggest
# 443        предлагать      предложить              to offer, suggest
# 444      представлять     представить          to present, introduce
# 445      представлять     представить          to present, introduce
# 446      приближаться    приблизиться              to approach, near
# 447      приближаться    приблизиться              to approach, near
# 448         прибывать         прибыть                to arrive, come
# 449         прибывать         прибыть                to arrive, come
# 450         привозить        привезти            to bring by vehicle
# 451         приводить        привести                       to bring
# 452         приводить        привести                       to bring
# 453         привозить        привезти            to bring by vehicle
# 454         привыкать      привыкнуть                 to get used to
# 455         привыкать      привыкнуть                 to get used to
# 456        приглашать      пригласить                      to invite
# 457        приглашать      пригласить                      to invite
# 458          готовить     приготовить               to prepare, cook
# 459       придумывать       придумать               to think, invent
# 460       придумывать       придумать               to think, invent
# 461         приезжать        приехать           to arrive by vehicle
# 462         приезжать        приехать           to arrive by vehicle
# 463        признавать        признать            to recognize, admit
# 464      признаваться      признаться              to confess, admit
# 465        признавать        признать            to recognize, admit
# 466      признаваться      признаться              to confess, admit
# 467         приходить          прийти                to come, arrive
# 468       приходиться        прийтись                to fit; have to
# 469       приказывать       приказать              to order, command
# 470       приказывать       приказать              to order, command
# 471        прикрывать        прикрыть              to cover, conceal
# 472        прикрывать        прикрыть              to cover, conceal
# 473      принадлежать    принадлежить                      to belong
# 474      принадлежать    принадлежить                      to belong
# 475         приносить        принести                       to bring
# 476         принимать         принять                to take, accept
# 477       приниматься       приняться            to begin, set about
# 478         приносить        принести                       to bring
# 479         принимать         принять                to take, accept
# 480       приниматься       приняться            to begin, set about
# 481         присылать        прислать                        to send
# 482         присылать        прислать                        to send
# 483         приходить          прийти                to come, arrive
# 484       приходиться        прийтись               to have to, must
# 485         пробовать     попробовать                         to try
# 486         проверять       проверить               to check, verify
# 487         проверять       проверить               to check, verify
# 488         проводить        провести          to accompany; conduct
# 489         проводить        провести          to accompany; conduct
# 490     проговаривать     проговорить                to talk through
# 491     проговаривать     проговорить                to talk through
# 492         продавать         продать                        to sell
# 493         продавать         продать                        to sell
# 494        продолжать      продолжить                    to continue
# 495        продолжать      продолжить                    to continue
# 496         проживать         прожить                 to live, spend
# 497         проживать         прожить                 to live, spend
# 498           звучать      прозвучать                 to sound, ring
# 499       производить      произвести                     to produce
# 500       производить      произвести                     to produce
# 501       произносить      произнести            to pronounce, utter
# 502       произносить      произнести            to pronounce, utter
# 503       происходить       произойти               to happen, occur
# 504       происходить       произойти               to happen, occur
# 505         проходить          пройти        to pass, go by, be over
# 506         пропадать        пропасть           to disappear, vanish
# 507         пропадать        пропасть           to disappear, vanich
# 508           просить       попросить                      to ask to
# 509       просыпаться      проснуться                     to wake up
# 510           прощать        простить                     to forgive
# 511       просыпаться      проснуться                     to wake up
# 512         протянуть     протягивать             to stretch, extend
# 513         протянуть     протягивать             to stretch, extend
# 514         проходить          пройти        to pass, go by, be over
# 515            читать        прочесть                        to read
# 516            читать       прочитать                        to read
# 517           прощать        простить                     to forgive
# 518           прыгать        прыгнуть          to jump, leap, bounce
# 519           прыгать        прыгнуть          to jump, leap, bounce
# 520          пугаться      испугаться     to be frightened, startled
# 521           пускать         пустить  to let, allow, permit, let in
# 522           пускать         пустить  to let, allow, permit, let in
# 523          пытаться      попытаться                         to try
# 524        радоваться    обрадоваться              to be glad, happy
# 525       разбираться     разобраться        to disassemble, examine
# 526      разглядывать      разглядеть                     to examine
# 527      разглядывать      разглядеть                     to examine
# 528       раздаваться       раздаться                     to resound
# 529       раздаваться       раздаться                     to resound
# 530       разбираться     разобраться        to disassemble, examine
# 531         разрешать       разрешить               to allow, permit
# 532         разрешать       разрешить               to allow, permit
# 533      рассказывать      рассказать               to tell, narrate
# 534      рассказывать      рассказать               to tell, narrate
# 535     рассматривать     рассмотреть           to examine, consider
# 536     рассматривать     рассмотреть           to examine, consider
# 537             расти         вырасти                        to grow
# 538            решать          решить               to decide, solve
# 539            решать          решить               to decide, solve
# 540         рождаться        родиться                     to be born
# 541         рождаться        родиться                     to be born
# 542            садить        посадить                       to plant
# 543          садиться           сесть              to sit down or up
# 544            валить         свалить                  to fell, dump
# 545            валять         свалять                 to roll, shape
# 546            варить         сварить                  to boil, cook
# 547            гореть         сгореть                        to burn
# 548            делать         сделать                    to do, make
# 549          делаться       сделаться              to become, happen
# 550          садиться           сесть              to sit down or up
# 551          говорить         сказать                  to say, speak
# 552            косить         скосить                         to mow
# 553           костить        скостить            to abuse, reprimand
# 554          скрывать          скрыть               to hide, conceal
# 555          скрывать          скрыть               to hide, conceal
# 556             слать         послать                        to send
# 557           следить       наследить          to watch, spy, follow
# 558         следовать     последовать           to follow, come next
# 559           служить       послужить                       to serve
# 560         случаться       случиться                      to happen
# 561         случаться       случиться                      to happen
# 562           слушать       послушать                      to listen
# 563           слышать        услышать                        to hear
# 564          смеяться      засмеяться                       to laugh
# 565          смотреть      посмотреть                 to look, watch
# 566              мочь           смочь                     to be able
# 567           снимать           снять        to take off; photograph
# 568           снимать           снять        to take off; photograph
# 569          собирать         собрать             to gather, collect
# 570        собираться       собраться        to gather; to get ready
# 571          собирать         собрать             to gather, collect
# 572        собираться       собраться        to gather; to get ready
# 573            совать          сунуть         to stick, poke, thrust
# 574         совершать       совершить          to accomplish, commit
# 575         совершать       совершить          to accomplish, commit
# 576             врать         соврать                         to lie
# 577       соглашаться     согласиться              to agree, consent
# 578       соглашаться     согласиться              to agree, consent
# 579         создавать         создать                      to create
# 580         создавать         создать                      to create
# 581           сходить           сойти             to go or come down
# 582          сообщать        сообщить              to report, convey
# 583          сообщать        сообщить              to report, convey
# 584        составлять       составить       to put together, compose
# 585        составлять       составить       to put together, compose
# 586           спадать          спасть            to fall down, abate
# 587           спасать          спасти                to save, rescue
# 588           спасать          спасти                to save, rescue
# 589           спадать          спасть            to fall down, abate
# 590             спать         поспать                       to sleep
# 591              петь           спеть                        to sing
# 592           спешить       поспешить                       to hurry
# 593           спорить       поспорить              to argue, dispute
# 594        спрашивать        спросить                to ask, inquire
# 595        спрашивать        спросить                to ask, inquire
# 596        спускаться      спуститься          to come down, descend
# 597        спускаться      спуститься          to come down, descend
# 598           ставить       поставить      to put, stand (something)
# 599       становиться           стать         to become, begin, come
# 600         стараться     постараться              to try, endeavour
# 601       становиться           стать         to become, begin, come
# 602            стоять        постоять                       to stand
# 603          страдать      пострадать                      to suffer
# 604          стрелять      выстрелить                       to shoot
# 605        стремиться     устремиться                to rush, strive
# 606           строить       построить      to build, make, construct
# 607           стучать       постучать           to tap, knock, pound
# 608            судить        посудить                  to judge, try
# 609             уметь          суметь                     to be able
# 610            совать          сунуть         to stick, poke, thrust
# 611        схватывать        схватить         to seize, grasp, catch
# 612        схватывать        схватить         to seize, grasp, catch
# 613           сходить           сойти             to go or come down
# 614           считать       посчитать             to count, consider
# 615         считаться     посчитаться         to consider, settle up
# 616              есть          съесть                         to eat
# 617            играть         сыграть                        to play
# 618            искать         сыскать            to search, look for
# 619           таскать          тащить                  to pull, drag
# 620           таскать          тащить                  to pull, drag
# 621           терпеть       потерпеть                    to tolerate
# 622            терять        потерять                        to lose
# 623        торопиться    поторопиться                       to hurry
# 624           торчать         торчить         to protrude, stick out
# 625           торчать         торчить         to protrude, stick out
# 626         требовать     потребовать                      to demand
# 627       требоваться   потребоваться                   to be needed
# 628            тянуть         вытянут             to stretch, extend
# 629        убеждаться       убедиться                to be convinced
# 630        убеждаться       убедиться                to be convinced
# 631           убивать           убить                        to kill
# 632           убивать           убить                        to kill
# 633            видеть         увидеть                         to see
# 634         удаваться         удаться                succeed, manage
# 635           ударять         ударить                 to strike, hit
# 636           ударять         ударить                 to strike, hit
# 637         удаваться         удаться                succeed, manage
# 638        удивляться       удивиться                to be surprised
# 639        удивляться       удивиться                to be surprised
# 640           уезжать          уехать            to leave by vehicle
# 641           уезжать          уехать            to leave by vehicle
# 642            жалить         ужалить                       to sting
# 643           уходить            уйти              to leave, go away
# 644            колоть         уколоть                       to prick
# 645         улыбаться      улыбнуться                       to smile
# 646         улыбаться      улыбнуться                       to smile
# 647           умирать         умереть                         to die
# 648             уметь          суметь                     to be able
# 649           умирать         умереть                         to die
# 650            падать          упасть                        to fall
# 651           слышать        услышать                        to hear
# 652        усмехаться     усмехнуться        to laugh slightly, grin
# 653        усмехаться     усмехнуться        to laugh slightly, grin
# 654          успевать          успеть         to be on time, succeed
# 655          успевать          успеть         to be on time, succeed
# 656       успокоиться   успокаиваться                   to calm down
# 657       успокоиться   успокаиваться                   to calm down
# 658          уставать          устать                   to get tired
# 659     устанавливать      установить              to install, mount
# 660     устанавливать      установить              to install, mount
# 661          уставать          устать                   to get tired
# 662        устраивать        устроить            to arrange, to make
# 663        устраивать        устроить            to arrange, to make
# 664        утверждать       утвердить             to affirm, confirm
# ...
# 610          сунуть        True      True              0       1.000000
# 611        схватить        True      True              0       1.000000
# 612        схватить        True      True              0       1.000000
# 613           сойти        True      True              0       1.000000
# 614       посчитать        True      True              0       1.000000
# 615     посчитаться        True      True              0       1.000000
# 616          съесть        True      True              0       1.000000
# 617         сыграть        True      True              0       1.000000
# 618         сыскать        True      True              0       1.000000
# 619          тащить        True      True              0       1.000000
# 620          тащить        True      True              0       1.000000
# 621       потерпеть        True      True              0       1.000000
# 622        потерять        True      True              0       1.000000
# 623    поторопиться        True      True              0       1.000000
# 624         торчить        True      True              0       1.000000
# 625         торчить        True      True              0       1.000000
# 626     потребовать        True      True              0       1.000000
# 627   потребоваться        True      True              0       1.000000
# 628        потянуть       False     False              3       0.625000
# 629       убедиться        True      True              0       1.000000
# 630       убедиться        True      True              0       1.000000
# 631           убить        True      True              0       1.000000
# 632           убить        True      True              0       1.000000
# 633          подать       False     False              4       0.428571
# 634         удаться        True      True              0       1.000000
# 635         ударить        True      True              0       1.000000
# 636         ударить        True      True              0       1.000000
# 637         удаться        True      True              0       1.000000
# 638       удивиться        True      True              0       1.000000
# 639       удивиться        True      True              0       1.000000
# 640          уехать        True      True              0       1.000000
# 641          уехать        True      True              0       1.000000
# 642         ужалить        True      True              0       1.000000
# 643            уйти        True      True              0       1.000000
# 644         уколоть        True      True              0       1.000000
# 645      улыбнуться        True      True              0       1.000000
# 646      улыбнуться        True      True              0       1.000000
# 647         умереть        True      True              0       1.000000
# 648          суметь        True      True              0       1.000000
# 649         умереть        True      True              0       1.000000
# 650          упасть        True      True              0       1.000000
# 651          услыть       False     False              2       0.750000
# 652     усмехнуться        True      True              0       1.000000
# 653     усмехнуться        True      True              0       1.000000
# 654          успеть        True      True              0       1.000000
# 655          успеть        True      True              0       1.000000
# 656   успокаиваться        True      True              0       1.000000
# 657   успокаиваться        True      True              0       1.000000
# 658          устать        True      True              0       1.000000
# 659      установить        True      True              0       1.000000
# 660      установить        True      True              0       1.000000
# 661          устать        True      True              0       1.000000
# 662        устроить        True      True              0       1.000000
# 663        устроить        True      True              0       1.000000
# 664       утвердить        True      True              0       1.000000
# 665       утвердить        True      True              0       1.000000
# 666            уйти        True      True              0       1.000000
# 667         научить        True      True              0       1.000000
# 668       научиться        True      True              0       1.000000
# 669         хватить        True      True              0       1.000000
# 670         хватить        True      True              0       1.000000
# 671           пойти        True      True              0       1.000000
# 672        захотеть        True      True              0       1.000000
# 673        прочесть        True      True              0       1.000000
# 674        прочесть       False     False              3       0.666667
# 675   почувствовать        True      True              0       1.000000
# 676         явиться        True      True              0       1.000000
# 677         явиться        True      True              0       1.000000
#
#          bleu
# 0    1.000000
# 1    1.000000
# 2    1.000000
# 3    1.000000
# 4    1.000000
# 5    1.000000
# 6    1.000000
# 7    1.000000
# 8    1.000000
# 9    1.000000
# 10   1.000000
# 11   1.000000
# 12   1.000000
# 13   1.000000
# 14   1.000000
# 15   1.000000
# 16   0.400000
# 17   0.583333
# 18   1.000000
# 19   1.000000
# 20   1.000000
# 21   1.000000
# 22   1.000000
# 23   1.000000
# 24   1.000000
# 25   1.000000
# 26   0.423241
# 27   1.000000
# 28   1.000000
# 29   1.000000
# 30   1.000000
# 31   1.000000
# 32   0.916667
# 33   0.400000
# 34   0.916667
# 35   1.000000
# 36   1.000000
# 37   1.000000
# 38   1.000000
# 39   1.000000
# 40   1.000000
# 41   1.000000
# 42   1.000000
# 43   1.000000
# 44   1.000000
# 45   1.000000
# 46   0.750000
# 47   0.750000
# 48   1.000000
# 49   1.000000
# 50   1.000000
# 51   1.000000
# 52   1.000000
# 53   1.000000
# 54   1.000000
# 55   1.000000
# 56   1.000000
# 57   1.000000
# 58   1.000000
# 59   1.000000
# 60   1.000000
# 61   1.000000
# 62   1.000000
# 63   1.000000
# 64   1.000000
# 65   1.000000
# 66   1.000000
# 67   1.000000
# 68   1.000000
# 69   1.000000
# 70   1.000000
# 71   1.000000
# 72   1.000000
# 73   1.000000
# 74   1.000000
# 75   1.000000
# 76   1.000000
# 77   1.000000
# 78   1.000000
# 79   1.000000
# 80   1.000000
# 81   1.000000
# 82   1.000000
# 83   1.000000
# 84   1.000000
# 85   0.750000
# 86   1.000000
# 87   0.564321
# 88   0.564321
# 89   1.000000
# 90   1.000000
# 91   1.000000
# 92   1.000000
# 93   1.000000
# 94   0.716531
# 95   1.000000
# 96   1.000000
# 97   1.000000
# 98   1.000000
# 99   1.000000
# 100  1.000000
# 101  1.000000
# 102  1.000000
# 103  1.000000
# 104  1.000000
# 105  1.000000
# 106  1.000000
# 107  1.000000
# 108  1.000000
# 109  1.000000
# 110  1.000000
# 111  1.000000
# 112  1.000000
# 113  1.000000
# 114  1.000000
# 115  1.000000
# 116  1.000000
# 117  1.000000
# 118  1.000000
# 119  1.000000
# 120  1.000000
# 121  1.000000
# 122  1.000000
# 123  1.000000
# 124  1.000000
# 125  1.000000
# 126  1.000000
# 127  1.000000
# 128  1.000000
# 129  1.000000
# 130  1.000000
# 131  1.000000
# 132  1.000000
# 133  0.778801
# 134  0.778801
# 135  1.000000
# 136  1.000000
# 137  0.857143
# 138  0.857143
# 139  1.000000
# 140  1.000000
# 141  1.000000
# 142  0.551561
# 143  1.000000
# 144  1.000000
# 145  0.875000
# 146  0.875000
# 147  1.000000
# 148  1.000000
# 149  1.000000
# 150  1.000000
# 151  0.601378
# 152  0.601378
# 153  1.000000
# 154  1.000000
# 155  1.000000
# 156  1.000000
# 157  1.000000
# 158  1.000000
# 159  1.000000
# 160  1.000000
# 161  1.000000
# 162  1.000000
# 163  1.000000
# 164  1.000000
# 165  1.000000
# 166  1.000000
# 167  1.000000
# 168  1.000000
# 169  1.000000
# 170  1.000000
# 171  1.000000
# 172  1.000000
# 173  1.000000
# 174  1.000000
# 175  1.000000
# 176  1.000000
# 177  1.000000
# 178  0.857143
# 179  1.000000
# 180  1.000000
# 181  1.000000
# 182  1.000000
# 183  1.000000
# 184  1.000000
# 185  1.000000
# 186  1.000000
# 187  1.000000
# 188  1.000000
# 189  1.000000
# 190  1.000000
# 191  1.000000
# 192  1.000000
# 193  1.000000
# 194  1.000000
# 195  1.000000
# 196  1.000000
# 197  1.000000
# 198  1.000000
# 199  1.000000
# 200  1.000000
# 201  1.000000
# 202  1.000000
# 203  1.000000
# 204  1.000000
# 205  1.000000
# 206  1.000000
# 207  1.000000
# 208  1.000000
# 209  1.000000
# 210  1.000000
# 211  1.000000
# 212  1.000000
# 213  0.716531
# 214  1.000000
# 215  0.536256
# 216  1.000000
# 217  1.000000
# 218  1.000000
# 219  1.000000
# 220  1.000000
# 221  1.000000
# 222  1.000000
# 223  1.000000
# 224  1.000000
# 225  1.000000
# 226  1.000000
# 227  1.000000
# 228  1.000000
# 229  1.000000
# 230  1.000000
# 231  1.000000
# 232  1.000000
# 233  1.000000
# 234  1.000000
# 235  1.000000
# 236  1.000000
# 237  1.000000
# 238  1.000000
# 239  1.000000
# 240  1.000000
# 241  1.000000
# 242  1.000000
# 243  1.000000
# 244  1.000000
# 245  1.000000
# 246  1.000000
# 247  1.000000
# 248  1.000000
# 249  1.000000
# 250  1.000000
# 251  1.000000
# 252  1.000000
# 253  1.000000
# 254  1.000000
# 255  1.000000
# 256  1.000000
# 257  1.000000
# 258  1.000000
# 259  1.000000
# 260  1.000000
# 261  1.000000
# 262  1.000000
# 263  1.000000
# 264  1.000000
# 265  1.000000
# 266  1.000000
# 267  1.000000
# 268  1.000000
# 269  0.800000
# 270  0.800000
# 271  1.000000
# 272  1.000000
# 273  1.000000
# 274  1.000000
# 275  1.000000
# 276  1.000000
# 277  1.000000
# 278  1.000000
# 279  1.000000
# 280  1.000000
# 281  1.000000
# 282  1.000000
# 283  1.000000
# 284  1.000000
# 285  1.000000
# 286  0.750000
# 287  0.750000
# 288  1.000000
# 289  1.000000
# 290  1.000000
# 291  1.000000
# 292  1.000000
# 293  1.000000
# 294  1.000000
# 295  1.000000
# 296  1.000000
# 297  1.000000
# 298  1.000000
# 299  1.000000
# 300  1.000000
# 301  1.000000
# 302  1.000000
# 303  1.000000
# 304  1.000000
# 305  1.000000
# 306  1.000000
# 307  1.000000
# 308  1.000000
# 309  1.000000
# 310  1.000000
# 311  1.000000
# 312  1.000000
# 313  1.000000
# 314  1.000000
# 315  1.000000
# 316  1.000000
# 317  1.000000
# 318  1.000000
# 319  1.000000
# 320  1.000000
# 321  1.000000
# 322  1.000000
# 323  1.000000
# 324  1.000000
# 325  1.000000
# 326  1.000000
# 327  1.000000
# 328  1.000000
# 329  1.000000
# 330  1.000000
# 331  0.743038
# 332  1.000000
# 333  1.000000
# 334  1.000000
# 335  1.000000
# 336  1.000000
# 337  1.000000
# 338  1.000000
# 339  1.000000
# 340  1.000000
# 341  1.000000
# 342  1.000000
# 343  1.000000
# 344  1.000000
# 345  1.000000
# 346  0.606531
# 347  1.000000
# 348  1.000000
# 349  0.716531
# 350  1.000000
# 351  1.000000
# 352  1.000000
# 353  1.000000
# 354  1.000000
# 355  1.000000
# 356  1.000000
# 357  1.000000
# 358  1.000000
# 359  1.000000
# 360  1.000000
# 361  1.000000
# 362  1.000000
# 363  1.000000
# 364  1.000000
# 365  1.000000
# 366  1.000000
# 367  1.000000
# 368  1.000000
# 369  1.000000
# 370  1.000000
# 371  1.000000
# 372  1.000000
# 373  0.900000
# 374  1.000000
# 375  1.000000
# 376  1.000000
# 377  1.000000
# 378  1.000000
# 379  1.000000
# 380  1.000000
# 381  1.000000
# 382  1.000000
# 383  1.000000
# 384  1.000000
# 385  1.000000
# 386  0.716531
# 387  1.000000
# 388  1.000000
# 389  1.000000
# 390  0.900000
# 391  1.000000
# 392  0.900000
# 393  1.000000
# 394  1.000000
# 395  1.000000
# 396  0.777778
# 397  1.000000
# 398  1.000000
# 399  1.000000
# 400  1.000000
# 401  1.000000
# 402  1.000000
# 403  1.000000
# 404  1.000000
# 405  1.000000
# 406  1.000000
# 407  1.000000
# 408  1.000000
# 409  1.000000
# 410  1.000000
# 411  1.000000
# 412  1.000000
# 413  1.000000
# 414  1.000000
# 415  1.000000
# 416  1.000000
# 417  1.000000
# 418  0.751477
# 419  0.751477
# 420  1.000000
# 421  1.000000
# 422  1.000000
# 423  1.000000
# 424  1.000000
# 425  1.000000
# 426  1.000000
# 427  1.000000
# 428  1.000000
# 429  1.000000
# 430  1.000000
# 431  1.000000
# 432  1.000000
# 433  1.000000
# 434  1.000000
# 435  1.000000
# 436  1.000000
# 437  1.000000
# 438  1.000000
# 439  1.000000
# 440  1.000000
# 441  1.000000
# 442  1.000000
# 443  1.000000
# 444  1.000000
# 445  1.000000
# 446  0.818731
# 447  0.818731
# 448  1.000000
# 449  1.000000
# 450  1.000000
# 451  1.000000
# 452  1.000000
# 453  1.000000
# 454  0.596560
# 455  0.596560
# 456  1.000000
# 457  1.000000
# 458  1.000000
# 459  1.000000
# 460  1.000000
# 461  1.000000
# 462  1.000000
# 463  1.000000
# 464  1.000000
# 465  1.000000
# 466  1.000000
# 467  1.000000
# 468  1.000000
# 469  1.000000
# 470  1.000000
# 471  0.666667
# 472  0.666667
# 473  0.818731
# 474  0.818731
# 475  1.000000
# 476  1.000000
# 477  1.000000
# 478  1.000000
# 479  1.000000
# 480  1.000000
# 481  1.000000
# 482  1.000000
# 483  1.000000
# 484  1.000000
# 485  1.000000
# 486  1.000000
# 487  1.000000
# 488  1.000000
# 489  1.000000
# 490  1.000000
# 491  1.000000
# 492  1.000000
# 493  1.000000
# 494  1.000000
# 495  1.000000
# 496  1.000000
# 497  1.000000
# 498  1.000000
# 499  1.000000
# 500  1.000000
# 501  1.000000
# 502  1.000000
# 503  0.644123
# 504  0.644123
# 505  1.000000
# 506  1.000000
# 507  1.000000
# 508  1.000000
# 509  1.000000
# 510  1.000000
# 511  1.000000
# 512  1.000000
# 513  1.000000
# 514  1.000000
# 515  1.000000
# 516  0.661873
# 517  1.000000
# 518  1.000000
# 519  1.000000
# 520  1.000000
# 521  1.000000
# 522  1.000000
# 523  1.000000
# 524  1.000000
# 525  1.000000
# 526  1.000000
# 527  1.000000
# 528  1.000000
# 529  1.000000
# 530  1.000000
# 531  1.000000
# 532  1.000000
# 533  1.000000
# 534  1.000000
# 535  1.000000
# 536  1.000000
# 537  1.000000
# 538  1.000000
# 539  1.000000
# 540  1.000000
# 541  1.000000
# 542  1.000000
# 543  1.000000
# 544  1.000000
# 545  1.000000
# 546  1.000000
# 547  1.000000
# 548  1.000000
# 549  1.000000
# 550  1.000000
# 551  1.000000
# 552  1.000000
# 553  1.000000
# 554  1.000000
# 555  1.000000
# 556  1.000000
# 557  1.000000
# 558  1.000000
# 559  0.751477
# 560  1.000000
# 561  1.000000
# 562  0.751477
# 563  0.716531
# 564  0.800000
# 565  1.000000
# 566  1.000000
# 567  1.000000
# 568  1.000000
# 569  1.000000
# 570  1.000000
# 571  1.000000
# 572  1.000000
# 573  1.000000
# 574  1.000000
# 575  1.000000
# 576  1.000000
# 577  0.818182
# 578  0.818182
# 579  1.000000
# 580  1.000000
# 581  1.000000
# 582  1.000000
# 583  1.000000
# 584  1.000000
# 585  1.000000
# 586  1.000000
# 587  1.000000
# 588  1.000000
# 589  1.000000
# 590  1.000000
# 591  1.000000
# 592  1.000000
# 593  1.000000
# 594  1.000000
# 595  1.000000
# 596  1.000000
# 597  1.000000
# 598  1.000000
# 599  1.000000
# 600  1.000000
# 601  1.000000
# 602  0.875000
# 603  0.894839
# 604  1.000000
# 605  1.000000
# 606  1.000000
# 607  0.777778
# 608  0.875000
# 609  1.000000
# 610  1.000000
# 611  1.000000
# 612  1.000000
# 613  1.000000
# 614  1.000000
# 615  1.000000
# 616  1.000000
# 617  1.000000
# 618  1.000000
# 619  1.000000
# 620  1.000000
# 621  1.000000
# 622  1.000000
# 623  1.000000
# 624  1.000000
# 625  1.000000
# 626  1.000000
# 627  1.000000
# 628  0.625000
# 629  1.000000
# 630  1.000000
# 631  1.000000
# 632  1.000000
# 633  0.423241
# 634  1.000000
# 635  1.000000
# 636  1.000000
# 637  1.000000
# 638  1.000000
# 639  1.000000
# 640  1.000000
# 641  1.000000
# 642  1.000000
# 643  1.000000
# 644  1.000000
# 645  1.000000
# 646  1.000000
# 647  1.000000
# 648  1.000000
# 649  1.000000
# 650  1.000000
# 651  0.716531
# 652  1.000000
# 653  1.000000
# 654  1.000000
# 655  1.000000
# 656  1.000000
# 657  1.000000
# 658  1.000000
# 659  1.000000
# 660  1.000000
# 661  1.000000
# 662  1.000000
# 663  1.000000
# 664  1.000000
# 665  1.000000
# 666  1.000000
# 667  1.000000
# 668  1.000000
# 669  1.000000
# 670  1.000000
# 671  1.000000
# 672  1.000000
# 673  1.000000
# 674  0.661873
# 675  1.000000
# 676  1.000000
# 677  1.000000
