# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import random
import pandas as pd

# %%
data = pd.read_csv("teacher_learner.csv")
df = pd.DataFrame(data)

# %%
teacher = df["teacher"]
learner = df["learner"]

pairs = list(zip(teacher, learner))

# %%
pairs
# Out:
# [('помочь', 'помогать'),
#  ('злоупотреблять', 'злоупотребить'),
#  ('пойти', 'идти'),
#  ('проконтролировать', 'контролировать'),
#  ('покупать', 'купить'),
#  ('начинать', 'начать'),
#  ('передавать', 'передать'),
#  ('возвращаться', 'вернуться'),
#  ('приходить', 'прийти'),
#  ('выражать', 'выразить'),
#  ('разрушать', 'разрушить'),
#  ('уделять', 'удалить'),
#  ('достигнуть', 'достигать'),
#  ('заменить', 'заменять'),
#  ('заметить', 'замечать'),
#  ('пообщаться', 'общаться'),
#  ('оживить', 'оживлять'),
#  ('помочь', 'помогать'),
#  ('помочь', 'помогать'),
#  ('помочь', 'помогать'),
#  ('поступить', 'поступать'),
#  ('представить', 'представлять'),
#  ('принимать', 'принять'),
#  ('проверить', 'проверять'),
#  ('разуверить', 'разуверять'),
#  ('сократить', 'сокращать'),
#  ('улучшить', 'улучшать'),
#  ('уступить', 'уступать'),
#  ('увидеть', 'видеть'),
#  ('увидеть', 'видеть'),
#  ('увидеть', 'видеть'),
#  ('увидеть', 'видеть'),
#  ('поговорить', 'говорить'),
#  ('приготовить', 'готовить'),
#  ('сделать', 'делать'),
#  ('сделать', 'делать'),
#  ('сделать', 'делать'),
#  ('сделать', 'делать'),
#  ('сделать это', 'делать'),
#  ('подождать', 'ждать'),
#  ('пойти', 'идти'),
#  ('сконцентрироваться', 'концентрироваться'),
#  ('закончить', 'кончать'),
#  ('покупать', 'купить'),
#  ('покупать', 'купить'),
#  ('понять,', 'могут понимать'),
#  ('сможет работать', 'может работает'),
#  ('пообедать.', 'обедать'),
#  ('оставаться', 'остаться'),
#  ('написать', 'писать'),
#  ('написать', 'писать'),
#  ('выпить', 'пить'),
#  ('оплатить', 'платить'),
#  ('поддерживать', 'поддержaть'),
#  ('продавать', 'продать'),
#  ('попросить', 'просить'),
#  ('вырасти', 'раститься'),
#  ('связывать', 'связать'),
#  ('услышать', 'слышать'),
#  ('потрогать', 'трогать'),
#  ('убивать и наносить', 'убить и нанести'),
#  ('узнавать', 'узнать'),
#  ('охарактеризовать как', 'характеризовать'),
#  ('захотеть', 'хотеть'),
#  ('почувствовать', 'чувствовать'),
#  ('почувствовать', 'чуствовать'),
#  ('вернуться', 'возвращать'),
#  ('нанести', 'наносить'),
#  ('переезжать', 'переехать'),
#  ('прийти', 'приходить'),
#  ('прийти', 'приходить'),
#  ('прийти', 'приходить'),
#  ('проводить', 'провести'),
#  ('проводить', 'провести'),
#  ('произойти', 'происходить'),
#  ('стать', 'становить'),
#  ('убивать и наносить', 'убить и нанести'),
#  ('выбрать', 'выбирать'),
#  ('изменять', 'изменить'),
#  ('изменяться', 'измениться'),
#  ('изменить', 'изменрять'),
#  ('измениться', 'изменяться'),
#  ('получать', 'получить'),
#  ('проявляться', 'проявиться'),
#  ('решать', 'решить'),
#  ('решать', 'решить'),
#  ('оказаться', 'оказываться'),
#  ('отказаться', 'отказываться'),
#  ('открыть', 'открывать'),
#  ('показать', 'показывать'),
#  ('рассмотреть', 'рассматривать'),
#  ('понять', 'понимать'),
#  ('понять', 'понимать'),
#  ('понять', 'понимать'),
#  ('понять', 'понимать'),
#  ('понять', 'понимать'),
#  ('понять', 'понимать'),
#  ('понять', 'понимать'),
#  ('писать', 'написать'),
#  ('забыть', 'забывать'),
#  ('возникнуть', 'возникать'),
#  ('выдерживать', 'выдержать'),
#  ('ответить', 'отвечать'),
#  ('выбирать', 'выбрать'),
#  ('сделать', 'делать'),
#  ('забывать', 'забыть'),
#  ('записывать', 'записать'),
#  ('пойти', 'идти'),
#  ('покупать', 'купить'),
#  ('покупать', 'купить'),
#  ('помыть', 'мыть'),
#  ('называть', 'назвать'),
#  ('одеваться', 'одеться'),
#  ('написать', 'писать'),
#  ('придумывать', 'придумать'),
#  ('признать', 'признавать'),
#  ('узнавать', 'узнать'),
#  ('помогать', 'помочь'),
#  ('выезжать', 'выехать'),
#  ('перевести', 'переводить'),
#  ('говорить', 'сказать'),
#  ('сравнить', 'сравнивать'),
#  ('понять', 'понимать'),
#  ('писать', 'написать'),
#  ('нанимать', 'нанять'),
#  ('нанимать', 'нанять'),
#  ('обсудить', 'обсуждать'),
#  ('обсудить', 'обсуждать'),
#  ('отметить', 'отмечать'),
#  ('отступить', 'отступать'),
#  ('помочь', 'помогать'),
#  ('помочь.', 'помогать'),
#  ('поразить', 'поражать'),
#  ('прекратить', 'прекращать'),
#  ('принимать', 'принять'),
#  ('продолжить', 'продалжать'),
#  ('соединиться', 'соединяться'),
#  ('увидеть', 'видеть'),
#  ('увидеть', 'видеть'),
#  ('поговорить', 'говорить'),
#  ('сделать', 'делать'),
#  ('сделать', 'делать'),
#  ('поделиться', 'делиться'),
#  ('поиграть в', 'играть'),
#  ('покупать', 'купить'),
#  ('оставаться ', 'остаться'),
#  ('написать', 'писать'),
#  ('описать', 'писать'),
#  ('написать', 'писать'),
#  ('выпить', 'пить'),
#  ('показывать', 'показать'),
#  ('услышать', 'слышать'),
#  ('потанцевать,', 'танцевать'),
#  ('знать', 'узнать'),
#  ('поучаствовать', 'участвовать'),
#  ('вернуться', 'возвращаться'),
#  ('выходить', 'выйти'),
#  ('поймать', 'ловить'),
#  ('отдохнуть', 'отдыхать'),
#  ('отдохнуть', 'отдыхать'),
#  ('отдохнуть', 'отдыхать'),
#  ('отдохнуть', 'отдыхать'),
#  ('переезжать', 'переехать'),
#  ('переезжать', 'переехать'),
#  ('предложить', 'предлагать'),
#  ('проводить', 'провести'),
#  ('проводить', 'провести'),
#  ('проводить', 'провести'),
#  ('развестись', 'разводиться'),
#  ('говорить', 'сказать'),
#  ('стать', 'становиться'),
#  ('уезжать', 'уехать'),
#  ('решать', 'решить'),
#  ('окончить', 'оканчивать'),
#  ('описать', 'описывать'),
#  ('подчеркнуть', 'подчеркивать'),
#  ('подчеркнуть', 'подчёркивать'),
#  ('рассказать', 'рассказывать'),
#  ('спросить', 'спрашивать'),
#  ('увеличить', 'увеличивать'),
#  ('обнять', 'обнимать'),
#  ('понять,', 'понимать'),
#  ('понять,', 'понимать'),
#  ('съесть', 'есть'),
#  ('советовал', 'посоветовал'),
#  ('вспомнить', 'вспоминать'),
#  ('выразить', 'выражать'),
#  ('достичь', 'достигать'),
#  ('обсудить', 'обсуждать'),
#  ('оживить', 'оживлять'),
#  ('поднимать', 'поднять'),
#  ('помочь', 'помогать'),
#  ('помочь', 'помогать'),
#  ('помочь', 'помогать'),
#  ('поступить', 'поступать'),
#  ('привлечь', 'привлекать'),
#  ('решить', 'решать'),
#  ('спасти', 'спасать'),
#  ('укрепить', 'укреплять'),
#  ('уменьшить', 'уменьшать'),
#  ('увидеть ', 'ведеть'),
#  ('увидеть', 'видеть'),
#  ('увидеть', 'видеть'),
#  ('поговорить', 'говорить'),
#  ('подготовиться', 'готовиться'),
#  ('сделать', 'делать'),
#  ('сделать', 'делать'),
#  ('сделать', 'делать'),
#  ('сделать', 'делать'),
#  ('пожить', 'жить'),
#  ('покупать', 'купить'),
#  ('пообедать', 'обедать'),
#  ('заплатить', 'платить'),
#  ('попить', 'пыть'),
#  ('порадовать', 'радовать'),
#  ('развивать', 'развить'),
#  ('развивать', 'развить'),
#  ('отремонтировать.', 'ремонтировать'),
#  ('сдавать', 'сдать'),
#  ('услышать', 'слышать'),
#  ('знать', 'узнать'),
#  ('научить', 'учить'),
#  ('вернуться', 'возвращаться'),
#  ('выйти', 'выходить'),
#  ('избежать', 'избегать'),
#  ('изменять', 'изменить'),
#  ('оставлять', 'оставить'),
#  ('решать', 'решить'),
#  ('решать', 'решить'),
#  ('улучшать', 'улучшить'),
#  ('доказать', 'доказывать'),
#  ('заработать', 'зарабатывать'),
#  ('заняться', 'заниматься'),
#  ('понять', 'понимать'),
#  ('принять', 'принимать'),
#  ('смотреть', 'посмотреть'),
#  ('узнал', 'узнавал'),
#  ('включить', 'включать'),
#  ('возникла', 'возникала'),
#  ('воспринимать', 'воспринять'),
#  ('было бы вспомнить', 'вспоминать'),
#  ('выразить', 'выражать'),
#  ('выразить', 'выражать'),
#  ('выразить', 'выразать'),
#  ('достичь', 'достигать'),
#  ('достичь', 'достигать'),
#  ('достичь', 'достигать'),
#  ('Назначить', 'Назначать'),
#  ('обручились', 'обручались'),
#  ('обсудить', 'обсуждать'),
#  ('обсудить', 'обсуждать'),
#  ('обсудить', 'обсуждать'),
#  ('обсудить', 'обсуждать'),
#  ('обсудить', 'обсуждать'),
#  ('обсудить', 'обсуждать'),
#  ('объяснить', 'объяснять'),
#  ('определить', 'определять'),
#  ('определить', 'определять'),
#  ('отличиться от', 'отличатся'),
#  ('помочь', 'памагать'),
#  ('помочь', 'помогат'),
#  ('помочь', 'помогать'),
#  ('помочь', 'помогать'),
#  ('понимать', 'понять'),
#  ('посетить', 'посещать'),
#  ('посетить', 'посещать'),
#  ('пригласил', 'приглашал'),
#  ('принимать', 'принять'),
#  ('продолжить', 'продолжать'),
#  ('продолжил', 'продолжать'),
#  ('развлечься', 'развлекаться'),
#  ('согласиться', 'соглашаться'),
#  ('убедить', 'убеждать'),
#  ('убедят', 'убеждать'),
#  ('удерживается ', 'удержаться'),
#  ('ускорить', 'ускорять'),
#  ('забронировать', 'бронировать'),
#  ('увидеть', 'видеть'),
#  ('увидеть', 'видеть'),
#  ('вывешивать', 'вывесить'),
#  ('вызывать', 'вызвать'),
#  ('выкапывать', 'выкопать'),
#  ('высказывать', 'высказать'),
#  ('высказывать', 'высказать'),
#  ('поговорить', 'говорить'),
#  ('сказать', 'говорить'),
#  ('приготовить', 'готовить'),
#  ('погулять', 'гулять'),
#  ('сделать', 'делать'),
#  ('сделать', 'делать'),
#  ('сделать', 'делать'),
#  ('сделать', 'делать'),
#  ('сделать', 'делать'),
#  ('подружиться', 'дружиться'),
#  ('подумать', 'думать'),
#  ('подумать', 'думать'),
#  ('подумать', 'думать'),
#  ('пожениться', 'жениться'),
#  ('позавтракал', 'завтракал'),
#  ('позавтракала', 'завтракала'),
#  ('узнать', 'знать'),
#  ('узнать', 'знать'),
#  ('проконтролировать', 'контролировать'),
#  ('покупать', 'купить'),
#  ('покупать', 'купить'),
#  ('покупать', 'купить'),
#  ('покупать', 'купить'),
#  ('покупать', 'купить'),
#  ('покупать', 'купить'),
#  ('помыть', 'мыть'),
#  ('помыть', 'мыть'),
#  ('начинать', 'начать'),
#  ('пообедать', 'обедать'),
#  ('описывать', 'описать'),
#  ('описывать', 'описать'),
#  ('опаздывать', 'опоздать'),
#  ('осваивать', 'освоить'),
#  ('оставаться', 'остаться'),
#  ('оставаться ', 'остаться'),
#  ('оставаться ', 'остаться'),
#  ('открывать', 'открыть'),
#  ('открывать', 'открыть'),
#  ('переписывать', 'переписать'),
#  ('напечатать', 'печатать'),
#  ('напечатать', 'печатать'),
#  ('написать', 'писать'),
#  ('прерывать', 'прервать'),
#  ('придумывать', 'придумать'),
#  ('попросить', 'просить'),
#  ('попутешествовать', 'путешествовать'),
#  ('попыталась', 'пыталась'),
#  ('попытаться', 'пытаться'),
#  ('развивать', 'развить'),
#  ('развивать', 'развить'),
#  ('сдавать', 'сдать'),
#  ('послушать', 'слушать'),
#  ('услышать то,', 'слышать'),
#  ('посмотреть', 'смотреть'),
#  ('Посмотрите', 'Смотрите'),
#  ('создавать', 'создать'),
#  ('создавать', 'создать'),
#  ('спрашивать.', 'спросить'),
#  ('спрашивать', 'спросить'),
#  ('спрашивать', 'спросить'),
#  ('постараться', 'стараться'),
#  ('потанцуем..."', 'танцевать'),
#  ('убивать', 'убить'),
#  ('узнавать', 'узнать'),
#  ('упаковывать', 'упаковать'),
#  ('устанавливать', 'установить'),
#  ('научить', 'учить'),
#  ('научитесь', 'учиться'),
#  ('сформировать', 'формировать'),
#  ('очистить', 'чистить'),
#  ('выбирать', 'выбрать'),
#  (' помочь ', 'помоготь'),
#  ('помогать', 'помочь'),
#  ('вложить', 'вкладывать'),
#  ('избежать', 'избегать'),
#  ('найти', 'находить'),
#  ('перевести', 'переводить'),
#  ('перевести.', 'переводить'),
#  ('попадать', 'попасть'),
#  ('послать', 'посылать'),
#  ('предложить', 'предлагать'),
#  ('приходит', 'прийти'),
#  ('приходит', 'прийти'),
#  ('провести', 'проводить'),
#  ('говорить', 'сказать'),
#  ('говорить', 'сказать'),
#  ('становиться', 'стать'),
#  ('становиться', 'стать'),
#  ('увозят', 'увести'),
#  ('уехать', 'уезжать'),
#  ('начать', 'начинать'),
#  ('начать', 'начинать'),
#  ('выбрать', 'выбирать'),
#  ('выбрать', 'выбирать'),
#  ('выбрать', 'выбирать'),
#  ('собрать', 'собирать'),
#  ('включать', 'включить'),
#  ('вспоминать', 'вспомнить'),
#  ('встречаться', 'встретиться'),
#  ('добавлять', 'добавить'),
#  ('добавлять', 'добавить'),
#  ('замечать', 'заметить'),
#  ('заставляют', 'заставят'),
#  ('изготовлять', 'изготовить'),
#  ('изменить', 'изменять'),
#  ('изучать', 'изучить'),
#  ('изучать', 'изучить'),
#  ('обращали', 'обратить'),
#  ('обсуждают', 'обсудить'),
#  ('объяснять', 'объяснить'),
#  ('объяснять', 'объяснить'),
#  ('определять', 'определить'),
#  ('оставляет', 'оставить'),
#  ('перемещаться', 'переместить'),
#  ('повторять', 'повторить'),
#  ('повторять', 'повторить'),
#  ('повторять', 'помнить'),
#  ('посвящать', 'посвятить'),
#  ('появляется', 'появится'),
#  ('приглашать', 'пригласить'),
#  ('примерять', 'примерить'),
#  ('разделять', 'разделить'),
#  ('расслабляется', 'расслабится'),
#  ('решать', 'решить'),
#  ('решает', 'решить'),
#  ('соединять', 'соединить'),
#  ('сохранять', 'сохранить'),
#  ('сохранять', 'сохранить'),
#  ('уверять', 'уверить'),
#  ('улучшать', 'улучшить'),
#  ('вызвали', 'вызывал'),
#  ('договориться', 'договариваться'),
#  ('закрыть', 'закрывать'),
#  ('назвать', 'называть'),
#  ('описать', 'описывать'),
#  ('описать', 'описывать'),
#  ('остановиться', 'останавливаться'),
#  ('поддержать', 'поддерживать'),
#  ('подпишет', 'подписывает'),
#  ('показать', 'показывать'),
#  ('показать, ', 'показывать'),
#  ('предсказать,', 'предсказывать'),
#  ('прервать', 'прерывать'),
#  ('расскажу', 'рассказиваю'),
#  ('рассмотреть', 'рассматрывать'),
#  ('спросить', 'спрашивать'),
#  ('увеличиться', 'увеличиваться'),
#  ('понять', 'понимать'),
#  ('понять', 'понимать'),
#  ('понять', 'понимать'),
#  ('понять', 'понимать'),
#  ('понять', 'понимать'),
#  ('понять', 'понимать'),
#  ('понять', 'понимать'),
#  ('понять', 'понимать'),
#  ('понять', 'понимать'),
#  ('принять', 'принимать'),
#  ('делать', 'cделать'),
#  ('съесть', 'есть'),
#  ('платить', 'заплатить'),
#  ('писать', 'написать'),
#  ('готовятся', 'подготовятся'),
#  ('думаю', 'подумаю'),
#  ('знакомятся', 'познакомятся'),
#  ('идут', 'поидёт'),
#  ('красят', 'покрасиют'),
#  ('мыть', 'помыть'),
#  ('нравились', 'понравилась'),
#  ('нравилось', 'понравилось'),
#  ('нравился', 'понравился'),
#  ('пытался', 'попытался'),
#  ('пытаются', 'попытаются'),
#  ('смотрела', 'посмотрела'),
#  ('смотрю', 'посмотрю'),
#  ('теряет', 'потеряет'),
#  ('чистим', 'почистаем'),
#  ('шли', 'пошли'),
#  ('попросила', 'просил'),
#  ('читать', 'прочитать'),
#  ('бужу', 'разбужу'),
#  ('сердились', 'рассердились'),
#  ('делает', 'сделает'),
#  ('делать', 'сделать'),
#  ('дeлать', 'Сделать'),
#  ('делать', 'сделать'),
#  ('делать', 'сделать'),
#  ('делаю', 'сделаю'),
#  ('делаю', 'сделаю'),
#  ('делают', 'сделают'),
#  ('могла', 'смог'),
#  ('формулирует', 'сформулирует'),
#  ('видел', 'увидел'),
#  ('пошёл', 'шёл'),
#  ('кричит', 'крикнует'),
#  ('подчеркивает', 'подчеркнет'),
#  ('подчеркивает', 'подчеркнует'),
#  ('забудет', 'забывает'),
#  ('забыли', 'забывали'),
#  ('задать', 'задавать'),
#  ('сдают', 'задают'),
#  ('издала', 'издавала'),
#  ('оделся', 'одевался'),
#  ('мыть', 'помыть'),
#  ('подумай', 'думай'),
#  ('Позвони', 'Звони'),
#  ('Постарайтесь', 'Старайтесь'),
#  ('посчитайте ', 'считайте'),
#  ('пошлите', 'посылайте'),
#  ('станете', 'становите'),
#  ('зассказала', 'рассказывала'),
#  ('вдадимся', 'вдаваемся'),
#  ('смогут', 'могут понимать'),
#  ('сможем', 'можем'),
#  ('сможем', 'можем'),
#  ('сможем', 'можем'),
#  ('сможет', 'может'),
#  ('понять', 'понимает'),
#  ('показаться', 'показываться'),
#  ('сажать', 'посадить'),
#  ('может', 'сможет'),
#  ('прийти', 'приходит'),
#  ('выключать', 'выключить'),
#  ('идти', 'пойти'),
#  ('читать', 'прочитать'),
#  ('поговорить', 'говорит'),
#  ('поговорить', 'говорит'),
#  ('понравиться', 'нравятся'),
#  ('нарисовал', 'рисовал'),
#  ('делает', 'сделает'),
#  ('слышать', 'услышать'),
#  ('вскакивает', 'выскочит'),
#  ('допустите', 'допускайте'),
#  ('исчезнет', 'исчезает'),
#  ('кончится', 'кончает'),
#  ('наступит', 'наступает'),
#  ('обмениваемся', 'обменяемся'),
#  ('поднимаюсь', 'поднимусь'),
#  ('получишь', 'получаешь'),
#  ('получить', 'получат'),
#  ('получить', 'получат'),
#  ('получили', 'получают'),
#  ('помогут', 'помогают'),
#  ('принимайте', 'примите'),
#  ('продолжите', 'продолжаете'),
#  ('продолжу', 'продолжаю'),
#  ('рассказывает', 'расскажет'),
#  ('решу', 'решаю'),
#  ('состоит', 'составляется'),
#  ('они справятся', 'справляются'),
#  ('сбережём', 'бережём'),
#  ('увидеть', 'видит'),
#  ('вспоминает', 'вспомнит'),
#  ('встаю', 'встану'),
#  ('встаю', 'встану'),
#  ('встану', 'встаю'),
#  ('выигрывает', 'выиграет'),
#  ('высказываю', 'выскажу'),
#  ('поговорим', 'говорим'),
#  ('гулять', 'гуляют'),
#  ('сделает', 'делает'),
#  ('сделают', 'делает'),
#  ('подумайте', 'думаете'),
#  ('думайте', 'думаете'),
#  ('заканчивается', 'закончится'),
#  ('зарабатываю', 'заработаю'),
#  ('пойдем', 'идём'),
#  ('окончат', 'кончат'),
#  ('покупаю', 'куплю'),
#  ('покупаю', 'куплю'),
#  ('покупают', 'купят'),
#  ('покупают', 'купят'),
#  ('покупают', 'купят'),
#  ('смогу', 'могу'),
#  ('смогу', 'могу'),
#  ('смогу', 'могу'),
#  ('смогут', 'могут'),
#  ('сможем', 'можем'),
#  ('сможем', 'можем'),
#  ('сможет', 'может'),
#  ('сможет', 'может'),
#  ('сможете', 'можете'),
#  ('оказывают наибольшее влияние', 'наиболее   влияние   окажут'),
#  ('напоминает', 'напомнит'),
#  ('оказываются', 'окажутся'),
#  ('напишу', 'опишу'),
#  ('опаздываю', 'опоздаю'),
#  ('опаздываю.', 'опоздаю.'),
#  ('оспаривает', 'оспорит'),
#  ('открывается', 'откроется'),
#  ('открываю', 'открою'),
#  ('перестают', 'перестанут'),
#  ('дарят', 'подарят,'),
#  ('показывают', 'покажут'),
#  ('приодевается', 'приоденется'),
#  ('проигрывает', 'проиграет'),
#  ('поработаю', 'работаю'),
#  ('разрабатывают', 'разработают'),
#  ('рассказываю', 'расскажу'),
#  ('делает', 'сделает'),
#  ('смешиваются,', 'смешаются'),
#  ('спрашивает', 'спросит'),
#  ('спрашивайте', 'спросите.'),
#  ('спрашиваю', 'спрошу'),
#  ('постараюсь', 'стараюсь'),
#  ('Потанцуем,', 'Танцуем'),
#  ('Потанцуем?', 'Танцуем'),
#  ('Потанцуем, ', 'Танцуем,'),
#  ('сумеешь', 'умеешь'),
#  ('успевает', 'успеет'),
#  ('успеваю', 'успею'),
#  ('успеваю', 'успею'),
#  ('успеваю', 'успею'),
#  ('захотят', 'хотят'),
#  ('захочет', 'хочет'),
#  ('захочу', 'хочу'),
#  ('почувствуете', 'чувствуете'),
#  ('помогает', 'поможет'),
#  ('помогает', 'поможет'),
#  ('помогают коже.', 'поможет   кожи.'),
#  ('возьму', 'беру'),
#  ('возвращается', 'вернется'),
#  ('возвращается', 'вернётся'),
#  ('возвращается', 'вернётся'),
#  ('возвращается', 'вернуется'),
#  ('возвращаюсь', 'вернусь'),
#  ('возвращаются', 'вернутся'),
#  ('возвращаюсь', 'вернуюсь'),
#  ('возвращаюсь', 'вернуюсь'),
#  ('входят', 'воидут'),
#  ('выбегаем', 'выбежим'),
#  ('выезжает', 'выедет'),
#  ('выезжаю', 'выеду'),
#  ('выходит', 'выидет'),
#  ('выходят', 'выйдут'),
#  ('подходит', 'доидет'),
#  ('ложусь', 'лягу'),
#  ('находит', 'найдет'),
#  ('находит', 'найдёт'),
#  ('находите', 'найдёте'),
#  ('нахожу', 'найду'),
#  ('нахожу', 'найду'),
#  ('нахожу', 'найду'),
#  ('обходит', 'обоидет'),
#  ('отбегает', 'отбежит'),
#  ('подходят', 'подойдут'),
#  ('кладет', 'положит'),
#  ('предлагает', 'предложит'),
#  ('приходят', 'придёт'),
#  ('приезжает', 'приедет'),
#  ('приезжает', 'приедет'),
#  ('приезжает', 'приедет'),
#  ('приезжают', 'приедут'),
#  ('приходит', 'приидёт'),
#  ('приходит.', 'приидёт'),
#  ('прихожу', 'прииду'),
#  ('приходят', 'приидут'),
#  ('приходят', 'прийдут'),
#  ('приносят', 'принесут'),
#  ('принесет', 'приносит'),
#  ('придёт', 'приходит'),
#  ('проезжают', 'проедут'),
#  ('сбегают', 'сбегут'),
#  ('говорят', 'скажут'),
#  ('становятся', 'станут'),
#  ('становятся', 'станут'),
#  ('становятся', 'станут'),
#  (' убегает', 'убежит'),
#  ('уезжают', 'уедут'),
#  ('уходит.', 'уидёт'),
#  ('уходит', 'уидёт'),
#  ('уходит', 'уидёт.'),
#  ('падает', 'упадёт'),
#  ('падает', 'упает'),
#  ('уйдет', 'уходит'),
#  ('начнём', 'начинаем'),
#  ('начали', 'начинает'),
#  ('бросает', 'бросит'),
#  ('включает', 'включит'),
#  ('вспоминает', 'вспомнит'),
#  ('встречаемся', 'встретимся'),
#  ('встречаемся', 'встретимся'),
#  ('встречаемся', 'встретимся'),
#  ('встречаемся', 'встретимся'),
#  ('встречают', 'встретят'),
#  ('договариваются', 'договорятся'),
#  ('изучает', 'изучит'),
#  ('кончает', 'кончит'),
#  ('кончается', 'кончится'),
#  ('облегчает', 'облегчит'),
#  ('обращают', 'обратят'),
#  ('обращают', 'обратят'),
#  ('объясняет', 'обьяснит'),
#  ('отражает', 'отразят'),
#  (', отражает', 'отразят'),
#  ('говорит', 'поговорит'),
#  ('готовят', 'подготовят'),
#  ('позволяли', 'позволят'),
#  ('предъявляют', 'предъявят'),
#  ('приближается', 'приблизится'),
#  ('приглашают', 'пригласят'),
#  ('приготовля́ют', 'приготовлят'),
#  ('решает', 'решит'),
#  ('решает ', 'решит'),
#  ('решают', 'решят'),
#  ('совершают', 'совершят'),
#  ('сообщает', 'сообщит'),
#  ('видят', 'удивят'),
#  ('видят', 'удивят'),
#  ('расскажите', 'Рассказывайте'),
#  ('расскажу', 'рассказываю'),
#  ('спросим', 'спрашиваем'),
#  ('спросят', 'спрашивают'),
#  ('спросите', 'срашаваете'),
#  ('обнимемся', 'обнимаем'),
#  ('моется', 'вымоется'),
#  ('заболевают', 'заболят'),
#  ('позаботимся', 'заботимся'),
#  ('смеются', 'засмеются'),
#  ('пишет', 'напишит'),
#  ('учат', 'научат'),
#  ('характеризует', 'охарактеризует'),
#  ('обедаю', 'победаю'),
#  ('кому верите ', 'поверите'),
#  ('говорить', 'поговорить'),
#  ('гулять', 'погулять'),
#  ('думал', 'подумал'),
#  ('посещать', 'поетить'),
#  ('жили.', 'пожили'),
#  ('идет', 'пойдет'),
#  ('идет', 'пойдёт'),
#  ('иду', 'пойду'),
#  ('иду', 'пойду'),
#  ('иду', 'пойду'),
#  ('идут', 'пойдут'),
#  ('идут', 'поидят'),
#  ('идти', 'пойти'),
#  ('купила', 'покупала'),
#  ('купить', 'покупать'),
#  ('пытался', 'попытался'),
#  ('служат', 'послужат'),
#  ('старались', 'постарались'),
#  ('стараюсь', 'постараюсь'),
#  ('строил', 'построил'),
#  ('строилось', 'построилось'),
#  ('теряют', 'потеряют'),
#  ('толстеют', 'потолстают'),
#  ('учиться', 'поучиться'),
#  ('хвалить', 'похвалить'),
#  ('себя чувствую', 'почувствую'),
#  ('шла', 'пошла'),
#  ('являлась', 'появилась'),
#  ('делал', 'сделал'),
#  ('делают', 'сделают'),
#  ('делают', 'сделают'),
#  ('садиться', 'сесть'),
#  ('кручу', 'скручу'),
#  ('могут', 'смогут'),
#  ('лгут', 'солгут'),
#  ('видел', 'увидел'),
#  ('поужинали', 'ужинали'),
#  ('отдыхаю', 'отдохну'),
#  ('отдыхаю', 'отдохну'),
#  ('отдыхать', 'отдохнуть'),
#  ('упоминали', 'упомянули'),
#  ('встала', 'бстабала'),
#  ('забывать', 'забыть'),
#  ('оденутся', 'одеваются'),
#  ('останется', 'остаётся'),
#  ('перегреться', 'перегреваться'),
#  ('узнаете', 'узнаёте'),
#  ('дала', 'давала'),
#  ('смогла', 'могла'),
#  ('мог бы пойти', 'он мог бы идти'),
#  ('посмотреть', 'смотреть'),
#  ('прочитать', 'читать'),
#  ('ограничить', 'ограничивать'),
#  ('делать', 'сделать'),
#  ('спасать', 'спасти'),
#  ('задать', 'задавать'),
#  ('страдать', 'пострадать'),
#  ('делать', 'сделать'),
#  ('встретить', 'встречать'),
#  ('захотела', 'хотела'),
#  ('захотели', 'хотели'),
#  ('прочитать', 'читать'),
#  ('прочитать', 'читать'),
#  ('сосредоточиться', 'сосредоточиваться'),
#  ('мешать', 'помешать'),
#  ('попробовать', 'пробовать'),
#  ('проверил', 'проверял'),
#  ('сварила', 'варила'),
#  ('помыла', 'мыла'),
#  ('помогали', 'помогли'),
#  ('собралась', 'собиралась'),
#  ('прочитать', 'читать'),
#  ('дать', 'давать'),
#  ('бросил', 'бросал'),
#  ('встретил', 'встречал'),
#  ('встретил', 'встречал'),
#  ('встретила', 'встречала'),
#  ('встретила', 'встречала'),
#  ('встретила', 'встречала'),
#  ('встретила', 'встречали'),
#  ('выросло', 'вырастало'),
#  ('достиг', 'достигал'),
#  ('достигли', 'достигали'),
#  ('достигли', 'достигали'),
#  ('заключил', 'заключал'),
#  ('заметил', 'замечал'),
#  ('заметил', 'замечал'),
#  ('заметила', 'замечала'),
#  ('я заметила', 'замечала'),
#  ('защищали', 'защитили'),
#  ('изобрели', 'изобретали'),
#  ('исчезли', 'исчезали'),
#  ('называли', 'назвали'),
#  ('объяснила,', 'объясняла'),
#  ('объяснила', 'обясняла'),
#  ('отказывался', 'оказался'),
#  ('казалось', 'показалось'),
#  ('получил', 'получал'),
#  ('помогла', 'помогал'),
#  ('помогла', 'помогала'),
#  ('помогли', 'помогали'),
#  ('помогло', 'помогало'),
#  ('понимала', 'понила'),
#  ('понимал', 'понял'),
#  ('понимала', 'поняла'),
#  ('понимали', 'поняли'),
#  ('поразил', 'поражал'),
#  ('поступила', 'поступала'),
#  ('поступила', 'поступала'),
#  ('появлялись', 'появились'),
#  ('предложил', 'предлагал'),
#  ('предложила', 'предлагала.'),
#  ('предложили', 'предлагали'),
#  ('предпочли', 'предпочитали'),
#  ('предложил', 'предупреждал'),
#  ('переступила', 'преступала'),
#  ('привлекло', 'привлекало'),
#  ('прилетел', 'прилетал'),
#  ('принимал', 'принял'),
#  ('продолжил', 'продолжал'),
#  ('продолжил', 'продолжал'),
#  ('продолжил', 'продолжал'),
#  ('продолжил', 'продолжал'),
#  ('продолжил', 'продолжал'),
#  ('продолжила обучение', 'продолжала'),
#  ('продолжили', 'продолжали'),
#  ('разрешил', 'разрешал'),
#  ('рассказывала', 'рассказала'),
#  ('решили', 'решали'),
#  ('сообщила', 'сообщала'),
#  ('справили', 'справляли'),
#  ('уверил', 'уверял'),
#  ('поужинала', 'ужинала'),
#  ('уменьшилось', 'уменьшалось'),
#  ('ухудшил', 'ухудшал'),
#  ('арестовывали', 'арестовали'),
#  ('поблагодврила', 'благодарила'),
#  ('побывал', 'бывал'),
#  ('побывали', 'бывали'),
#  ('увидел', 'видел'),
#  ('увидела', 'видела'),
#  ('увидела', 'видела'),
#  ('увидели', 'видели'),
#  ('увидели', 'видели'),
#  ('увидели', 'видели'),
#  ('увидели', 'видели'),
#  ('повлиял', 'влиял'),
#  ('повлиял', 'влиял'),
#  ('повлиял', 'влиял'),
#  ('повлияла', 'влияла'),
#  ('повлияла', 'влияла'),
#  ('повлияла', 'влияла'),
#  ('повлияли', 'влияли'),
#  ('своровал', 'воровал'),
#  ('воспитывала', 'воспитала'),
#  ('воспитывали', 'воспитали'),
#  ('выбирали', 'выбрали'),
#  ('выбирали', 'выбрали'),
#  ('поговорили', 'говорили'),
#  ('проголосовал', 'голосовал'),
#  ('проголосовал', 'голосовал'),
#  ('давал', 'дал'),
#  ('сделал', 'делал'),
#  ('сделал', 'делал'),
#  ('сделал', 'делал'),
#  ('сделала', 'делала'),
#  ('продиктовала', 'диктировала'),
#  ('договаривались', 'договорились'),
#  ('подумал', 'думал'),
#  ('подумала', 'думала'),
#  ('обдумала', 'думала'),
#  ('подумала', 'думала'),
#  ('подумала', 'думала'),
#  ('подумали', 'думали'),
#  ('пожалел', 'жалел'),
#  ('пожалела', 'жалела'),
#  ('пожелал', 'желал'),
#  ('прожил', 'жил'),
#  ('прожил', 'жил'),
#  ('прожила', 'жила'),
#  ('прожила', 'жила'),
#  ('прожила.', 'жила'),
#  ('позавтракал', 'завтракал'),
#  ('задавать', 'задать'),
#  ('заканчивали', 'закончили'),
#  ('заканчивалось', 'закончилось'),
#  ('позвонил', 'звонил'),
#  ('позвонил', 'звонил'),
#  ('позвонили', 'звонили'),
#  ('отзвонились', 'звонили'),
#  ('познакомилась', 'знакомилась'),
#  ('познакомился', 'знакомился'),
#  ('узнали', 'знали'),
#  ('заинтересовалась', 'интересовалась'),
#  ('заинтересовались', 'интересовались'),
#  ('показалось', 'казалась'),
#  ('показалось', 'казалась'),
#  ('оказалось,', 'казалось,'),
#  ('покупал', 'купил'),
#  ('покупала', 'купила'),
#  ('покушали', 'кушали'),
#  ('поменял', 'менял'),
#  ('смогла', 'могла'),
#  ('смогла', 'могла'),
#  ('вымыл', 'мыл'),
#  ('помыл', 'мыл'),
#  ('называли', 'назвали'),
#  ('унаследовал', 'наследовал'),
#  ('начинал', 'начал'),
#  ('начинала', 'начала'),
#  ('начинали', 'начали'),
#  ('понравился', 'нравился'),
#  ('понравился', 'нравился'),
#  ('понравился', 'нравился'),
#  ('понравились', 'нравился'),
#  ('одевалась', 'оделась'),
#  ('оказывалось,', 'оказалась'),
#  ('опаздывал', 'опаздал'),
#  ('описывали', 'описали'),
#  ('осознавал', 'осознал'),
#  ('открылся', 'открывался'),
#  ('попарился', 'парился'),
#  ('переставала', 'перестала'),
#  ('написал', 'писал'),
#  ('написал', 'писал'),
#  ('написал', 'писал'),
#  ('написал', 'писал'),
#  ('написал', 'писал'),
#  ('написал', 'писал'),
#  ('написала', 'писала'),
#  ('показывал', 'показал'),
#  ('показывали', 'показали'),
#  ('посылал', 'послал'),
#  ('придумывали', 'придумали'),
#  ('признавали', 'признали'),
#  ('признавали,', 'признали'),
#  ('продавала', 'продала'),
#  ('продавали', 'продали'),
#  ('попросил', 'просил'),
#  ('попросила', 'просила'),
#  ('попросила', 'просили'),
#  ('испугалась', 'пугалась'),
#  ('раздавали', 'раздали'),
#  ('сдавали', 'сдали'),
#  ('сдавали', 'сдали'),
#  ('сдавали', 'сдали'),
#  ('рассердилась', 'сердилась'),
#  ('послужила', 'служила'),
#  ('услышала', 'слышала'),
#  ('услышала,', 'слышала'),
#  ('услышали', 'слышали'),
#  ('посмотрел', 'смотрел'),
#  ('посмотрел', 'смотрел'),
#  ('посмотрел', 'смотрел'),
#  ('поспал', 'спал'),
#  ('спрашивают', 'спросил'),
#  ('пострадали', 'страдали'),
#  ('утекла', 'текла'),
#  ('потратили', 'тратили'),
#  ('потребовалось', 'требовалось'),
#  ('убивали', 'убили'),
#  ('убивали ', 'убили'),
#  ('поужинал', 'ужинал'),
#  ('поужинал', 'ужинал'),
#  ('знала', 'узнала'),
#  ('умирал', 'умерли'),
#  ('успевала', 'успела'),
#  ('выучила', 'учила'),
#  ('научилась', 'училась'),
#  ('научили', 'учили'),
#  ('сформировались', 'формировались'),
#  ('похвалил', 'хвалил'),
#  ('похвастался', 'хвалился'),
#  ('захотелось', 'хотелось'),
#  ('почитал', 'читал'),
#  ('прочитал', 'читал'),
#  ('прочитала', 'читала'),
#  ('прочитать', 'читать'),
#  ('прочитать', 'читать'),
#  ('почувствовала', 'чувствовала'),
#  ('пошли', 'шли'),
#  ('сэкономило', 'экономило'),
#  ('помогал', 'помог'),
#  ('брали', 'взяли'),
#  ('вела', 'водила'),
#  ('вошел', 'входил'),
#  ('вошло', 'входил'),
#  ('вышел', 'выходил'),
#  ('вышел', 'выходил'),
#  ('выходил', 'вышел'),
#  ('догнала', 'догоняла'),
#  ('изгнали', 'изгоняли'),
#  ('изгнали', 'изгоняли'),
#  ...]

# %%
all_text = [char for src, tgt in pairs for char in src + tgt]
chars = sorted(set(all_text))
char2idx = {c: i+4 for i, c in enumerate(chars)}
char2idx["<PAD>"] = 0
char2idx["<SOS>"] = 1
char2idx["<EOS>"] = 2
char2idx["<UNK>"] = 3
idx2char = {i: c for c, i in char2idx.items()}
vocab_size = len(char2idx)

# %%
class VerbPairDataset(Dataset):
    def __init__(self, pairs, char2idx, max_len=20):
        self.pairs = pairs
        self.char2idx = char2idx
        self.max_len = max_len

    def encode(self, word, add_sos=False):
        seq = [char2idx.get(c, char2idx["<UNK>"]) for c in word]
        if add_sos:
            seq = [char2idx["<SOS>"]] + seq
        seq = seq + [char2idx["<EOS>"]]
        seq += [char2idx["<PAD>"]] * (self.max_len - len(seq))
        return seq[:self.max_len]

    def __len__(self):
        return len(self.pairs)

    def __getitem__(self, idx):
        src, tgt = self.pairs[idx]
        src_encoded = self.encode(src)
        tgt_encoded = self.encode(tgt, add_sos=True)
        return torch.tensor(src_encoded), torch.tensor(tgt_encoded)

# %%
class Encoder(nn.Module):
    def __init__(self, vocab_size, emb_dim, hidden_dim):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, emb_dim)
        self.lstm = nn.LSTM(emb_dim, hidden_dim, batch_first=True)

    def forward(self, x):
        embedded = self.embedding(x)
        outputs, (hidden, cell) = self.lstm(embedded)
        return hidden, cell


class Decoder(nn.Module):
    def __init__(self, vocab_size, emb_dim, hidden_dim):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, emb_dim)
        self.lstm = nn.LSTM(emb_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, vocab_size)

    def forward(self, x, hidden, cell):
        x = x.unsqueeze(1)
        embedded = self.embedding(x)
        output, (hidden, cell) = self.lstm(embedded, (hidden, cell))
        prediction = self.fc(output.squeeze(1))
        return prediction, hidden, cell

# %%
def train_seq2seq(encoder, decoder, dataloader, epochs=20, teacher_forcing_ratio=0.5):
    criterion = nn.CrossEntropyLoss(ignore_index=char2idx["<PAD>"])
    enc_opt = optim.Adam(encoder.parameters(), lr=0.001)
    dec_opt = optim.Adam(decoder.parameters(), lr=0.001)

    for epoch in range(epochs):
        total_loss = 0
        for src, tgt in dataloader:
            enc_opt.zero_grad()
            dec_opt.zero_grad()
            hidden, cell = encoder(src)
            input_token = tgt[:, 0]
            loss = 0
            for t in range(1, tgt.shape[1]):
                output, hidden, cell = decoder(input_token, hidden, cell)
                loss += criterion(output, tgt[:, t])
                teacher_force = random.random() < teacher_forcing_ratio
                top1 = output.argmax(1)
                input_token = tgt[:, t] if teacher_force else top1
            loss.backward()
            enc_opt.step()
            dec_opt.step()
            total_loss += loss.item() / tgt.shape[1]
        print(f"Epoch {epoch+1}, Loss: {total_loss / len(dataloader):.4f}")

# %%
def predict(encoder, decoder, word, max_len=20):
    with torch.no_grad():
        encoder.eval()
        decoder.eval()
        input_seq = torch.tensor([dataset.encode(word)], dtype=torch.long)
        hidden, cell = encoder(input_seq)
        input_token = torch.tensor([char2idx["<SOS>"]])
        output_seq = []

        for _ in range(max_len):
            output, hidden, cell = decoder(input_token, hidden, cell)
            top1 = output.argmax(1)
            if top1.item() == char2idx["<EOS>"]:
                break
            output_seq.append(idx2char[top1.item()])
            input_token = top1

        return "".join(output_seq)

# %%
dataset = VerbPairDataset(pairs, char2idx)
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

encoder = Encoder(vocab_size, emb_dim=64, hidden_dim=128)
decoder = Decoder(vocab_size, emb_dim=64, hidden_dim=128)

train_seq2seq(encoder, decoder, dataloader, epochs=30)

# Test
# Out:
# Epoch 1, Loss: nan
# Epoch 2, Loss: nan
# Epoch 3, Loss: nan
# Epoch 4, Loss: nan
# Epoch 5, Loss: nan
# Epoch 6, Loss: nan
# Epoch 7, Loss: nan
# Epoch 8, Loss: nan
# Epoch 9, Loss: nan
# Epoch 10, Loss: nan
# Epoch 11, Loss: nan
# Epoch 12, Loss: nan
# Epoch 13, Loss: nan
# Epoch 14, Loss: nan
# Epoch 15, Loss: nan
# Epoch 16, Loss: nan
# Epoch 17, Loss: nan
# Epoch 18, Loss: nan
# Epoch 19, Loss: nan
# Epoch 20, Loss: nan
# Epoch 21, Loss: nan
# Epoch 22, Loss: nan
# Epoch 23, Loss: nan
# Epoch 24, Loss: nan
# Epoch 25, Loss: nan
# Epoch 26, Loss: nan
# Epoch 27, Loss: nan
# Epoch 28, Loss: nan
# Epoch 29, Loss: nan
# Epoch 30, Loss: nan

# %%
df["learner_pred"] = df["teacher"].apply(lambda word: predict(encoder, decoder, word))

# %%
df["is_correct"] = df["learner_pred"] == df["learner"]
accuracy = df["is_correct"].mean()
print(f"Exact match accuracy: {accuracy:.2f}")
# Out:
# Exact match accuracy: 0.87

# %%
import nltk
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
import editdistance

# %%
smoothie = SmoothingFunction().method4

def compute_metrics(row):
    pred = row["learner_pred"]
    truth = row["learner"]

    # Exact match
    is_exact = pred == truth

    # Edit distance
    edit_dist = editdistance.eval(pred, truth)

    # Character accuracy
    max_len = max(len(pred), len(truth))
    char_acc = 1 - (edit_dist / max_len) if max_len > 0 else 1.0

    # BLEU score (character-level)
    bleu = sentence_bleu(
        [list(truth)], list(pred), weights=(1, 0, 0, 0), smoothing_function=smoothie
    )

    return pd.Series([is_exact, edit_dist, char_acc, bleu],
                     index=["is_exact", "edit_distance", "char_accuracy", "bleu"])

# %%
df[["is_exact", "edit_distance", "char_accuracy", "bleu"]] = df.apply(compute_metrics, axis=1)

# %%
print("Exact Match Accuracy:", df["is_exact"].mean())
print("Average Edit Distance:", df["edit_distance"].mean())
print("Average Character Accuracy:", df["char_accuracy"].mean())
print("Average BLEU Score:", df["bleu"].mean())
# Out:
# Exact Match Accuracy: 0.8653061224489796
# Average Edit Distance: 0.2873469387755102
# Average Character Accuracy: 0.9667192950662339
# Average BLEU Score: 0.9701638379886588

# %%
import pandas as pd

# Show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# To avoid cutting off wide content
pd.set_option('display.max_colwidth', None)


df
# Out:
#                            teacher                      learner  \
# 0                           помочь                     помогать
# 1                   злоупотреблять                злоупотребить
# 2                            пойти                         идти
# 3                проконтролировать               контролировать
# 4                         покупать                       купить
# 5                         начинать                       начать
# 6                       передавать                     передать
# 7                     возвращаться                    вернуться
# 8                        приходить                       прийти
# 9                         выражать                     выразить
# 10                       разрушать                    разрушить
# 11                         уделять                      удалить
# 12                      достигнуть                    достигать
# 13                        заменить                     заменять
# 14                        заметить                     замечать
# 15                      пообщаться                     общаться
# 16                         оживить                     оживлять
# 17                          помочь                     помогать
# 18                          помочь                     помогать
# 19                          помочь                     помогать
# 20                       поступить                    поступать
# 21                     представить                 представлять
# 22                       принимать                      принять
# 23                       проверить                    проверять
# 24                      разуверить                   разуверять
# 25                       сократить                    сокращать
# 26                        улучшить                     улучшать
# 27                        уступить                     уступать
# 28                         увидеть                       видеть
# 29                         увидеть                       видеть
# 30                         увидеть                       видеть
# 31                         увидеть                       видеть
# 32                      поговорить                     говорить
# 33                     приготовить                     готовить
# 34                         сделать                       делать
# 35                         сделать                       делать
# 36                         сделать                       делать
# 37                         сделать                       делать
# 38                     сделать это                       делать
# 39                       подождать                        ждать
# 40                           пойти                         идти
# 41              сконцентрироваться            концентрироваться
# 42                       закончить                      кончать
# 43                        покупать                       купить
# 44                        покупать                       купить
# 45                         понять,               могут понимать
# 46                 сможет работать               может работает
# 47                      пообедать.                      обедать
# 48                      оставаться                     остаться
# 49                        написать                       писать
# 50                        написать                       писать
# 51                          выпить                         пить
# 52                        оплатить                      платить
# 53                    поддерживать                   поддержaть
# 54                       продавать                      продать
# 55                       попросить                      просить
# 56                         вырасти                    раститься
# 57                       связывать                      связать
# 58                        услышать                      слышать
# 59                       потрогать                      трогать
# 60              убивать и наносить              убить и нанести
# 61                        узнавать                       узнать
# 62            охарактеризовать как              характеризовать
# 63                        захотеть                       хотеть
# 64                   почувствовать                  чувствовать
# 65                   почувствовать                   чуствовать
# 66                       вернуться                   возвращать
# 67                         нанести                     наносить
# 68                      переезжать                    переехать
# 69                          прийти                    приходить
# 70                          прийти                    приходить
# 71                          прийти                    приходить
# 72                       проводить                     провести
# 73                       проводить                     провести
# 74                       произойти                  происходить
# 75                           стать                    становить
# 76              убивать и наносить              убить и нанести
# 77                         выбрать                     выбирать
# 78                        изменять                     изменить
# 79                      изменяться                   измениться
# 80                        изменить                    изменрять
# 81                      измениться                   изменяться
# 82                        получать                     получить
# 83                     проявляться                   проявиться
# 84                          решать                       решить
# 85                          решать                       решить
# 86                       оказаться                  оказываться
# 87                      отказаться                 отказываться
# 88                         открыть                    открывать
# 89                        показать                   показывать
# 90                     рассмотреть                рассматривать
# 91                          понять                     понимать
# 92                          понять                     понимать
# 93                          понять                     понимать
# 94                          понять                     понимать
# 95                          понять                     понимать
# 96                          понять                     понимать
# 97                          понять                     понимать
# 98                          писать                     написать
# 99                          забыть                     забывать
# 100                     возникнуть                    возникать
# 101                    выдерживать                    выдержать
# 102                       ответить                     отвечать
# 103                       выбирать                      выбрать
# 104                        сделать                       делать
# 105                       забывать                       забыть
# 106                     записывать                     записать
# 107                          пойти                         идти
# 108                       покупать                       купить
# 109                       покупать                       купить
# 110                         помыть                         мыть
# 111                       называть                      назвать
# 112                      одеваться                      одеться
# 113                       написать                       писать
# 114                    придумывать                    придумать
# 115                       признать                   признавать
# 116                       узнавать                       узнать
# 117                       помогать                       помочь
# 118                       выезжать                      выехать
# 119                      перевести                   переводить
# 120                       говорить                      сказать
# 121                       сравнить                   сравнивать
# 122                         понять                     понимать
# 123                         писать                     написать
# 124                       нанимать                       нанять
# 125                       нанимать                       нанять
# 126                       обсудить                    обсуждать
# 127                       обсудить                    обсуждать
# 128                       отметить                     отмечать
# 129                      отступить                    отступать
# 130                         помочь                     помогать
# 131                        помочь.                     помогать
# 132                       поразить                     поражать
# 133                     прекратить                   прекращать
# 134                      принимать                      принять
# 135                     продолжить                   продалжать
# 136                    соединиться                  соединяться
# 137                        увидеть                       видеть
# 138                        увидеть                       видеть
# 139                     поговорить                     говорить
# 140                        сделать                       делать
# 141                        сделать                       делать
# 142                     поделиться                     делиться
# 143                     поиграть в                       играть
# 144                       покупать                       купить
# 145                    оставаться                      остаться
# 146                       написать                       писать
# 147                        описать                       писать
# 148                       написать                       писать
# 149                         выпить                         пить
# 150                     показывать                     показать
# 151                       услышать                      слышать
# 152                   потанцевать,                    танцевать
# 153                          знать                       узнать
# 154                  поучаствовать                  участвовать
# 155                      вернуться                 возвращаться
# 156                       выходить                        выйти
# 157                        поймать                       ловить
# 158                      отдохнуть                     отдыхать
# 159                      отдохнуть                     отдыхать
# 160                      отдохнуть                     отдыхать
# 161                      отдохнуть                     отдыхать
# 162                     переезжать                    переехать
# 163                     переезжать                    переехать
# 164                     предложить                   предлагать
# 165                      проводить                     провести
# 166                      проводить                     провести
# 167                      проводить                     провести
# 168                     развестись                  разводиться
# 169                       говорить                      сказать
# 170                          стать                  становиться
# 171                        уезжать                       уехать
# 172                         решать                       решить
# 173                       окончить                   оканчивать
# 174                        описать                    описывать
# 175                    подчеркнуть                 подчеркивать
# 176                    подчеркнуть                 подчёркивать
# 177                     рассказать                 рассказывать
# 178                       спросить                   спрашивать
# 179                      увеличить                  увеличивать
# 180                         обнять                     обнимать
# 181                        понять,                     понимать
# 182                        понять,                     понимать
# 389                        изучать                      изучить
# 390                        изучать                      изучить
# 391                       обращали                     обратить
# 392                      обсуждают                     обсудить
# 393                      объяснять                    объяснить
# 394                      объяснять                    объяснить
# 395                     определять                   определить
# 396                      оставляет                     оставить
# 397                   перемещаться                  переместить
# 398                      повторять                    повторить
# 399                      повторять                    повторить
# 400                      повторять                      помнить
# 401                      посвящать                    посвятить
# 402                     появляется                     появится
# 403                     приглашать                   пригласить
# 404                      примерять                    примерить
# 405                      разделять                    разделить
# 406                  расслабляется                  расслабится
# 407                         решать                       решить
# 408                         решает                       решить
# 409                      соединять                    соединить
# 410                      сохранять                    сохранить
# 411                      сохранять                    сохранить
# 412                        уверять                      уверить
# 413                       улучшать                     улучшить
# 414                        вызвали                      вызывал
# 415                   договориться               договариваться
# 416                        закрыть                    закрывать
# 417                        назвать                     называть
# 418                        описать                    описывать
# 419                        описать                    описывать
# 420                   остановиться              останавливаться
# 421                     поддержать                 поддерживать
# 422                       подпишет                  подписывает
# 423                       показать                   показывать
# 424                     показать,                    показывать
# 425                   предсказать,                предсказывать
# 426                       прервать                    прерывать
# 427                       расскажу                  рассказиваю
# 428                    рассмотреть                рассматрывать
# 429                       спросить                   спрашивать
# 430                    увеличиться                увеличиваться
# 431                         понять                     понимать
# 432                         понять                     понимать
# 433                         понять                     понимать
# 434                         понять                     понимать
# 435                         понять                     понимать
# 436                         понять                     понимать
# 437                         понять                     понимать
# 438                         понять                     понимать
# 439                         понять                     понимать
# 440                        принять                    принимать
# 441                         делать                      cделать
# 442                         съесть                         есть
# 443                        платить                    заплатить
# 444                         писать                     написать
# 445                      готовятся                 подготовятся
# 446                          думаю                      подумаю
# 447                     знакомятся                 познакомятся
# 448                           идут                       поидёт
# 449                         красят                    покрасиют
# 450                           мыть                       помыть
# 451                      нравились                  понравилась
# 452                      нравилось                  понравилось
# 453                       нравился                   понравился
# 454                        пытался                    попытался
# 455                       пытаются                   попытаются
# 456                       смотрела                   посмотрела
# 457                         смотрю                     посмотрю
# 458                         теряет                     потеряет
# 459                         чистим                    почистаем
# 460                            шли                        пошли
# 461                      попросила                       просил
# 462                         читать                    прочитать
# 463                           бужу                      разбужу
# 464                      сердились                 рассердились
# 465                         делает                      сделает
# 466                         делать                      сделать
# 467                         дeлать                      Сделать
# 468                         делать                      сделать
# 469                         делать                      сделать
# 470                          делаю                       сделаю
# 471                          делаю                       сделаю
# 472                         делают                      сделают
# 473                          могла                         смог
# 474                    формулирует                 сформулирует
# 475                          видел                       увидел
# 476                          пошёл                          шёл
# 477                         кричит                     крикнует
# 478                   подчеркивает                   подчеркнет
# 479                   подчеркивает                  подчеркнует
# 480                        забудет                     забывает
# 481                         забыли                     забывали
# 482                         задать                     задавать
# 483                          сдают                       задают
# 484                         издала                     издавала
# 485                         оделся                     одевался
# 486                           мыть                       помыть
# 487                        подумай                        думай
# 488                        Позвони                        Звони
# 489                   Постарайтесь                   Старайтесь
# 490                    посчитайте                      считайте
# 491                        пошлите                    посылайте
# 492                        станете                    становите
# 493                     зассказала                 рассказывала
# 494                       вдадимся                    вдаваемся
# 495                         смогут               могут понимать
# 496                         сможем                        можем
# 497                         сможем                        можем
# 498                         сможем                        можем
# 499                         сможет                        может
# 500                         понять                     понимает
# 501                     показаться                 показываться
# 502                         сажать                     посадить
# 503                          может                       сможет
# 504                         прийти                     приходит
# 505                      выключать                    выключить
# 506                           идти                        пойти
# 507                         читать                    прочитать
# 508                     поговорить                      говорит
# 509                     поговорить                      говорит
# 510                    понравиться                     нравятся
# 511                      нарисовал                      рисовал
# 512                         делает                      сделает
# 513                        слышать                     услышать
# 514                     вскакивает                     выскочит
# 515                      допустите                   допускайте
# 516                       исчезнет                     исчезает
# 517                       кончится                      кончает
# 518                       наступит                    наступает
# 519                   обмениваемся                   обменяемся
# 520                     поднимаюсь                    поднимусь
# 521                       получишь                    получаешь
# 522                       получить                      получат
# 523                       получить                      получат
# 524                       получили                     получают
# 525                        помогут                     помогают
# 526                     принимайте                      примите
# 527                     продолжите                  продолжаете
# 528                       продолжу                    продолжаю
# 529                   рассказывает                    расскажет
# 530                           решу                        решаю
# 531                        состоит                 составляется
# 532                  они справятся                  справляются
# 533                       сбережём                      бережём
# 534                        увидеть                        видит
# 535                     вспоминает                     вспомнит
# 536                          встаю                       встану
# 537                          встаю                       встану
# 538                         встану                        встаю
# 539                     выигрывает                     выиграет
# 540                     высказываю                      выскажу
# 541                      поговорим                      говорим
# 542                         гулять                       гуляют
# 543                        сделает                       делает
# 544                        сделают                       делает
# 545                      подумайте                      думаете
# 546                        думайте                      думаете
# 547                  заканчивается                   закончится
# 548                    зарабатываю                    заработаю
# 549                         пойдем                         идём
# 550                        окончат                       кончат
# 551                        покупаю                        куплю
# 552                        покупаю                        куплю
# 553                       покупают                        купят
# 554                       покупают                        купят
# 555                       покупают                        купят
# 556                          смогу                         могу
# 557                          смогу                         могу
# 558                          смогу                         могу
# 559                         смогут                        могут
# 560                         сможем                        можем
# 561                         сможем                        можем
# 562                         сможет                        может
# 563                         сможет                        может
# 564                        сможете                       можете
# 565   оказывают наибольшее влияние  наиболее   влияние   окажут
# 566                     напоминает                     напомнит
# 567                    оказываются                     окажутся
# 568                         напишу                        опишу
# 569                      опаздываю                      опоздаю
# 570                     опаздываю.                     опоздаю.
# 571                     оспаривает                      оспорит
# 572                    открывается                    откроется
# 573                       открываю                       открою
# 574                      перестают                   перестанут
# 575                          дарят                     подарят,
# 576                     показывают                      покажут
# 577                   приодевается                  приоденется
# 578                    проигрывает                    проиграет
# 579                      поработаю                      работаю
# 580                  разрабатывают                  разработают
# 581                    рассказываю                     расскажу
# 582                         делает                      сделает
# 583                   смешиваются,                    смешаются
# 584                     спрашивает                      спросит
# 585                    спрашивайте                    спросите.
# 586                      спрашиваю                       спрошу
# 587                     постараюсь                     стараюсь
# 588                     Потанцуем,                      Танцуем
# 589                     Потанцуем?                      Танцуем
# 590                    Потанцуем,                      Танцуем,
# 591                        сумеешь                       умеешь
# 592                       успевает                       успеет
# 593                        успеваю                        успею
# 594                        успеваю                        успею
# 595                        успеваю                        успею
# 596                        захотят                        хотят
# 597                        захочет                        хочет
# 598                         захочу                         хочу
# 599                   почувствуете                   чувствуете
# 600                       помогает                      поможет
# 601                       помогает                      поможет
# 602                 помогают коже.              поможет   кожи.
# 603                         возьму                         беру
# 604                   возвращается                     вернется
# 605                   возвращается                     вернётся
# 606                   возвращается                     вернётся
# 607                   возвращается                    вернуется
# 608                    возвращаюсь                      вернусь
# 609                   возвращаются                     вернутся
# 610                    возвращаюсь                     вернуюсь
# 611                    возвращаюсь                     вернуюсь
# 612                         входят                       воидут
# 613                       выбегаем                      выбежим
# 614                       выезжает                       выедет
# 615                        выезжаю                        выеду
# 616                        выходит                       выидет
# 617                        выходят                       выйдут
# 618                       подходит                       доидет
# 619                         ложусь                         лягу
# 620                        находит                       найдет
# 621                        находит                       найдёт
# 622                       находите                      найдёте
# 623                         нахожу                        найду
# 624                         нахожу                        найду
# 625                         нахожу                        найду
# 626                        обходит                      обоидет
# 627                       отбегает                      отбежит
# 628                       подходят                     подойдут
# 629                         кладет                      положит
# 630                     предлагает                    предложит
# 631                       приходят                       придёт
# 632                      приезжает                      приедет
# 633                      приезжает                      приедет
# 634                      приезжает                      приедет
# 635                      приезжают                      приедут
# 636                       приходит                      приидёт
# 637                      приходит.                      приидёт
# 638                        прихожу                       прииду
# 639                       приходят                      приидут
# 640                       приходят                      прийдут
# 641                       приносят                     принесут
# 642                       принесет                     приносит
# 643                         придёт                     приходит
# 644                      проезжают                      проедут
# 645                        сбегают                       сбегут
# 646                        говорят                       скажут
# 647                     становятся                       станут
# 648                     становятся                       станут
# 649                     становятся                       станут
# 650                        убегает                       убежит
# 651                        уезжают                        уедут
# 652                        уходит.                        уидёт
# 653                         уходит                        уидёт
# 654                         уходит                       уидёт.
# 655                         падает                       упадёт
# 656                         падает                        упает
# 657                          уйдет                       уходит
# 658                         начнём                     начинаем
# 659                         начали                     начинает
# 660                        бросает                       бросит
# 661                       включает                      включит
# 662                     вспоминает                     вспомнит
# 663                    встречаемся                   встретимся
# 664                    встречаемся                   встретимся
# 665                    встречаемся                   встретимся
# 666                    встречаемся                   встретимся
# 667                      встречают                     встретят
# 668                 договариваются                  договорятся
# 669                        изучает                       изучит
# 670                        кончает                       кончит
# 671                      кончается                     кончится
# 672                      облегчает                     облегчит
# 673                       обращают                      обратят
# 674                       обращают                      обратят
# 675                      объясняет                     обьяснит
# 676                       отражает                      отразят
# 677                     , отражает                      отразят
# 678                        говорит                    поговорит
# 679                        готовят                   подготовят
# 680                      позволяли                     позволят
# 681                    предъявляют                    предъявят
# 682                   приближается                  приблизится
# 683                     приглашают                    пригласят
# 684                  приготовля́ют                  приготовлят
# 685                         решает                        решит
# 686                        решает                         решит
# 687                         решают                        решят
# 688                      совершают                     совершят
# 689                       сообщает                      сообщит
# 690                          видят                       удивят
# 691                          видят                       удивят
# 692                     расскажите                Рассказывайте
