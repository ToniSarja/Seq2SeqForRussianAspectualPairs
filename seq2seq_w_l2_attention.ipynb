# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import random

data = pd.read_csv("real_nonce.csv")
df = pd.DataFrame(data)
teacher = df["prime"]
learner = df["target"]

pairs = list(zip(teacher, learner))

# %%
# Character processing remains the same
all_text = [char for src, tgt in pairs for char in src + tgt]
chars = sorted(set(all_text))
char2idx = {c: i+4 for i, c in enumerate(chars)}
char2idx["<PAD>"] = 0
char2idx["<SOS>"] = 1
char2idx["<EOS>"] = 2
char2idx["<UNK>"] = 3
idx2char = {i: c for c, i in char2idx.items()}
vocab_size = len(char2idx)

class VerbPairDataset(Dataset):
    def __init__(self, pairs, char2idx, max_len=20):
        self.pairs = pairs
        self.char2idx = char2idx
        self.max_len = max_len

    def encode(self, word, add_sos=False):
        if not word:  # Handle empty input
            word = "<UNK>"
        seq = [char2idx.get(c, char2idx["<UNK>"]) for c in word]
        if add_sos:
            seq = [char2idx["<SOS>"]] + seq
        seq = seq + [char2idx["<EOS>"]]
        seq += [char2idx["<PAD>"]] * (self.max_len - len(seq))
        return seq[:self.max_len]

    def __len__(self):
        return len(self.pairs)

    def __getitem__(self, idx):
        src, tgt = self.pairs[idx]
        src_encoded = self.encode(src)
        tgt_encoded = self.encode(tgt, add_sos=True)
        return torch.tensor(src_encoded), torch.tensor(tgt_encoded)
    
class Attention(nn.Module):
    def __init__(self, hidden_dim):
        super().__init__()
        self.attn = nn.Linear(hidden_dim * 2, hidden_dim)
        self.v = nn.Linear(hidden_dim, 1, bias=False)

    def forward(self, hidden, encoder_outputs):
        # hidden: (1, batch_size, hidden_dim)
        # encoder_outputs: (batch_size, seq_len, hidden_dim)
        hidden = hidden.squeeze(0)  # (batch_size, hidden_dim)
        
        # Repeat hidden for each encoder output
        hidden_expanded = hidden.unsqueeze(1).expand(-1, encoder_outputs.shape[1], -1)  # (batch_size, seq_len, hidden_dim)
        
        # Concatenate and score
        energy = torch.tanh(self.attn(torch.cat((hidden_expanded, encoder_outputs), dim=2)))  # (batch_size, seq_len, hidden_dim)
        attention_scores = self.v(energy).squeeze(2)  # (batch_size, seq_len)
        
        return torch.softmax(attention_scores, dim=1)
        
class Encoder(nn.Module):
    def __init__(self, vocab_size, emb_dim, hidden_dim):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, emb_dim)
        self.lstm = nn.LSTM(emb_dim, hidden_dim, batch_first=True, bidirectional=True)
        self.fc = nn.Linear(hidden_dim * 2, hidden_dim)
        self.ln = nn.LayerNorm(hidden_dim)

    def forward(self, x):
        embedded = self.embedding(x)
        outputs, (hidden, cell) = self.lstm(embedded)

        # Merge bidirectional outputs
        outputs = self.fc(outputs)  # (batch_size, seq_len, hidden_dim)
        outputs = self.ln(outputs)

        # Adjust hidden state (sum bidirectional states)
        hidden = hidden.view(2, -1, hidden.shape[2])  # (2, batch_size, hidden_dim)
        hidden = torch.sum(hidden, dim=0).unsqueeze(0)  # (1, batch_size, hidden_dim)
        hidden = torch.tanh(hidden)

        # Ensure cell state is also 3D
        cell = cell.view(2, -1, cell.shape[2])
        cell = torch.sum(cell, dim=0).unsqueeze(0)

        return outputs, hidden, cell
        
class Decoder(nn.Module):
    def __init__(self, vocab_size, emb_dim, hidden_dim):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, emb_dim)
        self.lstm = nn.LSTM(emb_dim + hidden_dim, hidden_dim, batch_first=True)
        self.attention = Attention(hidden_dim)
        self.fc = nn.Linear(hidden_dim * 2, vocab_size)
        self.ln = nn.LayerNorm(hidden_dim)

    def forward(self, x, hidden, cell, encoder_outputs):
        x = x.unsqueeze(1)  # (batch_size, 1)
        embedded = self.embedding(x)  # (batch_size, 1, emb_dim)

        # Ensure hidden/cell are 3D: (num_layers, batch_size, hidden_dim)
        if hidden.dim() == 2:
            hidden = hidden.unsqueeze(0)  # (1, batch_size, hidden_dim)
        if cell.dim() == 2:
            cell = cell.unsqueeze(0)

        # Calculate attention
        attn_weights = self.attention(hidden, encoder_outputs)  # (batch_size, seq_len)
        context = torch.bmm(attn_weights.unsqueeze(1), encoder_outputs)  # (batch_size, 1, hidden_dim)

        # Combine embedding and context
        lstm_input = torch.cat((embedded, context), dim=2)  # (batch_size, 1, emb_dim + hidden_dim)

        # LSTM step
        output, (hidden, cell) = self.lstm(lstm_input, (hidden, cell))
        output = self.ln(output)

        # Final prediction
        output = torch.cat((output.squeeze(1), context.squeeze(1)), dim=1)
        prediction = self.fc(output)

        return prediction, hidden, cell, attn_weights
def train_seq2seq(encoder, decoder, dataloader, epochs=20):
    criterion = nn.CrossEntropyLoss(ignore_index=char2idx["<PAD>"])
    optimizer = optim.Adam(list(encoder.parameters()) + list(decoder.parameters()), lr=0.0001)
    
    for epoch in range(epochs):
        total_loss = 0
        teacher_forcing_ratio = 0.8 * (0.9 ** epoch)
        
        for src, tgt in dataloader:
            optimizer.zero_grad()
            
            if src.nelement() == 0 or tgt.nelement() == 0:
                continue
                
            # Encoder forward (returns all outputs)
            encoder_outputs, hidden, cell = encoder(src)
            input_token = tgt[:, 0]
            loss = 0
            
            for t in range(1, tgt.shape[1]):
                # Decoder with attention
                output, hidden, cell, _ = decoder(
                    input_token, hidden, cell, encoder_outputs
                )
                step_loss = criterion(output, tgt[:, t])
                
                if torch.isnan(step_loss).any():
                    continue
                    
                loss += step_loss
                teacher_force = random.random() < teacher_forcing_ratio
                input_token = tgt[:, t] if teacher_force else output.argmax(1)
            
            if torch.isnan(loss).any() or loss == 0:
                continue
                
            loss.backward()
            torch.nn.utils.clip_grad_norm_(encoder.parameters(), 1.0)
            torch.nn.utils.clip_grad_norm_(decoder.parameters(), 1.0)
            optimizer.step()
            
            total_loss += loss.item() / tgt.shape[1]
        
        avg_loss = total_loss / len(dataloader)
        print(f"Epoch {epoch+1}, Loss: {avg_loss:.4f}")

# %%
# Initialize with larger batch size
dataset = VerbPairDataset(pairs, char2idx)
dataloader = DataLoader(dataset, batch_size=16, shuffle=True)  # Increased from 2 to 16

encoder = Encoder(vocab_size, emb_dim=64, hidden_dim=128)
decoder = Decoder(vocab_size, emb_dim=64, hidden_dim=128)

train_seq2seq(encoder, decoder, dataloader, epochs=200)
# Out:
# Epoch 1, Loss: 1.6551
# Epoch 2, Loss: 1.2270
# Epoch 3, Loss: 1.0619
# Epoch 4, Loss: 1.0409
# Epoch 5, Loss: 0.9926
# Epoch 6, Loss: 0.9805
# Epoch 7, Loss: 0.9445
# Epoch 8, Loss: 0.9570
# Epoch 9, Loss: 0.9485
# Epoch 10, Loss: 0.9909
# Epoch 11, Loss: 0.9856
# Epoch 12, Loss: 0.9636
# Epoch 13, Loss: 0.9487
# Epoch 14, Loss: 0.9067
# Epoch 15, Loss: 0.9698
# Epoch 16, Loss: 0.9602
# Epoch 17, Loss: 0.9495
# Epoch 18, Loss: 0.9432
# Epoch 19, Loss: 0.9565
# Epoch 20, Loss: 0.9475
# Epoch 21, Loss: 0.8912
# Epoch 22, Loss: 0.8783
# Epoch 23, Loss: 0.8911
# Epoch 24, Loss: 0.8889
# Epoch 25, Loss: 0.8490
# Epoch 26, Loss: 0.8898
# Epoch 27, Loss: 0.8877
# Epoch 28, Loss: 0.8511
# Epoch 29, Loss: 0.8674
# Epoch 30, Loss: 0.8431
# Epoch 31, Loss: 0.8659
    encoder.eval()
    decoder.eval()

    # Prepare input tensor
    seq = [char2idx.get(c, char2idx["<UNK>"]) for c in word] + [char2idx["<EOS>"]]
    seq += [char2idx["<PAD>"]] * (max_len - len(seq))
    src_tensor = torch.tensor([seq[:max_len]], dtype=torch.long)

    # Encoder forward
    with torch.no_grad():
        encoder_outputs, hidden, cell = encoder(src_tensor)

    # Start decoding
    input_token = torch.tensor([char2idx["<SOS>"]], dtype=torch.long)
    decoded_indices = []

    for _ in range(max_len):
        with torch.no_grad():
            output, hidden, cell, attn_weights = decoder(
                input_token, hidden, cell, encoder_outputs
            )
        prediction = output.argmax(1).item()

        if prediction == char2idx["<EOS>"]:
            break

        decoded_indices.append(prediction)
        input_token = torch.tensor([prediction], dtype=torch.long)

    return ''.join(idx2char[idx] for idx in decoded_indices)

# %%
import nltk
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
import editdistance

# %%
smoothie = SmoothingFunction().method4

def compute_metrics(row):
    pred = row["target_pred"]
    truth = row["target"]

    # Exact match
    is_exact = pred == truth

    # Edit distance
    edit_dist = editdistance.eval(pred, truth)

    # Character accuracy
    max_len = max(len(pred), len(truth))
    char_acc = 1 - (edit_dist / max_len) if max_len > 0 else 1.0

    # BLEU score (character-level)
    bleu = sentence_bleu(
        [list(truth)], list(pred), weights=(1, 0, 0, 0), smoothing_function=smoothie
    )

    return pd.Series([is_exact, edit_dist, char_acc, bleu],
                     index=["is_exact", "edit_distance", "char_accuracy", "bleu"])

# %%
df["target_pred"] = df["prime"].apply(lambda word: predict(encoder, decoder, word, char2idx, idx2char, max_len=20))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df["target_pred"] = df["prime"].apply(lambda word: predict(encoder, decoder, word, char2idx, idx2char, max_len=20))
#
# File ~/python stuff/pytorch_stuff/lib/python3.11/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)   4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)   4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File ~/python stuff/pytorch_stuff/lib/python3.11/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~/python stuff/pytorch_stuff/lib/python3.11/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/python stuff/pytorch_stuff/lib/python3.11/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/python stuff/pytorch_stuff/lib/python3.11/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[6], line 1, in <lambda>(word)
# ----> 1 df["target_pred"] = df["prime"].apply(lambda word: predict(encoder, decoder, word, char2idx, idx2char, max_len=20))
#
# NameError: name 'encoder' is not defined

# %%
df[["is_exact", "edit_distance", "char_accuracy", "bleu"]] = df.apply(compute_metrics, axis=1)

# %%
print("Exact Match Accuracy:", df["is_exact"].mean())
print("Average Edit Distance:", df["edit_distance"].mean())
print("Average Character Accuracy:", df["char_accuracy"].mean())
print("Average BLEU Score:", df["bleu"].mean())
# Out:
# Exact Match Accuracy: 0.8866213151927438
# Average Edit Distance: 0.42403628117913833
# Average Character Accuracy: 0.9490202352447251
# Average BLEU Score: 0.9609782440218038

# %%
# Save model and optimizer states
torch.save({
    'encoder_state_dict': encoder.state_dict(),
    'decoder_state_dict': decoder.state_dict(),
}, 'l2_prime_target_seq2seq_attention_model.pth')

# %%
# Rebuild the models with the same dimensions used during training
emb_dim = 64        # or whatever value you used
hidden_dim = 128    # match your training setup

encoder = Encoder(vocab_size, emb_dim, hidden_dim)
decoder = Decoder(vocab_size, emb_dim, hidden_dim)

# Load the checkpoint
checkpoint = torch.load('l2_prime_target_seq2seq_attention_model.pth', map_location='cuda')
encoder.load_state_dict(checkpoint['encoder_state_dict'])
decoder.load_state_dict(checkpoint['decoder_state_dict'])

# Set to eval mode
encoder.eval()
decoder.eval()
# Out:
# Decoder(
#   (embedding): Embedding(67, 64)
#   (lstm): LSTM(192, 128, batch_first=True)
#   (attention): Attention(
#     (attn): Linear(in_features=256, out_features=128, bias=True)
#     (v): Linear(in_features=128, out_features=1, bias=False)
#   )
#   (fc): Linear(in_features=256, out_features=67, bias=True)
#   (ln): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
# )

# %%
import torch.nn.functional as F

def compute_surprisal(decoder, encoder_outputs, hidden, cell, tgt_seq):
    surprisal = 0.0
    input_token = tgt_seq[:, 0]
    for t in range(1, tgt_seq.shape[1]):
        output, hidden, cell, _ = decoder(input_token, hidden, cell, encoder_outputs)
        log_probs = F.log_softmax(output, dim=1)
        target_token = tgt_seq[:, t]
        token_log_prob = log_probs.gather(1, target_token.unsqueeze(1)).squeeze(1)
        surprisal += -token_log_prob
        input_token = target_token  # Greedy decoding
    return surprisal.mean().item()

# %%
def get_embedding_output(encoder, word_tensor):
    with torch.no_grad():
        outputs, _, _ = encoder(word_tensor)
        # Mean pooling over non-padding tokens
        mask = (word_tensor != char2idx["<PAD>"]).unsqueeze(2)
        pooled = (outputs * mask).sum(1) / mask.sum(1)
    return pooled

# %%
def encode_tensor(word, char2idx, max_len=20, add_sos=False):
    seq = [char2idx.get(c, char2idx["<UNK>"]) for c in word]
    if add_sos:
        seq = [char2idx["<SOS>"]] + seq
    seq = seq + [char2idx["<EOS>"]]
    seq += [char2idx["<PAD>"]] * (max_len - len(seq))
    seq = seq[:max_len]
    return torch.tensor([seq])  # Batch size = 1

# %%
# Example inputs
word1 = "поговорить"
word2 = "говорить"

# Convert to tensors
tensor1 = encode_tensor(word1, char2idx)
tensor2 = encode_tensor(word2, char2idx)

# Feed to encoder
vec1 = get_embedding_output(encoder, tensor1)
vec2 = get_embedding_output(encoder, tensor2)

# Cosine similarity
similarity = F.cosine_similarity(vec1, vec2)
print("Cosine similarity:", similarity.item())
# Out:
# Cosine similarity: 0.9397709369659424

# %%
unrelated_prime = "все-таки"
target = "СМОТРЕТЬ"

src_tensor = encode_tensor(unrelated_prime, char2idx, max_len=20)
tgt_tensor = encode_tensor(target, char2idx, max_len=20, add_sos=True)

encoder_outputs, hidden, cell = encoder(src_tensor)
surprisal_value = compute_surprisal(decoder, encoder_outputs, hidden, cell, tgt_tensor)

print(f"Surprisal for '{target}' after '{unrelated_prime}': {surprisal_value:.4f}")
# Out:
# Surprisal for 'СМОТРЕТЬ' after 'все-таки': 154.8890

# %%
related_prime = "посмотреть"
target = "СМОТРЕТЬ"

src_tensor = encode_tensor(related_prime, char2idx, max_len=20)
tgt_tensor = encode_tensor(target, char2idx, max_len=20, add_sos=True)

encoder_outputs, hidden, cell = encoder(src_tensor)
surprisal_value = compute_surprisal(decoder, encoder_outputs, hidden, cell, tgt_tensor)

print(f"Surprisal for '{target}' after '{related_prime}': {surprisal_value:.4f}")
# Out:
# Surprisal for 'СМОТРЕТЬ' after 'посмотреть': 127.4068

# %%
def get_embedding_output(encoder, word_tensor):
    with torch.no_grad():
        outputs, _, _ = encoder(word_tensor)
        # Mean pooling over non-padding tokens
        mask = (word_tensor != char2idx["<PAD>"]).unsqueeze(2)
        pooled = (outputs * mask).sum(1) / mask.sum(1)
    return pooled

# %%
stimulus = {
    "БЕЖАТЬ": "бежал",
    "БРОСИТЬ": "бросил",
    "ВСТРЕЧАТЬ": "встречал",
    "ВЫБРАТЬ": "выбрал",
    "ЗАБЫТЬ": "забыл",
    "КРИЧАТЬ": "кричал",
    "НАЧАТЬ": "начал",
    "ОЖИДАТЬ": "ожидал",
    "ПИСАТЬ": "писал",
    "ПЛАКАТЬ": "плакал",
    "ВЕРИТЬ": "поверить",
    "ГОВОРИТЬ": "поговорить",
    "ДЕРЖАТЬ": "подержать",
    "ДУМАТЬ": "подумать",
    "ЖЕЛАТЬ": "пожелать",
    "ИГРАТЬ": "поиграть",
    "ИСКАТЬ": "поискать",
    "КУРИТЬ": "покурить",
    "ЛЕЖАТЬ": "полежать",
    "ПОМНИТЬ": "помнил",
    "ПОНЯТЬ": "понял",
    "ПРОСИТЬ": "попросить",
    "СИДЕТЬ": "посидеть",
    "СЛУШАТЬ": "послушать",
    "СМОТРЕТЬ": "посмотреть",
    "СТАВИТЬ": "поставить",
    "СТОЯТЬ": "постоять",
    "СТРАДАТЬ": "пострадать",
    "СТРОИТЬ": "построить",
    "СЧИТАТЬ": "посчитать",
    "ТЕРЯТЬ": "потерять",
    "ТРАТИТЬ": "потратить",
    "РЕШИТЬ": "решил",
    "СЛЫШАТЬ": "слышал",
    "СНИМАТЬ": "снимал",
    "СОБРАТЬ": "собрал",
    "СООБЩИТЬ": "сообщил",
    "УБИТЬ": "убил",
    "УЗНАТЬ": "узнал",
    "УМЕТЬ": "умел"
}

for target, prime in stimulus.items():
    src_tensor = encode_tensor(prime, char2idx, max_len=20)
    tgt_tensor = encode_tensor(target, char2idx, max_len=20, add_sos=True)
    encoder_outputs, hidden, cell = encoder(src_tensor)
    surprisal_value = compute_surprisal(decoder, encoder_outputs, hidden, cell, tgt_tensor)

    print(f"Surprisal for '{target}' after '{prime}': {surprisal_value:.4f}")
# Out:
# Surprisal for 'БЕЖАТЬ' after 'бежал': 139.7279
# Surprisal for 'БРОСИТЬ' after 'бросил': 156.0452
# Surprisal for 'ВСТРЕЧАТЬ' after 'встречал': 109.6985
# Surprisal for 'ВЫБРАТЬ' after 'выбрал': 143.4145
# Surprisal for 'ЗАБЫТЬ' after 'забыл': 152.1673
# Surprisal for 'КРИЧАТЬ' after 'кричал': 141.2435
# Surprisal for 'НАЧАТЬ' after 'начал': 136.0975
# Surprisal for 'ОЖИДАТЬ' after 'ожидал': 138.0157
# Surprisal for 'ПИСАТЬ' after 'писал': 163.3674
# Surprisal for 'ПЛАКАТЬ' after 'плакал': 138.8557
# Surprisal for 'ВЕРИТЬ' after 'поверить': 159.7498
# Surprisal for 'ГОВОРИТЬ' after 'поговорить': 141.2491
# Surprisal for 'ДЕРЖАТЬ' after 'подержать': 133.5329
# Surprisal for 'ДУМАТЬ' after 'подумать': 149.6062
# Surprisal for 'ЖЕЛАТЬ' after 'пожелать': 119.6074
# Surprisal for 'ИГРАТЬ' after 'поиграть': 162.3116
# Surprisal for 'ИСКАТЬ' after 'поискать': 146.9487
# Surprisal for 'КУРИТЬ' after 'покурить': 164.3717
# Surprisal for 'ЛЕЖАТЬ' after 'полежать': 130.6950
# Surprisal for 'ПОМНИТЬ' after 'помнил': 150.1490
# Surprisal for 'ПОНЯТЬ' after 'понял': 163.5119
# Surprisal for 'ПРОСИТЬ' after 'попросить': 156.3406
# Surprisal for 'СИДЕТЬ' after 'посидеть': 153.2991
# Surprisal for 'СЛУШАТЬ' after 'послушать': 129.5957
# Surprisal for 'СМОТРЕТЬ' after 'посмотреть': 127.4068
# Surprisal for 'СТАВИТЬ' after 'поставить': 131.4149
# Surprisal for 'СТОЯТЬ' after 'постоять': 167.3321
# Surprisal for 'СТРАДАТЬ' after 'пострадать': 122.5130
# Surprisal for 'СТРОИТЬ' after 'построить': 153.4905
# Surprisal for 'СЧИТАТЬ' after 'посчитать': 126.6113
# Surprisal for 'ТЕРЯТЬ' after 'потерять': 159.2522
# Surprisal for 'ТРАТИТЬ' after 'потратить': 136.8847
# Surprisal for 'РЕШИТЬ' after 'решил': 164.8913
# Surprisal for 'СЛЫШАТЬ' after 'слышал': 133.3468
# Surprisal for 'СНИМАТЬ' after 'снимал': 132.1029
# Surprisal for 'СОБРАТЬ' after 'собрал': 146.3747
# Surprisal for 'СООБЩИТЬ' after 'сообщил': 123.1187
# Surprisal for 'УБИТЬ' after 'убил': 183.2840
# Surprisal for 'УЗНАТЬ' after 'узнал': 145.5956
# Surprisal for 'УМЕТЬ' after 'умел': 168.7038

# %%
unrelated_stimulus = {
    "БЕЖАТЬ": "мальчик",
    "БРОСИТЬ": "никакой",
    "ВЕРИТЬ": "самый",
    "ВСТРЕЧАТЬ": "крупный",
    "ВЫБРАТЬ": "назад",
    "ГОВОРИТЬ": "все-таки",
    "ДЕРЖАТЬ": "работа",
    "ДУМАТЬ": "мысль",
    "ЖЕЛАТЬ": "принцип",
    "ЗАБЫТЬ": "структура",
    "ИГРАТЬ": "великий",
    "ИСКАТЬ": "мужчина",
    "КРИЧАТЬ": "простой",
    "КУРИТЬ": "взгляд",
    "ЛЕЖАТЬ": "простой",
    "НАЧАТЬ": "всякий",
    "ОЖИДАТЬ": "внимание",
    "ПИСАТЬ": "черный",
    "ПЛАКАТЬ": "женщина",
    "ПОМНИТЬ": "власть",
    "ПОНЯТЬ": "хорошо",
    "ПРОСИТЬ": "близкий",
    "РЕШИТЬ": "далекий",
    "СИДЕТЬ": "первый",
    "СЛУШАТЬ": "готовый",
    "СЛЫШАТЬ": "история",
    "СМОТРЕТЬ": "впрочем",
    "СНИМАТЬ": "развитие",
    "СОБРАТЬ": "сильный",
    "СООБЩИТЬ": "важный",
    "СТАВИТЬ": "очередь",
    "СТОЯТЬ": "палец",
    "СТРАДАТЬ": "машина",
    "СТРОИТЬ": "область",
    "СЧИТАТЬ": "вторник",
    "ТЕРЯТЬ": "метод",
    "ТРАТИТЬ": "задание",
    "УБИТЬ": "часто",
    "УЗНАТЬ": "тысяча",
    "УМЕТЬ": "характер"
}

for target, prime in unrelated_stimulus.items():
    src_tensor = encode_tensor(prime, char2idx, max_len=20)
    tgt_tensor = encode_tensor(target, char2idx, max_len=20, add_sos=True)
    encoder_outputs, hidden, cell = encoder(src_tensor)
    surprisal_value = compute_surprisal(decoder, encoder_outputs, hidden, cell, tgt_tensor)

    print(f"Surprisal for '{target}' after '{prime}': {surprisal_value:.4f}")
# Out:
# Surprisal for 'БЕЖАТЬ' after 'мальчик': 152.1419
# Surprisal for 'БРОСИТЬ' after 'никакой': 151.0968
# Surprisal for 'ВЕРИТЬ' after 'самый': 164.1617
# Surprisal for 'ВСТРЕЧАТЬ' after 'крупный': 136.7074
# Surprisal for 'ВЫБРАТЬ' after 'назад': 146.0451
# Surprisal for 'ГОВОРИТЬ' after 'все-таки': 134.0031
# Surprisal for 'ДЕРЖАТЬ' after 'работа': 157.7887
# Surprisal for 'ДУМАТЬ' after 'мысль': 167.2929
# Surprisal for 'ЖЕЛАТЬ' after 'принцип': 168.0079
# Surprisal for 'ЗАБЫТЬ' after 'структура': 165.3170
# Surprisal for 'ИГРАТЬ' after 'великий': 168.5400
# Surprisal for 'ИСКАТЬ' after 'мужчина': 157.6588
# Surprisal for 'КРИЧАТЬ' after 'простой': 165.6801
# Surprisal for 'КУРИТЬ' after 'взгляд': 165.2780
# Surprisal for 'ЛЕЖАТЬ' after 'простой': 180.6647
# Surprisal for 'НАЧАТЬ' after 'всякий': 170.5712
# Surprisal for 'ОЖИДАТЬ' after 'внимание': 152.9007
# Surprisal for 'ПИСАТЬ' after 'черный': 164.5813
# Surprisal for 'ПЛАКАТЬ' after 'женщина': 142.2334
# Surprisal for 'ПОМНИТЬ' after 'власть': 158.8977
# Surprisal for 'ПОНЯТЬ' after 'хорошо': 174.0163
# Surprisal for 'ПРОСИТЬ' after 'близкий': 152.4176
# Surprisal for 'РЕШИТЬ' after 'далекий': 163.7885
# Surprisal for 'СИДЕТЬ' after 'первый': 170.3448
# Surprisal for 'СЛУШАТЬ' after 'готовый': 160.6704
# Surprisal for 'СЛЫШАТЬ' after 'история': 155.0043
# Surprisal for 'СМОТРЕТЬ' after 'впрочем': 142.0408
# Surprisal for 'СНИМАТЬ' after 'развитие': 146.5484
# Surprisal for 'СОБРАТЬ' after 'сильный': 155.8745
# Surprisal for 'СООБЩИТЬ' after 'важный': 133.6910
# Surprisal for 'СТАВИТЬ' after 'очередь': 154.7476
# Surprisal for 'СТОЯТЬ' after 'палец': 164.6864
# Surprisal for 'СТРАДАТЬ' after 'машина': 139.7176
# Surprisal for 'СТРОИТЬ' after 'область': 148.0689
# Surprisal for 'СЧИТАТЬ' after 'вторник': 159.8573
# Surprisal for 'ТЕРЯТЬ' after 'метод': 167.3025
# Surprisal for 'ТРАТИТЬ' after 'задание': 148.4076
# Surprisal for 'УБИТЬ' after 'часто': 187.7898
# Surprisal for 'УЗНАТЬ' after 'тысяча': 155.7797
# Surprisal for 'УМЕТЬ' after 'характер': 169.0424

# %%
df["target_pred"] = df["prime"].apply(lambda word: predict(encoder, decoder, word, char2idx, idx2char, max_len=20))

# %%
import pandas as pd

# Show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# To avoid cutting off wide content
pd.set_option('display.max_colwidth', None)


df
# Out:
#              prime         target       target_pred  is_exact  edit_distance  \
# 0           ТАЩИТЬ        ТАСКАТЬ           ТАСКАТЬ      True              0
# 1           зотеть         ЗОТЕТЬ            ЗОТЕТЬ      True              0
# 2            малыш         РОДИТЬ            РОДИТЬ      True              0
# 3            мначь          МНАЧЬ             МНАЧЬ      True              0
# 4         конфликт        СПОРИТЬ           СПОРИТЬ      True              0
# 5           рэбить         РЭБИТЬ            РЭБИТЬ      True              0
# 6           рагеть         РАГЕТЬ            РАГЕТЬ      True              0
# 7          дорогой         ЦЕНИТЬ            ЦЕНИТЬ      True              0
# 8           бореть         БОРЕТЬ            БОРЕТЬ      True              0
# 9          оказать        ОКАЗАТЬ           ОКАЗАТЬ      True              0
# 10           штука         РЕШАТЬ            РЕШАТЬ      True              0
# 11         обарать        ОБАРАТЬ           ОБАРАТЬ      True              0
# 12          власть         КЛАСТЬ           КОМНИТЬ     False              4
# 13          цорать         ЦОРАТЬ            ЦОРАТЬ      True              0
# 14         удивить         ВИСЕТЬ            ВИСЕТЬ      True              0
# 15           хнуть          ХНУТЬ             ХНУТЬ      True              0
# 16          начать         КАЧАТЬ            КАЧАТЬ      True              0
# 17       прововать         ВАВАТЬ            ВАВАТЬ      True              0
# 18      пострадать       СТРАДАТЬ          СТРАДАТЬ      True              0
# 19          аренда         ЛЕТЕТЬ            ЛЕТЕТЬ      True              0
# 20         словарь       ЦЕЛОВАТЬ          ЦЕЛОВАТЬ      True              0
# 21           ареть          АРЕТЬ             АРЕТЬ      True              0
# 22         полезть          ЛЕЗТЬ             ЛЕЗТЬ      True              0
# 23      посмотреть       СМОТРЕТЬ          СМОТРЕТЬ      True              0
# 24          венять         ВЕНЯТЬ            ВЕНЯТЬ      True              0
# 25         издание        ГИБНУТЬ           ГИБНУТЬ      True              0
# 26          димать         МИЗАТЬ            МИЗАТЬ      True              0
# 27         поехать          ЕХАТЬ             ЕХАТЬ      True              0
# 28          ромать         РОМАТЬ            РОМАТЬ      True              0
# 29      поработать       РАБОТАТЬ          РАБОТАТЬ      True              0
# 30          личать         ЛИЧАТЬ            ЛИЧАТЬ      True              0
# 31        полюбить         ЛЮБИТЬ            ЛЮБИТЬ      True              0
# 32          лешать         ЛЕШАТЬ            ЛЕШАТЬ      True              0
# 33        постоять         СТОЯТЬ            СТОЯТЬ      True              0
# 34          ращать         РАЩАТЬ            РАЩАТЬ      True              0
# 35        полежать         ЛЕЖАТЬ            ЛЕЖАТЬ      True              0
# 36            бють           БЮТЬ              БЮТЬ      True              0
# 37           ящить          ЯЩИТЬ             ЯЩИТЬ      True              0
# 38        поиграть         ИГРАТЬ            ИГРАТЬ      True              0
# 39          дужать         ДУЖАТЬ            ДУЖАТЬ      True              0
# 40       поставить        СТАВИТЬ           СТАВИТЬ      True              0
# 41            жучь           ЖУТЬ              ЖУТЬ      True              0
# 42       послушать        СЛУШАТЬ           СЛУШАТЬ      True              0
# 43          рокать         РОКАТЬ            РОКАТЬ      True              0
# 44          нунять         НУНЯТЬ            НУНЯТЬ      True              0
# 45         поспать          СПАТЬ             СПАТЬ      True              0
# 46          далеть         ДАЛЕТЬ            ДАЛЕТЬ      True              0
# 47        побывать         БЫВАТЬ            БЫВАТЬ      True              0
# 48         ботреть        БОТРЕТЬ           БОТРЕТЬ      True              0
# 49       попросить        ПРОСИТЬ           СРОСИТЬ     False              1
# 50          мувать         МУВАТЬ            МУВАТЬ      True              0
# 51        поискать         ИСКАТЬ            ИСКАТЬ      True              0
# 52         счастье       РАДОВАТЬ          РАВОВАТЬ     False              1
# 53          техеть         ТЕХЕТЬ            ТЕХЕТЬ      True              0
# 54        походить         ХОДИТЬ            ХОДИТЬ      True              0
# 55         готовый       МИМЕНИТЬ          СМИДАТЬЬ     False              6
# 56         никогда        БОЯТЬСЯ           БОЯТЬСЯ      True              0
# 57      московский       ПЕРОЖИТЬ          ПЕРОЖИТЬ      True              0
# 58        пожелать         ЖЕЛАТЬ            ЖЕЛАТЬ      True              0
# 59         пускать         ОСТИТЬ            ОСТИТЬ      True              0
# 60         желание    ЗНАКОМИТЬСЯ        ПЛАКОТЬСЯЯ     False              5
# 61         вкатять         МАТЯТЬ            МАТЯТЬ      True              0
# 62        помешать         МЕШАТЬ            МЕШАТЬ      True              0
# 63          лишать         ЛАШИТЬ            ЛАШИТЬ      True              0
# 64        потянуть         ТЯНУТЬ            ТЯНУТЬ      True              0
# 65       заключать         ЗАЧИТЬ            ЗАЧИТЬ      True              0
# 66           весна          ВЕСТИ             НЕСТИ     False              1
# 67      поделиться       ДЕЛИТЬСЯ          ДЕЛИТЬСЯ      True              0
# 68            бачь           БАЧЬ              БАЧЬ      True              0
# 69          теперь        ТЕРПЕТЬ           ТЕРПЕТЬ      True              0
# 70    рекомендация     СОВЕТОВАТЬ        СТЕОВВВАТЬ     False              5
# 71         понести          НЕСТИ             НЕСТИ      True              0
# 72          конять         КОНЯТЬ            КОНЯТЬ      True              0
# 73        потерять         ТЕРЯТЬ            ТЕРЯТЬ      True              0
# 74          лачить         ЛАЧИТЬ            ЛАЧИТЬ      True              0
# 75       состояние         ПАДАТЬ            ПАДАТЬ      True              0
# 76       присашать         ШАШАТЬ            ШАШАТЬ      True              0
# 77       повернуть        ВЕРНУТЬ           ВЕРНУТЬ      True              0
# 78           обеда        ОБЕЩАТЬ           ОБЕЩАТЬ      True              0
# 79          девить         ДЕВИТЬ            ДЕВИТЬ      True              0
# 80       потратить        ТРАТИТЬ           ТРАТИТЬ      True              0
# 81        директор      СЛЕДОВАТЬ         СЛЕДОВАТЬ      True              0
# 82          сюшать         СЮШАТЬ            СЮШАТЬ      True              0
# 83         связист        СВЯТИТЬ           СВЯТИТЬ      True              0
# 84          другой         ДУМАТЬ            ДУМАТЬ      True              0
# 85          статья          СТАТЬ            ЖАЛЕТЬ     False              4
# 86           енять          ЕНЯТЬ             ЕНЯТЬ      True              0
# 87            мышь           МЫТЬ              МЫТЬ      True              0
# 88           чтобы         ДАВАТЬ            ДАВАТЬ      True              0
# 89        все-таки       ГОВОРИТЬ          ГОВОРИТЬ      True              0
# 90          генать         ГЕНАТЬ            ГЕНАТЬ      True              0
# 91          первый         СИДЕТЬ            СЕДИТЬ     False              2
# 92          шурать         ШУРАТЬ            ШУРАТЬ      True              0
# 93          только         ЧИТАТЬ            ЧИТАТЬ      True              0
# 94           асять          АСЯТЬ             АСЯТЬ      True              0
# 95            даже          ЗВАТЬ             ЗВАТЬ      True              0
# 96          гирать         ГИРАТЬ            ГИРАТЬ      True              0
# 97            дело           ПИТЬ              ПИТЬ      True              0
# 98          голять         ГОЛЯТЬ            ГОЛЯТЬ      True              0
# 99          работа        ДЕРЖАТЬ           РЕРЖАТЬ     False              1
# 100         чикать         ЧИКАТЬ            ЧИКАТЬ      True              0
# 101       например       ЯВЛЯТЬСЯ          ЯЛЯЯТЬСЯ     False              2
# 102         шорать         ШОРАТЬ            ШОРАТЬ      True              0
# 103    возможность    ЧУВСТВОВАТЬ      КУВВВВВВВАТЬ     False              5
# 104         бишать         БИШАТЬ            БИШАТЬ      True              0
# 105      настоящий       ПЫТАТЬСЯ          ПЫТАТЬСЯ      True              0
# 106         ганять         ГАНЯТЬ            ГАНЯТЬ      True              0
# 107          самый         ВЕРИТЬ            ВЕРИТЬ      True              0
# 108        кинлить        КИНЛИТЬ           КИНЛИТЬ      True              0
# 109        большой        ЗВОНИТЬ           ЗВОНИТЬ      True              0
# 110       отвасять         ВУСЯТЬ            ВУСЯТЬ      True              0
# 111        ребенок      ТРЕБОВАТЬ         ТРЕБОВАТЬ      True              0
# 112         шадать         ШАДАТЬ            ШАДАТЬ      True              0
# 113         именно         КУПИТЬ            КУПИТЬ      True              0
# 114         барать         БАРАТЬ            БАРАТЬ      True              0
# 115      несколько      НРАВИТЬСЯ          НРАВВИТЬ     False              3
# 116         пузать         ПУЗАТЬ            ПУЗАТЬ      True              0
# 117         города         МЕНЯТЬ            МЕНЯТЬ      True              0
# 118          олять          ОЛЯТЬ             ОЛЯТЬ      True              0
# 119        женщина      СТАРАТЬСЯ         ПЛАРАТЬСЯ     False              2
# 120         викать         ВИКАТЬ            ВИКАТЬ      True              0
# 121         деньги        ГЛЯДЕТЬ           ГЛЯДЕТЬ      True              0
# 122        область        СТРОИТЬ           СТРОИТЬ      True              0
# 123     обраривать      ОБАРИВАТЬ         ОБАРИВАТЬ      True              0
# 124        молодой        МОЛЧАТЬ           МОЛЧАТЬ      True              0
# 125         собрал        СОБРАТЬ           СОБРАТЬ      True              0
# 126         ниветь         НИВЕТЬ            НИВЕТЬ      True              0
# 127         плакал        ПЛАКАТЬ           ПЛАКАТЬ      True              0
# 128         митять         МИТЯТЬ            МИТЯТЬ      True              0
# 129         хватил        ХВАТИТЬ           ХВАТИТЬ      True              0
# 130       галереть       ГАЛЕРЕТЬ          ГАЛЕРЕТЬ      True              0
# 131         выбрал        ВЫБРАТЬ           ВЫБРАТЬ      True              0
# 132        станять         ЦАНЯТЬ            ЦАНЯТЬ      True              0
# 133       встречал      ВСТРЕЧАТЬ         ВСТРЕЧАТЬ      True              0
# 134          занял         ЗАНЯТЬ            ЗАНЯТЬ      True              0
# 135          выпил         ВЫПИТЬ            ВЫПИТЬ      True              0
# 136         риветь         РИВЕТЬ            РИВЕТЬ      True              0
# 137         значил        ЗНАЧИТЬ           ЗНАЧИТЬ      True              0
# 138         случай        СЛУЖИТЬ           СЛУЖИТЬ      True              0
# 139       рыгивать       РЫГИВАТЬ          РЫГИВАТЬ      True              0
# 140          отдал         ОТДАТЬ            ОТДАТЬ      True              0
# 141       копачать       КОПАЧАТЬ          КОПАЧАТЬ      True              0
# 142        сообщил       СООБЩИТЬ          СООБЩИТЬ      True              0
# 143       извинять         ДИНИТЬ            ДИНИТЬ      True              0
# 144         кричал        КРИЧАТЬ           КРИЧАТЬ      True              0
# 145      араливать      АРАЛИВАТЬ         АРАЛИВАТЬ      True              0
# 146         вызвал        ВЫЗВАТЬ           ВЫЗВАТЬ      True              0
# 147         цареть         ЦАРЕТЬ            ЦАРЕТЬ      True              0
# 148         заявил        ЗАЯВИТЬ           ЗАЯВИТЬ      True              0
# 149         цорать         ЦОРАТЬ            ЦОРАТЬ      True              0
# 150         входил        ВХОДИТЬ           ВХОДИТЬ      True              0
# 151        обарать        ОБАРАТЬ           ОБАРАТЬ      True              0
# 152          забыл         ЗАБЫТЬ            ЗАБЫТЬ      True              0
# 153       цигачить       ЦИГАЧИТЬ          ЦИГАЧИТЬ      True              0
# 154           умел          УМЕТЬ             УМЕТЬ      True              0
# 155      бурличать      БУРЛИЧАТЬ         БУРЛИЧАТЬ      True              0
# 156        питание        КОРМИТЬ           КОРМИТЬ      True              0
# 157           убил          УБИТЬ             УБИТЬ      True              0
# 158          имен           ИМЕТЬ             ИМЕТЬ      True              0
# 159          яреть          ЯРЕТЬ             ЯРЕТЬ      True              0
# 160          бежал         БЕЖАТЬ            БЕЖАТЬ      True              0
# 161       покурить         КУРИТЬ            КУРИТЬ      True              0
# 162      трировать      ТРИРОВАТЬ         ТРИРОВАТЬ      True              0
# 163        никакой        БРОСИТЬ           БРОСИТЬ      True              0
# 164       дидарить       ДИДАРИТЬ          ДИДАРИТЬ      True              0
# 165         всегда         НОСИТЬ            НОСИТЬ      True              0
# 166         чобить         ЧОБИТЬ            ЧОБИТЬ      True              0
# 167         хорошо         ПОНЯТЬ            ПОНЯТЬ      True              0
# 168          ягать          ЯГАТЬ             ЯГАТЬ      True              0
# 169         всякий         НАЧАТЬ            НАЧАТЬ      True              0
# 170        грыгать        ГРЫГАТЬ           ГРЫГАТЬ      True              0
# 171         черный         ПИСАТЬ            ПИСАТЬ      True              0
# 172         бидать         БИДАТЬ            БИДАТЬ      True              0
# 173       действие       РЕРАТИТЬ          РЕРАТИТЬ      True              0
# 174        далекий         РЕШИТЬ             ИМЕТЬ     False              4
# 175         людеть         ЛЮДЕТЬ            ЛЮДЕТЬ      True              0
# 176        ловушка        ПОЙМАТЬ           ПОЙМАТЬ      True              0
# 177         лилять         ЛИЛЯТЬ            ЛИЛЯТЬ      True              0
# 178        процесс        ПОДНЯТЬ           ПОНЯТЬЬ     False              2
# 179         шурать         ШУРАТЬ            ШУРАТЬ      True              0
# 180       радиация       ИЗЛУЧАТЬ          ИЗЛУЧАТЬ      True              0
# 181         рикать         РИКАТЬ            РИКАТЬ      True              0
# 182       развитие        СНИМАТЬ            СРМИТЬ     False              3
# 183       отвечать         ВЕТИТЬ            ВЕТИТЬ      True              0
# 184         сакать         САКАТЬ            САКАТЬ      True              0
# 185        история        СЛЫШАТЬ           СЛЫШАТЬ      True              0
# 186         берать         БЕРАТЬ            БЕРАТЬ      True              0
# 187           корм         ПИТАТЬ            ПИТАТЬ      True              0
# 188         лучший        СВЯЗАТЬ           СВЯЗАТЬ      True              0
# 189         гимать         ГИМАТЬ            ГИМАТЬ      True              0
# 190         власть        ПОМНИТЬ           КОМНИТЬ     False              1
# 191       отмечать         МАТИТЬ            МАТИТЬ      True              0
# 192          идать          ИДАТЬ             ИДАТЬ      True              0
# 193        поэтому        ПОПАСТЬ           ПОПАСТЬ      True              0
# 194     приглашать        ПРИСИТЬ           ПРИСИТЬ      True              0
# 195         люсять         ЛЮСЯТЬ            ЛЮСЯТЬ      True              0
# 196         вообще        СОЗДАТЬ           СОЗДАТЬ      True              0
# 197         сенять         СЕНЯТЬ            СЕНЯТЬ      True              0
# 198            нож         РЕЗАТЬ            РЕЗАТЬ      True              0
# 199         тысяча         УЗНАТЬ            УЗНАТЬ      True              0
# 200         викать         ВИКАТЬ            ВИКАТЬ      True              0
# 201         больше        НАЗВАТЬ           ЗАЗВАТЬ     False              1
# 202        товарищ      ДРУЖИТЬСЯ         ДРУЖИТЬСЯ      True              0
# 203         женять         ЖЕНЯТЬ            ЖЕНЯТЬ      True              0
# 204      поступать        СТУРИТЬ           СТУРИТЬ      True              0
# 205       квартира       ПЕРЕДАТЬ          ПЕРЕДАТЬ      True              0
# 206         генать         ГЕНАТЬ            ГЕНАТЬ      True              0
# 207      нападение  РЕКОМЕНДОВАТЬ     ТЕРОООООВВАТЬ     False              7
# 208          асять          АСЯТЬ             АСЯТЬ      True              0
# 209          конец      СОВЕРШАТЬ         СОВЕРШАТЬ      True              0
# 210       внимание        ОЖИДАТЬ           КОМДАТЬ     False              3
# 211         верать         ВЕРАТЬ            ВЕРАТЬ      True              0
# 212      посчитать        СЧИТАТЬ           СЧИТАТЬ      True              0
# 213       включать         ЛЮЧИТЬ            ЛЮЧИТЬ      True              0
# 214        великий        ПРИНЯТЬ           ПРИНЯТЬ      True              0
# 215      выражение   ИНТЕРЕСОВАТЬ      ДРЫРОВОВВАТЬ     False              7
# 216         шурить         ШУРИТЬ            ШУРИТЬ      True              0
# 217         полный        УКАЗАТЬ           ЛАААТТЬ     False              4
# 218      вторжение         ДАРИТЬ            СТРИТЬ     False              2
# 219      запрешать         РЕТИТЬ            РЕТИТЬ      True              0
# 220         статья         ЖАЛЕТЬ            ЖАЛЕТЬ      True              0
# 221         зотеть         ЗОТЕТЬ            ЗОТЕТЬ      True              0
# 222         пятеро         РОДИТЬ            РОДИТЬ      True              0
# 223          мначь          МНАЧЬ             МНАЧЬ      True              0
# 224       конфликт        СПОРИТЬ           СПОРИТЬ      True              0
# 225         робить         РЭБИТЬ            РЭБИТЬ      True              0
# 226         рагеть         РАГЕТЬ            РАГЕТЬ      True              0
# 227        дорогой         ЦЕНИТЬ            ЦЕНИТЬ      True              0
# 228         бореть         БОРЕТЬ            БОРЕТЬ      True              0
# 229        оказать        ОКАЗАТЬ           ОКАЗАТЬ      True              0
# 230        решетка         РЕШАТЬ            РЕШАТЬ      True              0
# 231        обарать        ОБАРАТЬ           ОБАРАТЬ      True              0
# 232           река         КЛАСТЬ            КЛАСТЬ      True              0
# 233         цорать         ЦОРАТЬ            ЦОРАТЬ      True              0
# 234        удивить         ВИСЕТЬ            ВИСЕТЬ      True              0
# 235          хнуть          ХНУТЬ             ХНУТЬ      True              0
# 236         ломать         КАЧАТЬ            КАЧАТЬ      True              0
# 237      прововать         ВАВАТЬ            ВАВАТЬ      True              0
# 238         машина       СТРАДАТЬ          ПАРАДАТЬ     False              2
# 239       полететь         ЛЕТЕТЬ            ЛЕТЕТЬ      True              0
# 240          целый       ЦЕЛОВАТЬ          ЦЕЛОВАТЬ      True              0
# 241          ареть          АРЕТЬ             АРЕТЬ      True              0
# 242          орган          ЛЕЗТЬ             ЛЕЗТЬ      True              0
# 243        впрочем       СМОТРЕТЬ          СМОТРЕТЬ      True              0
# 244         венять         ВЕНЯТЬ            ВЕНЯТЬ      True              0
# 245         смерть        ГИБНУТЬ           ГИБНУТЬ      True              0
# 246         димать         МИЗАТЬ            МИЗАТЬ      True              0
# 247        сильный          ЕХАТЬ            СХАТТЬ     False              2
# 248         ромать         РОМАТЬ            РОМАТЬ      True              0
# 249       наверное       РАБОТАТЬ          РАБОТАТЬ      True              0
# 250         личать         ЛИЧАТЬ            ЛИЧАТЬ      True              0
# 251        военный         ЛЮБИТЬ          СЛЯЯТЬСЯ     False              6
# 252         лешать         ЛЕШАТЬ            ЛЕШАТЬ      True              0
# 253          палец         СТОЯТЬ            СТОЯТЬ      True              0
# 254         ращать         РАЩАТЬ            РАЩАТЬ      True              0
# 255        простой         ЛЕЖАТЬ           СРЖАТТЬ     False              3
# 256           бють           БЮТЬ              БЮТЬ      True              0
# 257          ящить          ЯЩИТЬ             ЯЩИТЬ      True              0
# 258        великий         ИГРАТЬ           ПРИНЯТЬ     False              5
# 259         дужать         ДУЖАТЬ            ДУЖАТЬ      True              0
# 260        очередь        СТАВИТЬ           СТАВИТЬ      True              0
# 261           жучь           ЖУТЬ              ЖУТЬ      True              0
# 262        готовый        СЛУШАТЬ          СМИДАТЬЬ     False              4
# 263         рокать         РОКАТЬ            РОКАТЬ      True              0
# 264         нунять         НУНЯТЬ            НУНЯТЬ      True              0
# 265         сердце          СПАТЬ             СПАТЬ      True              0
# 266         далеть         ДАЛЕТЬ            ДАЛЕТЬ      True              0
# 267        крупный         БЫВАТЬ         БЫВТААТТЬ     False              3
# 268        ботреть        БОТРЕТЬ           БОТРЕТЬ      True              0
# 269        близкий        ПРОСИТЬ           ПРОСИТЬ      True              0
# 270         мувать         МУВАТЬ            МУВАТЬ      True              0
# 271        мужчина         ИСКАТЬ            ИСКАТЬ      True              0
# 272        страшно       РАДОВАТЬ          РАДОВАТЬ      True              0
# 273         техеть         ТЕХЕТЬ            ТЕХЕТЬ      True              0
# 274        готовый         ХОДИТЬ          СМИДАТЬЬ     False              5
# 275        готовый       МИМЕНИТЬ          СМИДАТЬЬ     False              6
# 276          страх        БОЯТЬСЯ           БОЯТЬСЯ      True              0
# 277     московский       ПЕРОЖИТЬ          ПЕРОЖИТЬ      True              0
# 278        принцип         ЖЕЛАТЬ            ЖЕЛАТЬ      True              0
# 279        пускать         ОСТИТЬ            ОСТИТЬ      True              0
# 280  познакомиться    ЗНАКОМИТЬСЯ       ЗНАКОМИТЬСЯ      True              0
# 281        вкатять         МАТЯТЬ            МАТЯТЬ      True              0
# 282        дорогой         МЕШАТЬ            ЦЕНИТЬ     False              3
# 283         лишать         ЛАШИТЬ            ЛАШИТЬ      True              0
# 284        процесс         ТЯНУТЬ           ПОНЯТЬЬ     False              4
# 285      заключать         ЗАЧИТЬ            ЗАЧИТЬ      True              0
# 286         словно          ВЕСТИ             ВЕСТИ      True              0
# 287        условие       ДЕЛИТЬСЯ          ДЕЛИТЬСЯ      True              0
# 288           бачь           БАЧЬ              БАЧЬ      True              0
# 289     вступление        ТЕРПЕТЬ           ТЕРПЕТЬ      True              0
# 290         старый     СОВЕТОВАТЬ        СООООВВАТЬ     False              4
# 291          весна          НЕСТИ             НЕСТИ      True              0
# 292         конять         КОНЯТЬ            КОНЯТЬ      True              0
# 293          метод         ТЕРЯТЬ            ТЕРЯТЬ      True              0
# 294         лачить         ЛАЧИТЬ            ЛАЧИТЬ      True              0
# 295         падаль         ПАДАТЬ            ПАДАТЬ      True              0
# 296      присашать         ШАШАТЬ            ШАШАТЬ      True              0
# 297       средство        ВЕРНУТЬ           ВЕРНУТЬ      True              0
# 298          фильм        ОБЕЩАТЬ           ОБЕЩАТЬ      True              0
# 299         девить         ДЕВИТЬ            ДЕВИТЬ      True              0
# 300        задание        ТРАТИТЬ           СТАТИТЬ     False              2
# 301    последовать      СЛЕДОВАТЬ         СЛЕДОВАТЬ      True              0
# 302         сюшать         СЮШАТЬ            СЮШАТЬ      True              0
# 303       государь        СВЯТИТЬ           СВЯТИТЬ      True              0
# 304          мысль         ДУМАТЬ            ДУМАТЬ      True              0
# 305       огромный          СТАТЬ             СТАТЬ      True              0
# 306          енять          ЕНЯТЬ             ЕНЯТЬ      True              0
# 307          женат           МЫТЬ              МЫТЬ      True              0
# 308       подавать         ДАВАТЬ            ДАВАТЬ      True              0
# 309     поговорить       ГОВОРИТЬ          ГОВОРИТЬ      True              0
# 310         генать         ГЕНАТЬ            ГЕНАТЬ      True              0
# 311       посидеть         СИДЕТЬ            СИДЕТЬ      True              0
# 312         шурать         ШУРАТЬ            ШУРАТЬ      True              0
# 313          книга         ЧИТАТЬ            ЧИТАТЬ      True              0
# 314          асять          АСЯТЬ             АСЯТЬ      True              0
# 315        позвать          ЗВАТЬ             ЗВАТЬ      True              0
# 316         гирать         ГИРАТЬ            ГИРАТЬ      True              0
# 317           вода           ПИТЬ              ПИТЬ      True              0
# 318         голять         ГОЛЯТЬ            ГОЛЯТЬ      True              0
# 319      подержать        ДЕРЖАТЬ           ДЕРЖАТЬ      True              0
# 320         чикать         ЧИКАТЬ            ЧИКАТЬ      True              0
# 321        военный       ЯВЛЯТЬСЯ          СЛЯЯТЬСЯ     False              3
# 322         шорать         ШОРАТЬ            ШОРАТЬ      True              0
# 323         эмоция    ЧУВСТВОВАТЬ       СВУВВВВВАТЬ     False              5
# 324         бишать         БИШАТЬ            БИШАТЬ      True              0
# 325       старание       ПЫТАТЬСЯ          ПЫТАТЬСЯ      True              0
# 326         ганять         ГАНЯТЬ            ГАНЯТЬ      True              0
# 327       поверить         ВЕРИТЬ            ВЕРИТЬ      True              0
# 328       отвасять         ВУСЯТЬ            ВУСЯТЬ      True              0
# 329        кинлить        КИНЛИТЬ           КИНЛИТЬ      True              0
# 330         зонтик        ЗВОНИТЬ           ЗВОНИТЬ      True              0
# 331          нужно      ТРЕБОВАТЬ         ТРЕБОВАТЬ      True              0
# 332         шадать         ШАДАТЬ            ШАДАТЬ      True              0
# 333         куплет         КУПИТЬ            КУПИТЬ      True              0
# 334         барать         БАРАТЬ            БАРАТЬ      True              0
# 335    понравиться      НРАВИТЬСЯ         НРАВИТЬСЯ      True              0
# 336         пузать         ПУЗАТЬ            ПУЗАТЬ      True              0
# 337       поменять         МЕНЯТЬ            МЕНЯТЬ      True              0
# 338          олять          ОЛЯТЬ             ОЛЯТЬ      True              0
# 339        попытка      СТАРАТЬСЯ         СТАРАТЬСЯ      True              0
# 340         викать         ВИКАТЬ            ВИКАТЬ      True              0
# 341         взгляд        ГЛЯДЕТЬ            КУРИТЬ     False              5
# 342      построить        СТРОИТЬ           СТРОИТЬ      True              0
# 343     обраривать      ОБАРИВАТЬ         ОБАРИВАТЬ      True              0
# 344      помолчать        МОЛЧАТЬ           МОЛЧАТЬ      True              0
# 345        сильный        СОБРАТЬ            СХАТТЬ     False              4
# 346         ниветь         НИВЕТЬ            НИВЕТЬ      True              0
# 347        женщина        ПЛАКАТЬ         ПЛАРАТЬСЯ     False              3
# 348         митять         МИТЯТЬ            МИТЯТЬ      True              0
# 349          рядом        ХВАТИТЬ           ХВАТИТЬ      True              0
# 350         рашать         РАШАТЬ            РАШАТЬ      True              0
# 351          назад        ВЫБРАТЬ           ВЫБРАТЬ      True              0
# 352        станять         ЦАНЯТЬ            ЦАНЯТЬ      True              0
# 353        крупный      ВСТРЕЧАТЬ         БЫВТААТТЬ     False              7
# 354         машина         ЗАНЯТЬ          ПАРАДАТЬ     False              5
# 355      искусство         ВЫПИТЬ            ВЫПИТЬ      True              0
# 356         риветь         РИВЕТЬ            РИВЕТЬ      True              0
# 357          рынок        ЗНАЧИТЬ           ЗНАЧИТЬ      True              0
# 358         задача        СЛУЖИТЬ           СЛУЖИТЬ      True              0
# 359       рыгивать       РЫГИВАТЬ          РЫГИВАТЬ      True              0
# 360        военный         ОТДАТЬ          СЛЯЯТЬСЯ     False              6
# 361       копачать       КОПАЧАТЬ          КОПАЧАТЬ      True              0
# 362         важный       СООБЩИТЬ          СООБЩИТЬ      True              0
# 363       извинять         ДИНИТЬ            ДИНИТЬ      True              0
# 364        простой        КРИЧАТЬ           СРЖАТТЬ     False              4
# 365      араливать      АРАЛИВАТЬ         АРАЛИВАТЬ      True              0
# 366        сколько        ЗАЯВИТЬ           ЗАВВИТЬ     False              1
# 367         цареть         ЦАРЕТЬ            ЦАРЕТЬ      True              0
# 368          давно        ВЫЗВАТЬ           ВЫЗВАТЬ      True              0
# 369         цорать         ЦОРАТЬ            ЦОРАТЬ      True              0
# 370          центр        ВХОДИТЬ           ВХОДИТЬ      True              0
# 371        обарать        ОБАРАТЬ           ОБАРАТЬ      True              0
# 372      структура         ЗАБЫТЬ            ЗАБЫТЬ      True              0
# 373       цигачить       ЦИГАЧИТЬ          ЦИГАЧИТЬ      True              0
# 374       характер          УМЕТЬ             УМЕТЬ      True              0
# 375      бурличать      БУРЛИЧАТЬ         БУРЛИЧАТЬ      True              0
# 376        питание        КОРМИТЬ           КОРМИТЬ      True              0
# 377          часто          УБИТЬ             УБИТЬ      True              0
# 378        далекий          ИМЕТЬ             ИМЕТЬ      True              0
# 379          яреть          ЯРЕТЬ             ЯРЕТЬ      True              0
# 380        мальчик         БЕЖАТЬ            БЕЖАТЬ      True              0
# 381         взгляд         КУРИТЬ            КУРИТЬ      True              0
# 382      трировать      ТРИРОВАТЬ         ТРИРОВАТЬ      True              0
# 383         бросил        БРОСИТЬ           БРОСИТЬ      True              0
# 384       дидарить       ДИДАРИТЬ          ДИДАРИТЬ      True              0
# 385            нос         НОСИТЬ            НОСИТЬ      True              0
# 386         чобить         ЧОБИТЬ            ЧОБИТЬ      True              0
# 387          понял         ПОНЯТЬ            ПОНЯТЬ      True              0
# 388          ягать          ЯГАТЬ             ЯГАТЬ      True              0
# 389          начал         НАЧАТЬ            НАЧАТЬ      True              0
# 390        грыгать        ГРЫГАТЬ           ГРЫГАТЬ      True              0
# 391          писал         ПИСАТЬ            ПИСАТЬ      True              0
# 392         бидать         БИДАТЬ            БИДАТЬ      True              0
# 393       действие       РЕРАТИТЬ          РЕРАТИТЬ      True              0
# 394          решил         РЕШИТЬ            РЕШИТЬ      True              0
# 395         людеть         ЛЮДЕТЬ            ЛЮДЕТЬ      True              0
# 396        ловушка        ПОЙМАТЬ           ПОЙМАТЬ      True              0
# 397         лилять         ЛИЛЯТЬ            ЛИЛЯТЬ      True              0
# 398         поднял        ПОДНЯТЬ           ПОДНЯТЬ      True              0
# 399         шурать         ШУРАТЬ            ШУРАТЬ      True              0
# 400       радиация       ИЗЛУЧАТЬ          ИЗЛУЧАТЬ      True              0
# 401         рикать         РИКАТЬ            РИКАТЬ      True              0
# 402         снимал        СНИМАТЬ           СНИМАТЬ      True              0
# 403       отвечать         ВЕТИТЬ            ВЕТИТЬ      True              0
# 404         сакать         САКАТЬ            САКАТЬ      True              0
# 405         слышал        СЛЫШАТЬ           СЛЫШАТЬ      True              0
# 406         берать         БЕРАТЬ            БЕРАТЬ      True              0
# 407           корм         ПИТАТЬ            ПИТАТЬ      True              0
# 408         святой        СВЯЗАТЬ           СВЯЗАТЬ      True              0
# 409         гимать         ГИМАТЬ            ГИМАТЬ      True              0
# 410         помнил        ПОМНИТЬ           ПОМНИТЬ      True              0
# 411       отмечать         МАТИТЬ            МАТИТЬ      True              0
# 412          идать          ИДАТЬ             ИДАТЬ      True              0
# 413        поп-арт        ПОПАСТЬ           ПОПАСТЬ      True              0
# 414     приглашать        ПРИСИТЬ           ПРИСИТЬ      True              0
# 415         люсять         ЛЮСЯТЬ            ЛЮСЯТЬ      True              0
# 416         здание        СОЗДАТЬ           СОЗДАТЬ      True              0
# 417         сенять         СЕНЯТЬ            СЕНЯТЬ      True              0
# 418            нож         РЕЗАТЬ            РЕЗАТЬ      True              0
# 419          узнал         УЗНАТЬ            УЗНАТЬ      True              0
# 420         викать         ВИКАТЬ            ВИКАТЬ      True              0
# 421            имя        НАЗВАТЬ           НАЗВАТЬ      True              0
# 422        товарищ      ДРУЖИТЬСЯ         ДРУЖИТЬСЯ      True              0
# 423         женять         ЖЕНЯТЬ            ЖЕНЯТЬ      True              0
# 424      поступать        СТУРИТЬ           СТУРИТЬ      True              0
# 425        передал       ПЕРЕДАТЬ          ПЕРЕДАТЬ      True              0
# 426         генать         ГЕНАТЬ            ГЕНАТЬ      True              0
# 427          совет  РЕКОМЕНДОВАТЬ  СОВООДООООВОВАТЬ     False             10
# 428          асять          АСЯТЬ             АСЯТЬ      True              0
# 429          конец      СОВЕРШАТЬ         СОВЕРШАТЬ      True              0
# 430         ожидал        ОЖИДАТЬ           ОЖИДАТЬ      True              0
# 431         верать         ВЕРАТЬ            ВЕРАТЬ      True              0
# 432        вторник        СЧИТАТЬ           ЧОИТАТЬ     False              2
# 433       включать         ЛЮЧИТЬ            ЛЮЧИТЬ      True              0
# 434         принял        ПРИНЯТЬ           ПРИНЯТЬ      True              0
# 435        интрига   ИНТЕРЕСОВАТЬ      БРЕБОООВВАТЬ     False              7
# 436         шурить         ШУРИТЬ            ШУРИТЬ      True              0
# 437          казак        УКАЗАТЬ           УКАЗАТЬ      True              0
# 438       подарить         ДАРИТЬ            ДАРИТЬ      True              0
# 439      запрешать         РЕТИТЬ            РЕТИТЬ      True              0
# 440          жилет         ЖАЛЕТЬ            ЖАЛЕТЬ      True              0
#
#      char_accuracy      bleu
# 0         1.000000  1.000000
# 1         1.000000  1.000000
# 2         1.000000  1.000000
